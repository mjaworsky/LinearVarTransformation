# %%
from sklearn.datasets import make_multilabel_classification
from sklearn.multioutput import MultiOutputClassifier
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.neural_network import MLPRegressor

from imblearn.ensemble import RUSBoostClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import hamming_loss
from sklearn.model_selection import KFold
from sklearn.metrics import classification_report
from skmultilearn.problem_transform import BinaryRelevance
from skmultilearn.problem_transform import ClassifierChain
from skmultilearn.problem_transform import LabelPowerset
from sklearn.datasets import make_classification
from sklearn.multioutput import MultiOutputClassifier
from sklearn.utils import shuffle
from sklearn.metrics import multilabel_confusion_matrix
from sklearn.metrics import confusion_matrix
import numpy as np
import os
import pandas as pd

# %%
folder = "C:/Users/mdjaw/OneDrive/Documents/Markian Training/Research_USQ/USCenterDiseaseControlPrevention/LLCP2020XPT" 
os.chdir(folder)

BRFSS_Grounded = pd.read_csv("LLCP2021XPT_GENDER_WEIGHT.csv")

print(BRFSS_Grounded.shape)

BRFSS_Grounded_X = BRFSS_Grounded.drop(['CNCRTYP1', 'CNCRDIFF'], axis = 1)

print(BRFSS_Grounded_X.shape)
# Out:
# (450946, 56)
# (450946, 54)

# %%
X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  MNB = model = MultinomialNB()
  multi_target_MNB = MultiOutputClassifier(MNB, n_jobs=2)
  y_pred = multi_target_MNB.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - MultinomialNB")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - MultinomialNB")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - MultinomialNB AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))



X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  RB = RUSBoostClassifier(random_state=0)
  multi_target_RB = MultiOutputClassifier(RB, n_jobs=2)
  y_pred = multi_target_RB.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - RusBoost")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - RusBoost")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - RusBoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))


X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  AB = AdaBoostClassifier(n_estimators=200,learning_rate=1)
  multi_target_AB = MultiOutputClassifier(AB, n_jobs=2)
  y_pred = multi_target_AB.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - AdaBoost")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - AdaBoost")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - AdaBoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))
# Out:
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00     80941
#            1       0.00      0.00      0.00      1273
#            2       0.01      0.99      0.01       281
#            3       0.00      0.00      0.00       167
#            4       0.00      0.00      0.00       122
#            5       0.00      0.00      0.00        29
#            6       0.00      0.00      0.00        23
#            7       0.00      0.00      0.00        38
#            8       0.00      0.00      0.00       202
#            9       0.00      0.50      0.00         4
#           10       0.00      0.00      0.00       307
#           11       0.00      0.00      0.00        23
#           12       0.00      0.00      0.00        26
#           13       0.00      0.00      0.00        23
#           14       0.00      0.00      0.00        32
#           15       0.00      0.00      0.00        34
#           16       0.00      0.00      0.00        66
#           17       0.00      0.00      0.00       107
#           18       0.00      0.00      0.00       104
#           19       0.00      0.00      0.00       736
#           20       0.00      0.00      0.00        36
#           21       0.00      0.00      0.00      1306
#           22       0.00      0.00      0.00      2931
#           24       0.00      0.00      0.00       200
#           25       0.00      0.00      0.00       162
#           26       0.00      0.00      0.00        87
#           27       0.00      0.00      0.00        40
#           28       0.00      0.00      0.00        26
#           29       0.00      0.00      0.00         3
#           30       0.00      0.00      0.00       427
#           77       0.00      0.00      0.00       393
#           99       0.00      0.00      0.00        41
#
#     accuracy                           0.00     90190
#    macro avg       0.00      0.05      0.00     90190
# weighted avg       0.00      0.00      0.00     90190
#
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - MultinomialNB
#               precision    recall  f1-score   support
#
#          100       0.00      0.00      0.00     80728
#          101       0.00      0.00      0.00      7042
#          102       0.00      0.00      0.00      1808
#          103       0.00      0.00      0.00       420
#          107       0.00      0.00      0.00       118
#          109       0.00      1.00      0.00        74
#
#     accuracy                           0.00     90190
#    macro avg       0.00      0.17      0.00     90190
# weighted avg       0.00      0.00      0.00     90190
#
# Hamming Loss: 0.9968954429537643
# Hamming Loss: 0.9991795099234948
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00     82564
#            1       0.00      0.00      0.00      1050
#            2       0.01      1.00      0.01       251
#            3       0.00      0.00      0.00       144
#            4       0.00      0.00      0.00       100
#            5       0.00      0.00      0.00        37
#            6       0.00      0.00      0.00        16
#            7       0.00      0.62      0.00        32
#            8       0.00      0.00      0.00       149
#            9       0.00      0.00      0.00        15
#           10       0.00      0.00      0.00       278
#           11       0.00      0.00      0.00        16
#           12       0.00      0.00      0.00        33
#           13       0.00      0.00      0.00        20
#           14       0.00      0.00      0.00        33
#           15       0.00      0.00      0.00        30
#           16       0.00      0.00      0.00        57
#           17       0.00      0.00      0.00       100
#           18       0.00      0.00      0.00        84
#           19       0.00      0.00      0.00       687
#           20       0.00      0.00      0.00        26
#           21       0.00      0.00      0.00      1100
#           22       0.00      0.00      0.00      2250
#           23       0.00      0.00      0.00         1
#           24       0.00      0.00      0.00       149
#           25       0.00      0.00      0.00       161
#           26       0.00      0.00      0.00       106
#           27       0.00      0.00      0.00        30
#           28       0.00      0.00      0.00        16
#           29       0.00      0.00      0.00         4
#           30       0.00      0.00      0.00       321
#           77       0.00      0.00      0.00       296
#           99       0.00      0.00      0.00        33
#
#     accuracy                           0.00     90189
#    macro avg       0.00      0.05      0.00     90189
# weighted avg       0.00      0.00      0.00     90189
#
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - MultinomialNB
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#          100       0.00      0.00      0.00     82402
#          101       0.00      0.00      0.00      5956
#          102       0.00      0.00      0.00      1354
#          103       0.00      0.52      0.01       322
#          107       0.00      0.49      0.00        84
#          109       0.00      0.00      0.00        71
#
#     accuracy                           0.00     90189
#    macro avg       0.00      0.17      0.00     90189
# weighted avg       0.00      0.00      0.00     90189
#
# Hamming Loss: 0.9969951989710497
# Hamming Loss: 0.9977048198782557
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       1.00      0.06      0.11     83129
#            1       0.02      0.46      0.04       941
#            2       0.00      0.49      0.01       186
#            3       0.00      0.03      0.00       145
#            4       0.00      0.00      0.00        80
#            5       0.00      0.00      0.00        16
#            6       0.00      0.00      0.00        21
#            7       0.00      0.05      0.00        20
#            8       0.00      0.00      0.00       141
#            9       0.00      0.00      0.00         4
#           10       0.00      0.00      0.00       224
#           11       0.00      0.00      0.00        19
#           12       0.00      0.00      0.00        28
#           13       0.00      0.00      0.00        23
#           14       0.00      0.00      0.00        20
#           15       0.00      0.00      0.00        21
#           16       0.00      0.00      0.00        39
#           17       0.00      0.00      0.00        93
#           18       0.00      0.00      0.00        91
#           19       0.02      0.59      0.03       602
#           20       0.00      0.09      0.00        32
#           21       0.00      0.00      0.00      1044
#           22       0.00      0.00      0.00      2278
#           23       0.00      0.00      0.00         2
#           24       0.00      0.00      0.00       113
#           25       0.00      0.00      0.00       134
#           26       0.00      0.00      0.00        91
#           27       0.00      0.00      0.00        26
#           28       0.00      0.00      0.00        22
#           29       0.00      0.00      0.00         1
#           30       0.00      0.00      0.00       324
#           77       0.00      0.00      0.00       234
#           99       0.00      0.09      0.00        45
#
#     accuracy                           0.07     90189
#    macro avg       0.03      0.06      0.01     90189
# weighted avg       0.92      0.07      0.11     90189
#
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - MultinomialNB
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#          100       0.97      0.16      0.28     82994
#          101       0.07      0.34      0.12      5503
#          102       0.02      0.26      0.04      1285
#          103       0.01      0.23      0.01       282
#          107       0.00      0.17      0.00        60
#          109       0.00      0.00      0.00        65
#
#     accuracy                           0.18     90189
#    macro avg       0.18      0.19      0.08     90189
# weighted avg       0.90      0.18      0.27     90189
#
# Hamming Loss: 0.9345152956568983
# Hamming Loss: 0.8240029271862422
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.97      0.59      0.74     87184
#            1       0.00      0.00      0.00       385
#            2       0.01      0.21      0.01        75
#            3       0.00      0.00      0.00        66
#            4       0.00      0.00      0.00        45
#            5       0.00      0.00      0.00        11
#            6       0.00      0.00      0.00         4
#            7       0.00      0.10      0.00        10
#            8       0.00      0.00      0.00        61
#            9       0.00      0.00      0.00         2
#           10       0.00      0.00      0.00       101
#           11       0.00      0.00      0.00         8
#           12       0.00      0.00      0.00        10
#           13       0.00      0.00      0.00         5
#           14       0.00      0.00      0.00         8
#           15       0.00      0.00      0.00        10
#           16       0.00      0.00      0.00        30
#           17       0.00      0.00      0.00        40
#           18       0.00      0.00      0.00        36
#           19       0.00      0.00      0.00       270
#           20       0.00      0.00      0.00        17
#           21       0.00      0.00      0.00       419
#           22       0.00      0.00      0.00       939
#           23       0.00      0.00      0.00         0
#           24       0.00      0.00      0.00        63
#           25       0.00      0.00      0.00        61
#           26       0.00      0.00      0.00        33
#           27       0.00      0.00      0.00         9
#           28       0.00      0.00      0.00         6
#           29       0.00      0.00      0.00         2
#           30       0.00      0.00      0.00       111
#           77       0.00      0.00      0.00       142
#           99       0.00      0.00      0.00        26
#
#     accuracy                           0.57     90189
#    macro avg       0.03      0.03      0.02     90189
# weighted avg       0.94      0.57      0.71     90189
#
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - MultinomialNB
#               precision    recall  f1-score   support
#
#          100       0.97      0.83      0.89     87129
#          101       0.05      0.12      0.07      2378
#          102       0.00      0.00      0.00       528
#          103       0.00      0.00      0.00       104
#          107       0.00      0.11      0.00        28
#          109       0.00      0.00      0.00        22
#
#     accuracy                           0.80     90189
#    macro avg       0.17      0.18      0.16     90189
# weighted avg       0.94      0.80      0.86     90189
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Hamming Loss: 0.4259832130304139
# Hamming Loss: 0.19898213751122643
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.98      0.54      0.69     86105
#            1       0.01      0.43      0.03       519
#            2       0.00      0.14      0.01       117
#            3       0.01      0.28      0.01        81
#            4       0.00      0.00      0.00        48
#            5       0.00      0.00      0.00         6
#            6       0.00      0.00      0.00         9
#            7       0.00      0.00      0.00        10
#            8       0.00      0.00      0.00       102
#            9       0.00      0.00      0.00         3
#           10       0.00      0.00      0.00       121
#           11       0.00      0.00      0.00        10
#           12       0.00      0.00      0.00        18
#           13       0.00      0.00      0.00        16
#           14       0.00      0.00      0.00         9
#           15       0.00      0.00      0.00        11
#           16       0.00      0.00      0.00        36
#           17       0.00      0.00      0.00        68
#           18       0.00      0.00      0.00        47
#           19       0.01      0.47      0.02       355
#           20       0.00      0.21      0.00        33
#           21       0.00      0.00      0.00       632
#           22       0.00      0.00      0.00      1269
#           23       0.00      0.00      0.00         1
#           24       0.00      0.00      0.00        60
#           25       0.00      0.00      0.00        77
#           26       0.00      0.00      0.00        45
#           27       0.00      0.00      0.00        13
#           28       0.00      0.00      0.00         7
#           29       0.00      0.00      0.00         2
#           30       0.00      0.00      0.00       156
#           77       0.00      0.00      0.00       185
#           99       0.00      0.00      0.00        18
#
#     accuracy                           0.52     90189
#    macro avg       0.03      0.06      0.02     90189
# weighted avg       0.93      0.52      0.66     90189
#
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - MultinomialNB
#               precision    recall  f1-score   support
#
#          100       0.96      0.70      0.81     86042
#          101       0.05      0.37      0.09      3175
#          102       0.00      0.00      0.00       768
#          103       0.00      0.03      0.00       150
#          107       0.00      0.00      0.00        35
#          109       0.00      0.00      0.00        19
#
#     accuracy                           0.68     90189
#    macro avg       0.17      0.18      0.15     90189
# weighted avg       0.92      0.68      0.78     90189
#
# Hamming Loss: 0.48347359434077325
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Hamming Loss: 0.31716728204104716
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - MultinomialNB AGGREGATE
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       1.00      0.02      0.04    246634
#            1       0.02      0.13      0.04      3264
#            2       0.01      0.86      0.01       718
#            3       0.00      0.01      0.00       456
#            4       0.00      0.00      0.00       302
#            5       0.00      0.00      0.00        82
#            6       0.00      0.00      0.00        60
#            7       0.00      0.23      0.00        90
#            8       0.00      0.00      0.00       492
#            9       0.00      0.09      0.00        23
#           10       0.00      0.00      0.00       809
#           11       0.00      0.00      0.00        58
#           12       0.00      0.00      0.00        87
#           13       0.00      0.00      0.00        66
#           14       0.00      0.00      0.00        85
#           15       0.00      0.00      0.00        85
#           16       0.00      0.00      0.00       162
#           17       0.00      0.00      0.00       300
#           18       0.00      0.00      0.00       279
#           19       0.02      0.17      0.03      2025
#           20       0.00      0.03      0.00        94
#           21       0.00      0.00      0.00      3450
#           22       0.00      0.00      0.00      7459
#           23       0.00      0.00      0.00         3
#           24       0.00      0.00      0.00       462
#           25       0.00      0.00      0.00       457
#           26       0.00      0.00      0.00       284
#           27       0.00      0.00      0.00        96
#           28       0.00      0.00      0.00        64
#           29       0.00      0.00      0.00         8
#           30       0.00      0.00      0.00      1072
#           77       0.00      0.00      0.00       923
#           99       0.00      0.03      0.00       119
#          100       0.00      0.00      0.00    163130
#          101       0.00      0.00      0.00     12998
#          102       0.00      0.00      0.00      3162
#          103       0.00      0.22      0.01       742
#          107       0.00      0.20      0.00       202
#          109       0.00      0.51      0.00       145
#
#     accuracy                           0.01    450947
#    macro avg       0.03      0.06      0.00    450947
# weighted avg       0.55      0.01      0.02    450947
#
# Hamming Loss: 0.9635543173579487
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - RusBoost
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00     80941
#            1       0.00      0.00      0.00      1273
#            2       0.00      0.00      0.00       281
#            3       0.00      0.00      0.00       167
#            4       0.00      0.00      0.00       122
#            5       0.00      0.00      0.00        29
#            6       0.00      0.00      0.00        23
#            7       0.00      0.00      0.00        38
#            8       0.00      0.76      0.01       202
#            9       0.00      0.50      0.00         4
#           10       0.00      0.00      0.00       307
#           11       0.00      0.00      0.00        23
#           12       0.00      0.00      0.00        26
#           13       0.00      0.00      0.00        23
#           14       0.00      0.00      0.00        32
#           15       0.00      0.00      0.00        34
#           16       0.00      0.00      0.00        66
#           17       0.00      0.00      0.00       107
#           18       0.00      0.00      0.00       104
#           19       0.00      0.00      0.00       736
#           20       0.00      0.00      0.00        36
#           21       0.00      0.00      0.00      1306
#           22       0.00      0.00      0.00      2931
#           24       0.00      0.00      0.00       200
#           25       0.00      0.00      0.00       162
#           26       0.00      0.00      0.00        87
#           27       0.00      0.00      0.00        40
#           28       0.00      0.00      0.00        26
#           29       0.00      0.00      0.00         3
#           30       0.00      0.00      0.00       427
#           77       0.00      0.00      0.00       393
#           99       0.00      0.00      0.00        41
#
#     accuracy                           0.00     90190
#    macro avg       0.00      0.04      0.00     90190
# weighted avg       0.00      0.00      0.00     90190
#
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - RusBoost
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#          100       0.90      0.27      0.41     80728
#          101       0.00      0.00      0.00      7042
#          102       0.02      0.72      0.04      1808
#          103       0.00      0.01      0.01       420
#          107       0.00      0.00      0.00       118
#          109       0.00      0.00      0.00        74
#
#     accuracy                           0.25     90190
#    macro avg       0.15      0.17      0.08     90190
# weighted avg       0.80      0.25      0.37     90190
#
# Hamming Loss: 0.9982814059208338
# Hamming Loss: 0.7451047788003105
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - RusBoost
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00     82564
#            1       0.00      0.00      0.00      1050
#            2       0.00      0.00      0.00       251
#            3       0.00      0.00      0.00       144
#            4       0.00      0.00      0.00       100
#            5       0.00      0.00      0.00        37
#            6       0.00      0.00      0.00        16
#            7       0.00      0.00      0.00        32
#            8       0.00      0.00      0.00       149
#            9       0.00      0.07      0.00        15
#           10       0.00      0.00      0.00       278
#           11       0.00      0.44      0.00        16
#           12       0.00      0.00      0.00        33
#           13       0.00      0.00      0.00        20
#           14       0.00      0.00      0.00        33
#           15       0.00      0.00      0.00        30
#           16       0.00      0.00      0.00        57
#           17       0.00      0.00      0.00       100
#           18       0.00      0.00      0.00        84
#           19       0.00      0.00      0.00       687
#           20       0.00      0.00      0.00        26
#           21       0.00      0.00      0.00      1100
#           22       0.03      0.55      0.05      2250
#           23       0.00      0.00      0.00         1
#           24       0.00      0.00      0.00       149
#           25       0.00      0.00      0.00       161
#           26       0.00      0.00      0.00       106
#           27       0.00      0.00      0.00        30
#           28       0.00      0.00      0.00        16
#           29       0.00      0.25      0.00         4
#           30       0.00      0.00      0.00       321
#           77       0.00      0.00      0.00       296
#           99       0.00      0.00      0.00        33
#
#     accuracy                           0.01     90189
#    macro avg       0.00      0.04      0.00     90189
# weighted avg       0.00      0.01      0.00     90189
#
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - RusBoost
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#          100       0.00      0.00      0.00     82402
#          101       0.06      0.29      0.10      5956
#          102       0.00      0.00      0.00      1354
#          103       0.00      0.00      0.00       322
#          107       0.00      0.76      0.00        84
#          109       0.00      0.00      0.00        71
#
#     accuracy                           0.02     90189
#    macro avg       0.01      0.17      0.02     90189
# weighted avg       0.00      0.02      0.01     90189
#
# Hamming Loss: 0.9862289192695339
# Hamming Loss: 0.980296931998359
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - RusBoost
#               precision    recall  f1-score   support
#
#            0       0.90      0.39      0.54     83129
#            1       0.00      0.00      0.00       941
#            2       0.00      0.00      0.00       186
#            3       0.00      0.00      0.00       145
#            4       0.00      0.00      0.00        80
#            5       0.00      0.00      0.00        16
#            6       0.00      0.00      0.00        21
#            7       0.00      0.00      0.00        20
#            8       0.00      0.00      0.00       141
#            9       0.00      0.00      0.00         4
#           10       0.00      0.00      0.00       224
#           11       0.00      0.05      0.00        19
#           12       0.00      0.00      0.00        28
#           13       0.00      0.00      0.00        23
#           14       0.00      0.00      0.00        20
#           15       0.00      0.00      0.00        21
#           16       0.00      0.00      0.00        39
#           17       0.00      0.00      0.00        93
#           18       0.00      0.00      0.00        91
#           19       0.01      0.04      0.01       602
#           20       0.00      0.00      0.00        32
#           21       0.00      0.00      0.00      1044
#           22       0.00      0.00      0.00      2278
#           23       0.00      0.00      0.00         2
#           24       0.00      0.00      0.00       113
#           25       0.00      0.46      0.01       134
#           26       0.00      0.00      0.00        91
#           27       0.00      0.00      0.00        26
#           28       0.00      0.00      0.00        22
#           29       0.00      0.00      0.00         1
#           30       0.00      0.00      0.00       324
#           77       0.00      0.00      0.00       234
#           99       0.00      0.00      0.00        45
#
#     accuracy                           0.36     90189
#    macro avg       0.03      0.03      0.02     90189
# weighted avg       0.83      0.36      0.50     90189
#
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - RusBoost
#               precision    recall  f1-score   support
#
#          100       1.00      0.00      0.00     82994
#          101       0.00      0.00      0.00      5503
#          102       0.00      0.00      0.00      1285
#          103       0.00      1.00      0.01       282
#          107       0.00      0.00      0.00        60
#          109       0.00      0.00      0.00        65
#
#     accuracy                           0.01     90189
#    macro avg       0.17      0.17      0.00     90189
# weighted avg       0.92      0.01      0.00     90189
#
# Hamming Loss: 0.6432824402088947
# Hamming Loss: 0.9945669649292043
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - RusBoost
#               precision    recall  f1-score   support
#
#            0       0.99      0.24      0.38     87184
#            1       0.01      0.19      0.02       385
#            2       0.00      0.00      0.00        75
#            3       0.00      0.00      0.00        66
#            4       0.00      0.00      0.00        45
#            5       0.00      0.00      0.00        11
#            6       0.00      0.00      0.00         4
#            7       0.00      0.10      0.00        10
#            8       0.00      0.00      0.00        61
#            9       0.00      0.00      0.00         2
#           10       0.00      0.00      0.00       101
#           11       0.00      0.00      0.00         8
#           12       0.00      0.00      0.00        10
#           13       0.00      0.00      0.00         5
#           14       0.00      0.00      0.00         8
#           15       0.00      0.00      0.00        10
#           16       0.00      0.00      0.00        30
#           17       0.00      0.00      0.00        40
#           18       0.00      0.00      0.00        36
#           19       0.00      0.00      0.00       270
#           20       0.00      0.00      0.00        17
#           21       0.00      0.00      0.00       419
#           22       0.00      0.00      0.00       939
#           23       0.00      0.00      0.00         0
#           24       0.00      0.00      0.00        63
#           25       0.00      0.00      0.00        61
#           26       0.00      0.00      0.00        33
#           27       0.00      0.00      0.00         9
#           28       0.00      0.00      0.00         6
#           29       0.00      0.00      0.00         2
#           30       0.00      0.00      0.00       111
#           77       0.00      0.00      0.00       142
#           99       0.00      0.00      0.00        26
#
#     accuracy                           0.23     90189
#    macro avg       0.03      0.02      0.01     90189
# weighted avg       0.96      0.23      0.37     90189
#
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - RusBoost
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#          100       0.97      0.16      0.28     87129
#          101       0.00      0.00      0.00      2378
#          102       0.00      0.00      0.00       528
#          103       0.00      0.88      0.00       104
# ...
#           30       0.00      0.00      0.00       324
#           77       0.00      0.00      0.00       234
#           99       0.00      0.00      0.00        45
#
#     accuracy                           0.50     90189
#    macro avg       0.03      0.04      0.02     90189
# weighted avg       0.85      0.50      0.62     90189
#
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - AdaBoost
#               precision    recall  f1-score   support
#
#          100       0.92      1.00      0.96     82994
#          101       0.00      0.00      0.00      5503
#          102       0.00      0.00      0.00      1285
#          103       0.00      0.00      0.00       282
#          107       0.00      0.00      0.00        60
#          109       0.00      0.00      0.00        65
#
#     accuracy                           0.92     90189
#    macro avg       0.15      0.17      0.16     90189
# weighted avg       0.85      0.92      0.88     90189
#
# Hamming Loss: 0.4996174699797093
# Hamming Loss: 0.07977691292729712
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - AdaBoost
#               precision    recall  f1-score   support
#
#            0       0.97      0.55      0.70     87184
#            1       0.00      0.00      0.00       385
#            2       0.00      0.00      0.00        75
#            3       0.00      0.00      0.00        66
#            4       0.00      0.78      0.00        45
#            5       0.00      0.00      0.00        11
#            6       0.00      0.00      0.00         4
#            7       0.00      0.00      0.00        10
#            8       0.00      0.00      0.00        61
#            9       0.00      0.00      0.00         2
#           10       0.00      0.00      0.00       101
#           11       0.00      0.00      0.00         8
#           12       0.00      0.00      0.00        10
#           13       0.00      0.00      0.00         5
#           14       0.00      0.00      0.00         8
#           15       0.00      0.00      0.00        10
#           16       0.00      0.00      0.00        30
#           17       0.00      0.00      0.00        40
#           18       0.00      0.00      0.00        36
#           19       0.00      0.00      0.00       270
#           20       0.00      0.00      0.00        17
#           21       0.00      0.00      0.00       419
#           22       0.00      0.00      0.00       939
#           24       0.00      0.00      0.00        63
#           25       0.00      0.00      0.00        61
#           26       0.00      0.00      0.00        33
#           27       0.00      0.00      0.00         9
#           28       0.00      0.00      0.00         6
#           29       0.00      0.00      0.00         2
#           30       0.00      0.00      0.00       111
#           77       0.00      0.00      0.00       142
#           99       0.00      0.00      0.00        26
#
#     accuracy                           0.54     90189
#    macro avg       0.03      0.04      0.02     90189
# weighted avg       0.93      0.54      0.68     90189
#
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - AdaBoost
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#          100       0.97      1.00      0.98     87129
#          101       0.00      0.00      0.00      2378
#          102       0.00      0.00      0.00       528
#          103       0.00      0.00      0.00       104
#          107       0.00      0.00      0.00        28
#          109       0.00      0.00      0.00        22
#
#     accuracy                           0.97     90189
#    macro avg       0.16      0.17      0.16     90189
# weighted avg       0.93      0.97      0.95     90189
#
# Hamming Loss: 0.46397010721928394
# Hamming Loss: 0.03392874962578585
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - AdaBoost
#               precision    recall  f1-score   support
#
#            0       0.98      0.10      0.18     86105
#            1       0.00      0.00      0.00       519
#            2       0.00      0.00      0.00       117
#            3       0.00      0.88      0.00        81
#            4       0.00      0.00      0.00        48
#            5       0.00      0.00      0.00         6
#            6       0.00      0.00      0.00         9
#            7       0.00      0.00      0.00        10
#            8       0.00      0.00      0.00       102
#            9       0.00      0.00      0.00         3
#           10       0.00      0.00      0.00       121
#           11       0.00      0.00      0.00        10
#           12       0.00      0.00      0.00        18
#           13       0.00      0.00      0.00        16
#           14       0.00      0.00      0.00         9
#           15       0.00      0.00      0.00        11
#           16       0.00      0.00      0.00        36
#           17       0.00      0.00      0.00        68
#           18       0.00      0.00      0.00        47
#           19       0.00      0.05      0.01       355
#           20       0.00      0.00      0.00        33
#           21       0.00      0.00      0.00       632
#           22       0.00      0.00      0.00      1269
#           23       0.00      0.00      0.00         1
#           24       0.00      0.00      0.00        60
#           25       0.00      0.00      0.00        77
#           26       0.00      0.00      0.00        45
#           27       0.00      0.00      0.00        13
#           28       0.00      0.00      0.00         7
#           29       0.00      1.00      0.00         2
#           30       0.00      0.00      0.00       156
#           77       0.00      0.00      0.00       185
#           99       0.00      0.00      0.00        18
#
#     accuracy                           0.09     90189
#    macro avg       0.03      0.06      0.01     90189
# weighted avg       0.94      0.09      0.17     90189
#
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - AdaBoost
#               precision    recall  f1-score   support
#
#          100       0.95      1.00      0.98     86042
#          101       0.00      0.00      0.00      3175
#          102       0.00      0.00      0.00       768
#          103       0.00      0.00      0.00       150
#          107       0.00      0.00      0.00        35
#          109       0.00      0.00      0.00        19
#
#     accuracy                           0.95     90189
#    macro avg       0.16      0.17      0.16     90189
# weighted avg       0.91      0.95      0.93     90189
#
# Hamming Loss: 0.9055871558615796
# Hamming Loss: 0.04598121722161239
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - AdaBoost AGGREGATE
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.91      0.69      0.78    246634
#            1       0.00      0.00      0.00      3264
#            2       0.00      0.00      0.00       718
#            3       0.00      0.00      0.00       456
#            4       0.00      0.00      0.00       302
#            5       0.00      0.00      0.00        82
#            6       0.00      0.00      0.00        60
#            7       0.00      0.00      0.00        90
#            8       0.00      0.00      0.00       492
#            9       0.00      0.00      0.00        23
#           10       0.00      0.00      0.00       809
#           11       0.00      0.00      0.00        58
#           12       0.00      0.00      0.00        87
#           13       0.00      0.00      0.00        66
#           14       0.00      0.00      0.00        85
#           15       0.00      0.00      0.00        85
#           16       0.00      0.00      0.00       162
#           17       0.00      0.00      0.00       300
#           18       0.00      0.00      0.00       279
#           19       0.02      0.52      0.03      2025
#           20       0.00      0.00      0.00        94
#           21       0.00      0.00      0.00      3450
#           22       0.00      0.00      0.00      7459
#           23       0.00      0.00      0.00         3
#           24       0.00      0.00      0.00       462
#           25       0.00      0.00      0.00       457
#           26       0.00      0.00      0.00       284
#           27       0.00      0.00      0.00        96
#           28       0.00      0.00      0.00        64
#           29       0.00      0.00      0.00         8
#           30       0.00      0.00      0.00      1072
#           77       0.00      0.00      0.00       923
#           99       0.00      0.00      0.00       119
#          100       0.90      1.00      0.95    163130
#          101       0.00      0.00      0.00     12998
#          102       0.00      0.00      0.00      3162
#          103       0.00      0.00      0.00       742
#          107       0.00      0.00      0.00       202
#          109       0.00      0.00      0.00       145
#
#     accuracy                           0.74    450947
#    macro avg       0.05      0.06      0.05    450947
# weighted avg       0.83      0.74      0.77    450947
#
# Hamming Loss: 0.09245648621515815
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
folder = "C:/Users/mdjaw/OneDrive/Documents/Markian Training/Research_USQ/USCenterDiseaseControlPrevention/LLCP2020XPT" 
os.chdir(folder)

BRFSS_Grounded = pd.read_csv("LLCP2021XPT_ALCOHOL.csv")

print(BRFSS_Grounded.shape)

BRFSS_Grounded_X = BRFSS_Grounded.drop(['CNCRTYP1', 'CNCRDIFF'], axis = 1)

print(BRFSS_Grounded_X.shape)
# Out:
# (450946, 30)
# (450946, 28)

# %%
X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  MNB = model = MultinomialNB()
  multi_target_MNB = MultiOutputClassifier(MNB, n_jobs=2)
  y_pred = multi_target_MNB.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - MultinomialNB")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - MultinomialNB")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - MultinomialNB AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))








X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  RB = RUSBoostClassifier(random_state=0)
  multi_target_RB = MultiOutputClassifier(RB, n_jobs=2)
  y_pred = multi_target_RB.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - RusBoost")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - RusBoost")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - RusBoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))


X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  AB = AdaBoostClassifier(n_estimators=200,learning_rate=1)
  multi_target_AB = MultiOutputClassifier(AB, n_jobs=2)
  y_pred = multi_target_AB.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - AdaBoost")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - AdaBoost")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - AdaBoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))
# Out:
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.88      0.34      0.49     80941
#            1       0.00      0.00      0.00      1273
#            2       0.00      0.00      0.00       281
#            3       0.00      0.00      0.00       167
#            4       0.00      0.00      0.00       122
#            5       0.00      0.00      0.00        29
#            6       0.00      0.00      0.00        23
#            7       0.00      0.00      0.00        38
#            8       0.00      0.00      0.00       202
#            9       0.00      0.25      0.00         4
#           10       0.00      0.00      0.00       307
#           11       0.00      0.00      0.00        23
#           12       0.00      0.00      0.00        26
#           13       0.00      0.00      0.00        23
#           14       0.00      0.00      0.00        32
#           15       0.00      0.00      0.00        34
#           16       0.00      0.00      0.00        66
#           17       0.00      0.00      0.00       107
#           18       0.00      0.00      0.00       104
#           19       0.00      0.00      0.00       736
#           20       0.00      0.00      0.00        36
#           21       0.00      0.00      0.00      1306
#           22       0.00      0.00      0.00      2931
#           24       0.00      0.00      0.00       200
#           25       0.00      0.00      0.00       162
#           26       0.00      0.00      0.00        87
#           27       0.00      0.00      0.00        40
#           28       0.00      0.00      0.00        26
#           29       0.00      0.00      0.00         3
#           30       0.00      0.00      0.00       427
#           77       0.00      0.00      0.00       393
#           99       0.00      0.00      0.00        41
#
#     accuracy                           0.31     90190
#    macro avg       0.03      0.02      0.02     90190
# weighted avg       0.79      0.31      0.44     90190
#
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - MultinomialNB
#               precision    recall  f1-score   support
#
#          100       0.87      0.34      0.49     80728
#          101       0.00      0.00      0.00      7042
#          102       0.00      0.00      0.00      1808
#          103       0.00      0.00      0.00       420
#          107       0.00      0.00      0.00       118
#          109       0.00      0.57      0.00        74
#
#     accuracy                           0.31     90190
#    macro avg       0.15      0.15      0.08     90190
# weighted avg       0.78      0.31      0.44     90190
#
# Hamming Loss: 0.6914735558265883
# Hamming Loss: 0.6918727131611043
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.90      0.34      0.49     82564
#            1       0.00      0.00      0.00      1050
#            2       0.00      0.00      0.00       251
#            3       0.00      0.00      0.00       144
#            4       0.00      0.00      0.00       100
#            5       0.00      0.00      0.00        37
#            6       0.00      0.00      0.00        16
#            7       0.00      0.00      0.00        32
#            8       0.00      0.00      0.00       149
#            9       0.00      0.00      0.00        15
#           10       0.00      0.00      0.00       278
#           11       0.00      0.00      0.00        16
#           12       0.00      0.00      0.00        33
#           13       0.00      0.00      0.00        20
#           14       0.00      0.00      0.00        33
#           15       0.00      0.00      0.00        30
#           16       0.00      0.00      0.00        57
#           17       0.00      0.00      0.00       100
#           18       0.00      0.00      0.00        84
#           19       0.00      0.00      0.00       687
#           20       0.00      0.00      0.00        26
#           21       0.00      0.00      0.00      1100
#           22       0.00      0.00      0.00      2250
#           23       0.00      0.00      0.00         1
#           24       0.00      0.00      0.00       149
#           25       0.00      0.00      0.00       161
#           26       0.00      0.00      0.00       106
#           27       0.00      0.53      0.00        30
#           28       0.00      0.00      0.00        16
#           29       0.00      0.00      0.00         4
#           30       0.00      0.00      0.00       321
#           77       0.00      0.00      0.00       296
#           99       0.00      0.00      0.00        33
#
#     accuracy                           0.31     90189
#    macro avg       0.03      0.03      0.01     90189
# weighted avg       0.83      0.31      0.45     90189
#
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - MultinomialNB
#               precision    recall  f1-score   support
#
#          100       0.90      0.34      0.49     82402
#          101       0.00      0.00      0.00      5956
#          102       0.00      0.00      0.00      1354
#          103       0.00      0.00      0.00       322
#          107       0.00      0.67      0.00        84
#          109       0.00      0.00      0.00        71
#
#     accuracy                           0.31     90189
#    macro avg       0.15      0.17      0.08     90189
# weighted avg       0.82      0.31      0.45     90189
#
# Hamming Loss: 0.6922130193260819
# Hamming Loss: 0.6923349854195079
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.92      0.37      0.53     83129
#            1       0.02      0.07      0.03       941
#            2       0.00      0.02      0.00       186
#            3       0.00      0.00      0.00       145
#            4       0.00      0.00      0.00        80
#            5       0.00      0.00      0.00        16
#            6       0.00      0.00      0.00        21
#            7       0.00      0.00      0.00        20
#            8       0.00      0.00      0.00       141
#            9       0.00      0.00      0.00         4
#           10       0.00      0.00      0.00       224
#           11       0.00      0.00      0.00        19
#           12       0.00      0.82      0.00        28
#           13       0.00      0.00      0.00        23
#           14       0.00      0.00      0.00        20
#           15       0.00      0.00      0.00        21
#           16       0.00      0.00      0.00        39
#           17       0.00      0.00      0.00        93
#           18       0.00      0.00      0.00        91
#           19       0.00      0.00      0.00       602
#           20       0.00      0.00      0.00        32
#           21       0.00      0.00      0.00      1044
#           22       0.00      0.00      0.00      2278
#           23       0.00      0.00      0.00         2
#           24       0.00      0.00      0.00       113
#           25       0.00      0.00      0.00       134
#           26       0.00      0.00      0.00        91
#           27       0.00      0.00      0.00        26
#           28       0.00      0.00      0.00        22
#           29       0.00      0.00      0.00         1
#           30       0.00      0.00      0.00       324
#           77       0.00      0.00      0.00       234
#           99       0.00      0.00      0.00        45
#
#     accuracy                           0.34     90189
#    macro avg       0.03      0.04      0.02     90189
# weighted avg       0.85      0.34      0.49     90189
#
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - MultinomialNB
#               precision    recall  f1-score   support
#
#          100       0.92      0.38      0.53     82994
#          101       0.05      0.04      0.04      5503
#          102       0.00      0.00      0.00      1285
#          103       0.00      0.00      0.00       282
#          107       0.00      0.60      0.00        60
#          109       0.00      0.00      0.00        65
#
#     accuracy                           0.35     90189
#    macro avg       0.16      0.17      0.10     90189
# weighted avg       0.85      0.35      0.49     90189
#
# Hamming Loss: 0.6562551974187539
# Hamming Loss: 0.6504673518943552
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.97      0.59      0.74     87184
#            1       0.00      0.00      0.00       385
#            2       0.00      0.00      0.00        75
#            3       0.00      0.00      0.00        66
#            4       0.00      0.00      0.00        45
#            5       0.00      0.00      0.00        11
#            6       0.00      0.00      0.00         4
#            7       0.00      0.00      0.00        10
#            8       0.00      0.00      0.00        61
#            9       0.00      0.00      0.00         2
#           10       0.00      0.00      0.00       101
#           11       0.00      0.00      0.00         8
#           12       0.00      0.00      0.00        10
#           13       0.00      0.00      0.00         5
#           14       0.00      0.00      0.00         8
#           15       0.00      0.00      0.00        10
#           16       0.00      0.00      0.00        30
#           17       0.00      0.00      0.00        40
#           18       0.00      0.00      0.00        36
#           19       0.00      0.00      0.00       270
#           20       0.00      0.06      0.00        17
#           21       0.00      0.00      0.00       419
#           22       0.00      0.00      0.00       939
#           23       0.00      0.00      0.00         0
#           24       0.00      0.00      0.00        63
#           25       0.00      0.00      0.00        61
#           26       0.00      0.00      0.00        33
#           27       0.00      0.00      0.00         9
#           28       0.00      0.00      0.00         6
#           29       0.00      0.00      0.00         2
#           30       0.00      0.00      0.00       111
#           77       0.00      0.00      0.00       142
#           99       0.00      0.00      0.00        26
#
#     accuracy                           0.57     90189
#    macro avg       0.03      0.02      0.02     90189
# weighted avg       0.94      0.57      0.71     90189
#
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - MultinomialNB
#               precision    recall  f1-score   support
#
#          100       0.97      0.89      0.93     87129
#          101       0.00      0.00      0.00      2378
#          102       0.00      0.00      0.00       528
#          103       0.00      0.00      0.00       104
#          107       0.00      0.14      0.00        28
#          109       0.00      0.00      0.00        22
#
#     accuracy                           0.86     90189
#    macro avg       0.16      0.17      0.15     90189
# weighted avg       0.93      0.86      0.89     90189
#
# Hamming Loss: 0.4263823747907173
# Hamming Loss: 0.14155828316091762
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.97      0.69      0.80     86105
#            1       0.00      0.00      0.00       519
#            2       0.00      0.09      0.00       117
#            3       0.00      0.00      0.00        81
#            4       0.00      0.00      0.00        48
#            5       0.00      0.00      0.00         6
#            6       0.00      0.00      0.00         9
#            7       0.00      0.00      0.00        10
#            8       0.00      0.00      0.00       102
#            9       0.00      0.00      0.00         3
#           10       0.00      0.00      0.00       121
#           11       0.00      0.00      0.00        10
#           12       0.00      0.61      0.00        18
#           13       0.00      0.00      0.00        16
#           14       0.00      0.00      0.00         9
#           15       0.00      0.00      0.00        11
#           16       0.00      0.00      0.00        36
#           17       0.00      0.00      0.00        68
#           18       0.00      0.00      0.00        47
#           19       0.00      0.00      0.00       355
#           20       0.00      0.00      0.00        33
#           21       0.00      0.00      0.00       632
#           22       0.00      0.00      0.00      1269
#           23       0.00      0.00      0.00         1
#           24       0.00      0.00      0.00        60
#           25       0.00      0.00      0.00        77
#           26       0.00      0.00      0.00        45
#           27       0.00      0.00      0.00        13
#           28       0.00      0.00      0.00         7
#           29       0.00      0.00      0.00         2
#           30       0.00      0.00      0.00       156
#           77       0.00      0.00      0.00       185
#           99       0.00      0.00      0.00        18
#
#     accuracy                           0.65     90189
#    macro avg       0.03      0.04      0.02     90189
# weighted avg       0.92      0.65      0.77     90189
#
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - MultinomialNB
#               precision    recall  f1-score   support
#
#          100       0.97      0.69      0.80     86042
#          101       0.00      0.00      0.00      3175
#          102       0.00      0.00      0.00       768
#          103       0.00      0.00      0.00       150
#          107       0.00      0.51      0.00        35
#          109       0.00      0.00      0.00        19
#
#     accuracy                           0.65     90189
#    macro avg       0.16      0.20      0.13     90189
# weighted avg       0.92      0.65      0.76     90189
#
# Hamming Loss: 0.3451751322223331
# Hamming Loss: 0.3456297331160119
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - MultinomialNB AGGREGATE
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.90      0.35      0.50    246634
#            1       0.02      0.02      0.02      3264
#            2       0.00      0.00      0.00       718
#            3       0.00      0.00      0.00       456
#            4       0.00      0.00      0.00       302
#            5       0.00      0.00      0.00        82
#            6       0.00      0.00      0.00        60
#            7       0.00      0.00      0.00        90
#            8       0.00      0.00      0.00       492
#            9       0.00      0.04      0.00        23
#           10       0.00      0.00      0.00       809
#           11       0.00      0.00      0.00        58
#           12       0.00      0.26      0.00        87
#           13       0.00      0.00      0.00        66
#           14       0.00      0.00      0.00        85
#           15       0.00      0.00      0.00        85
#           16       0.00      0.00      0.00       162
#           17       0.00      0.00      0.00       300
#           18       0.00      0.00      0.00       279
#           19       0.00      0.00      0.00      2025
#           20       0.00      0.00      0.00        94
#           21       0.00      0.00      0.00      3450
#           22       0.00      0.00      0.00      7459
#           23       0.00      0.00      0.00         3
#           24       0.00      0.00      0.00       462
#           25       0.00      0.00      0.00       457
#           26       0.00      0.00      0.00       284
#           27       0.00      0.17      0.00        96
#           28       0.00      0.00      0.00        64
#           29       0.00      0.00      0.00         8
#           30       0.00      0.00      0.00      1072
#           77       0.00      0.00      0.00       923
#           99       0.00      0.00      0.00       119
#          100       0.89      0.34      0.49    163130
#          101       0.00      0.00      0.00     12998
#          102       0.00      0.00      0.00      3162
#          103       0.00      0.00      0.00       742
#          107       0.00      0.28      0.00       202
#          109       0.00      0.29      0.00       145
#
#     accuracy                           0.32    450947
#    macro avg       0.05      0.05      0.03    450947
# weighted avg       0.81      0.32      0.45    450947
#
# Hamming Loss: 0.6837765498111159
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - RusBoost
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00     80941
#            1       0.00      0.00      0.00      1273
#            2       0.00      0.00      0.00       281
#            3       0.00      0.00      0.00       167
#            4       0.00      0.00      0.00       122
#            5       0.00      0.00      0.00        29
#            6       0.00      0.00      0.00        23
#            7       0.00      0.00      0.00        38
#            8       0.00      0.00      0.00       202
#            9       0.00      0.00      0.00         4
#           10       0.00      0.00      0.00       307
#           11       0.00      0.00      0.00        23
#           12       0.00      0.00      0.00        26
#           13       0.00      0.00      0.00        23
#           14       0.00      0.00      0.00        32
#           15       0.00      0.56      0.00        34
#           16       0.00      0.00      0.00        66
#           17       0.00      0.00      0.00       107
#           18       0.00      0.00      0.00       104
#           19       0.00      0.00      0.00       736
#           20       0.00      0.00      0.00        36
#           21       0.00      0.00      0.00      1306
#           22       0.00      0.00      0.00      2931
#           24       0.00      0.00      0.00       200
#           25       0.00      0.00      0.00       162
#           26       0.00      0.11      0.00        87
#           27       0.00      0.00      0.00        40
#           28       0.00      0.31      0.00        26
#           29       0.00      0.00      0.00         3
#           30       0.00      0.00      0.00       427
#           77       0.00      0.01      0.01       393
#           99       0.00      0.00      0.00        41
#
#     accuracy                           0.00     90190
#    macro avg       0.00      0.03      0.00     90190
# weighted avg       0.00      0.00      0.00     90190
#
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - RusBoost
#               precision    recall  f1-score   support
#
#          100       0.90      0.90      0.90     80728
#          101       0.08      0.11      0.10      7042
#          102       0.00      0.00      0.00      1808
#          103       0.00      0.00      0.00       420
#          107       0.00      0.00      0.00       118
#          109       0.00      0.00      0.00        74
#
#     accuracy                           0.81     90190
#    macro avg       0.16      0.17      0.17     90190
# weighted avg       0.81      0.81      0.81     90190
#
# Hamming Loss: 0.9995564918505377
# Hamming Loss: 0.18966626011752966
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - RusBoost
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00     82564
#            1       0.02      0.62      0.04      1050
#            2       0.00      0.00      0.00       251
#            3       0.00      0.16      0.00       144
#            4       0.00      0.00      0.00       100
#            5       0.00      0.00      0.00        37
#            6       0.00      0.00      0.00        16
#            7       0.00      0.00      0.00        32
#            8       0.00      0.00      0.00       149
#            9       0.00      0.00      0.00        15
#           10       0.00      0.00      0.00       278
#           11       0.00      0.00      0.00        16
#           12       0.00      0.00      0.00        33
#           13       0.00      0.00      0.00        20
#           14       0.00      0.00      0.00        33
#           15       0.00      0.17      0.00        30
#           16       0.00      0.00      0.00        57
#           17       0.00      0.00      0.00       100
#           18       0.00      0.00      0.00        84
#           19       0.00      0.00      0.00       687
#           20       0.00      0.00      0.00        26
#           21       0.00      0.00      0.00      1100
#           22       0.04      0.09      0.05      2250
#           23       0.00      0.00      0.00         1
#           24       0.00      0.00      0.00       149
#           25       0.00      0.00      0.00       161
#           26       0.00      0.31      0.00       106
#           27       0.00      0.00      0.00        30
#           28       0.00      0.00      0.00        16
#           29       0.00      0.00      0.00         4
#           30       0.00      0.00      0.00       321
#           77       0.00      0.00      0.00       296
#           99       0.00      0.00      0.00        33
#
#     accuracy                           0.01     90189
#    macro avg       0.00      0.04      0.00     90189
# weighted avg       0.00      0.01      0.00     90189
#
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - RusBoost
#               precision    recall  f1-score   support
#
#          100       0.00      0.00      0.00     82402
#          101       0.00      0.00      0.00      5956
#          102       0.00      0.00      0.00      1354
#          103       0.00      0.00      0.00       322
#          107       0.00      1.00      0.00        84
#          109       0.00      0.00      0.00        71
#
#     accuracy                           0.00     90189
#    macro avg       0.00      0.17      0.00     90189
# weighted avg       0.00      0.00      0.00     90189
#
# Hamming Loss: 0.9899211655523401
# Hamming Loss: 0.9990686225592922
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - RusBoost
#               precision    recall  f1-score   support
#
#            0       1.00      0.01      0.01     83129
#            1       0.00      0.00      0.00       941
#            2       0.00      0.00      0.00       186
#            3       0.00      0.86      0.01       145
#            4       0.00      0.00      0.00        80
#            5       0.00      0.00      0.00        16
#            6       0.00      0.00      0.00        21
#            7       0.00      0.00      0.00        20
#            8       0.00      0.01      0.00       141
#            9       0.00      0.00      0.00         4
#           10       0.00      0.00      0.00       224
#           11       0.00      0.00      0.00        19
#           12       0.00      0.00      0.00        28
#           13       0.00      0.00      0.00        23
#           14       0.00      0.00      0.00        20
#           15       0.00      0.00      0.00        21
#           16       0.00      0.05      0.00        39
#           17       0.00      0.00      0.00        93
#           18       0.00      0.00      0.00        91
#           19       0.00      0.00      0.00       602
#           20       0.00      0.00      0.00        32
#           21       0.00      0.00      0.00      1044
#           22       0.00      0.00      0.00      2278
#           23       0.00      0.00      0.00         2
#           24       0.00      0.00      0.00       113
#           25       0.00      0.00      0.00       134
#           26       0.00      0.00      0.00        91
#           27       0.00      0.00      0.00        26
#           28       0.00      0.00      0.00        22
#           29       0.00      0.00      0.00         1
#           30       0.00      0.26      0.01       324
#           77       0.00      0.00      0.00       234
#           99       0.00      0.04      0.00        45
#
#     accuracy                           0.01     90189
#    macro avg       0.03      0.04      0.00     90189
# weighted avg       0.92      0.01      0.01     90189
#
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - RusBoost
#               precision    recall  f1-score   support
#
#          100       1.00      0.00      0.00     82994
#          101       0.00      0.00      0.00      5503
#          102       0.01      1.00      0.03      1285
#          103       0.00      0.00      0.00       282
#          107       0.00      0.00      0.00        60
#          109       0.00      0.00      0.00        65
#
#     accuracy                           0.02     90189
#    macro avg       0.17      0.17      0.01     90189
# weighted avg       0.92      0.02      0.01     90189
#
# Hamming Loss: 0.9907527525529721
# Hamming Loss: 0.9834458747740855
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - RusBoost
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00     87184
#            1       0.00      0.00      0.00       385
#            2       0.00      0.00      0.00        75
#            3       0.00      0.00      0.00        66
#            4       0.00      0.22      0.00        45
#            5       0.00      0.00      0.00        11
#            6       0.00      0.00      0.00         4
#            7       0.00      0.10      0.00        10
#            8       0.00      0.00      0.00        61
#            9       0.00      0.00      0.00         2
#           10       0.00      0.00      0.00       101
#           11       0.00      0.00      0.00         8
#           12       0.00      0.00      0.00        10
#           13       0.00      0.00      0.00         5
#           14       0.00      0.00      0.00         8
#           15       0.00      0.00      0.00        10
#           16       0.00      0.00      0.00        30
#           17       0.00      0.00      0.00        40
#           18       0.00      0.00      0.00        36
#           19       0.00      0.00      0.00       270
#           20       0.00      0.00      0.00        17
#           21       0.00      0.00      0.00       419
#           22       0.00      0.00      0.00       939
#           23       0.00      0.00      0.00         0
#           24       0.00      0.00      0.00        63
#           25       0.00      0.00      0.00        61
#           26       0.00      0.00      0.00        33
#           27       0.00      0.00      0.00         9
#           28       0.00      0.00      0.00         6
#           29       0.00      0.00      0.00         2
#           30       0.00      0.00      0.00       111
#           77       0.00      0.00      0.00       142
#           99       0.00      0.00      0.00        26
#
#     accuracy                           0.00     90189
#    macro avg       0.00      0.01      0.00     90189
# weighted avg       0.00      0.00      0.00     90189
#
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - RusBoost
#               precision    recall  f1-score   support
#
#          100       0.96      0.35      0.51     87129
#          101       0.02      0.55      0.04      2378
#          102       0.00      0.00      0.00       528
#          103       0.00      0.00      0.00       104
#          107       0.00      0.00      0.00        28
#          109       0.00      0.00      0.00        22
#
#     accuracy                           0.35     90189
#    macro avg       0.16      0.15      0.09     90189
# weighted avg       0.93      0.35      0.50     90189
#
# Hamming Loss: 0.9998780339065739
# Hamming Loss: 0.6479060639324086
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...
#           30       0.00      0.00      0.00       324
#           77       0.00      0.00      0.00       234
#           99       0.00      0.00      0.00        45
#
#     accuracy                           0.50     90189
#    macro avg       0.03      0.04      0.02     90189
# weighted avg       0.85      0.50      0.62     90189
#
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - AdaBoost
#               precision    recall  f1-score   support
#
#          100       0.92      1.00      0.96     82994
#          101       0.00      0.00      0.00      5503
#          102       0.00      0.00      0.00      1285
#          103       0.00      0.00      0.00       282
#          107       0.00      0.00      0.00        60
#          109       0.00      0.00      0.00        65
#
#     accuracy                           0.92     90189
#    macro avg       0.15      0.17      0.16     90189
# weighted avg       0.85      0.92      0.88     90189
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Hamming Loss: 0.4996174699797093
# Hamming Loss: 0.07977691292729712
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - AdaBoost
#               precision    recall  f1-score   support
#
#            0       0.97      0.55      0.70     87184
#            1       0.00      0.00      0.00       385
#            2       0.00      0.00      0.00        75
#            3       0.00      0.00      0.00        66
#            4       0.00      0.78      0.00        45
#            5       0.00      0.00      0.00        11
#            6       0.00      0.00      0.00         4
#            7       0.00      0.00      0.00        10
#            8       0.00      0.00      0.00        61
#            9       0.00      0.00      0.00         2
#           10       0.00      0.00      0.00       101
#           11       0.00      0.00      0.00         8
#           12       0.00      0.00      0.00        10
#           13       0.00      0.00      0.00         5
#           14       0.00      0.00      0.00         8
#           15       0.00      0.00      0.00        10
#           16       0.00      0.00      0.00        30
#           17       0.00      0.00      0.00        40
#           18       0.00      0.00      0.00        36
#           19       0.00      0.00      0.00       270
#           20       0.00      0.00      0.00        17
#           21       0.00      0.00      0.00       419
#           22       0.00      0.00      0.00       939
#           24       0.00      0.00      0.00        63
#           25       0.00      0.00      0.00        61
#           26       0.00      0.00      0.00        33
#           27       0.00      0.00      0.00         9
#           28       0.00      0.00      0.00         6
#           29       0.00      0.00      0.00         2
#           30       0.00      0.00      0.00       111
#           77       0.00      0.00      0.00       142
#           99       0.00      0.00      0.00        26
#
#     accuracy                           0.54     90189
#    macro avg       0.03      0.04      0.02     90189
# weighted avg       0.93      0.54      0.68     90189
#
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - AdaBoost
#               precision    recall  f1-score   support
#
#          100       0.97      1.00      0.98     87129
#          101       0.00      0.00      0.00      2378
#          102       0.00      0.00      0.00       528
#          103       0.00      0.00      0.00       104
#          107       0.00      0.00      0.00        28
#          109       0.00      0.00      0.00        22
#
#     accuracy                           0.97     90189
#    macro avg       0.16      0.17      0.16     90189
# weighted avg       0.93      0.97      0.95     90189
#
# Hamming Loss: 0.46397010721928394
# Hamming Loss: 0.03392874962578585
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - AdaBoost
#               precision    recall  f1-score   support
#
#            0       0.98      0.10      0.18     86105
#            1       0.00      0.00      0.00       519
#            2       0.00      0.00      0.00       117
#            3       0.00      0.88      0.00        81
#            4       0.00      0.00      0.00        48
#            5       0.00      0.00      0.00         6
#            6       0.00      0.00      0.00         9
#            7       0.00      0.00      0.00        10
#            8       0.00      0.00      0.00       102
#            9       0.00      0.00      0.00         3
#           10       0.00      0.00      0.00       121
#           11       0.00      0.00      0.00        10
#           12       0.00      0.00      0.00        18
#           13       0.00      0.00      0.00        16
#           14       0.00      0.00      0.00         9
#           15       0.00      0.00      0.00        11
#           16       0.00      0.00      0.00        36
#           17       0.00      0.00      0.00        68
#           18       0.00      0.00      0.00        47
#           19       0.00      0.05      0.01       355
#           20       0.00      0.00      0.00        33
#           21       0.00      0.00      0.00       632
#           22       0.00      0.00      0.00      1269
#           23       0.00      0.00      0.00         1
#           24       0.00      0.00      0.00        60
#           25       0.00      0.00      0.00        77
#           26       0.00      0.00      0.00        45
#           27       0.00      0.00      0.00        13
#           28       0.00      0.00      0.00         7
#           29       0.00      1.00      0.00         2
#           30       0.00      0.00      0.00       156
#           77       0.00      0.00      0.00       185
#           99       0.00      0.00      0.00        18
#
#     accuracy                           0.09     90189
#    macro avg       0.03      0.06      0.01     90189
# weighted avg       0.94      0.09      0.17     90189
#
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - AdaBoost
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#          100       0.95      1.00      0.98     86042
#          101       0.00      0.00      0.00      3175
#          102       0.00      0.00      0.00       768
#          103       0.00      0.00      0.00       150
#          107       0.00      0.00      0.00        35
#          109       0.00      0.00      0.00        19
#
#     accuracy                           0.95     90189
#    macro avg       0.16      0.17      0.16     90189
# weighted avg       0.91      0.95      0.93     90189
#
# Hamming Loss: 0.9055871558615796
# Hamming Loss: 0.04598121722161239
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - AdaBoost AGGREGATE
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.91      0.84      0.88    246634
#            1       0.00      0.00      0.00      3264
#            2       0.00      0.00      0.00       718
#            3       0.00      0.00      0.00       456
#            4       0.00      0.00      0.00       302
#            5       0.00      0.00      0.00        82
#            6       0.00      0.00      0.00        60
#            7       0.00      0.00      0.00        90
#            8       0.00      0.00      0.00       492
#            9       0.00      0.00      0.00        23
#           10       0.00      0.00      0.00       809
#           11       0.00      0.00      0.00        58
#           12       0.00      0.00      0.00        87
#           13       0.00      0.00      0.00        66
#           14       0.00      0.00      0.00        85
#           15       0.00      0.00      0.00        85
#           16       0.00      0.00      0.00       162
#           17       0.00      0.00      0.00       300
#           18       0.00      0.00      0.00       279
#           19       0.02      0.27      0.03      2025
#           20       0.00      0.00      0.00        94
#           21       0.00      0.00      0.00      3450
#           22       0.00      0.00      0.00      7459
#           23       0.00      0.00      0.00         3
#           24       0.00      0.00      0.00       462
#           25       0.00      0.00      0.00       457
#           26       0.00      0.00      0.00       284
#           27       0.00      0.00      0.00        96
#           28       0.00      0.00      0.00        64
#           29       0.00      0.00      0.00         8
#           30       0.00      0.00      0.00      1072
#           77       0.00      0.00      0.00       923
#           99       0.00      0.00      0.00       119
#          100       0.90      1.00      0.95    163130
#          101       0.00      0.00      0.00     12998
#          102       0.00      0.00      0.00      3162
#          103       0.00      0.00      0.00       742
#          107       0.00      0.00      0.00       202
#          109       0.00      0.00      0.00       145
#
#     accuracy                           0.82    450947
#    macro avg       0.05      0.05      0.05    450947
# weighted avg       0.82      0.82      0.82    450947
#
# Hamming Loss: 0.09245648621515815
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
folder = "C:/Users/mdjaw/OneDrive/Documents/Markian Training/Research_USQ/USCenterDiseaseControlPrevention/LLCP2020XPT" 
os.chdir(folder)

BRFSS_Grounded = pd.read_csv("LLCP2021XPT_DIABETES.csv")

print(BRFSS_Grounded.shape)

BRFSS_Grounded_X = BRFSS_Grounded.drop(['CNCRTYP1', 'CNCRDIFF'], axis = 1)

print(BRFSS_Grounded_X.shape)
# Out:
# (450946, 56)
# (450946, 54)

# %%
X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  MNB = model = MultinomialNB()
  multi_target_MNB = MultiOutputClassifier(MNB, n_jobs=2)
  y_pred = multi_target_MNB.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Diabetes + Weight Variables - MultinomialNB")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Diabetes + Weight Variables - MultinomialNB")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Diabetes + Weight Variables - MultinomialNB AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))








X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  RB = RUSBoostClassifier(random_state=0)
  multi_target_RB = MultiOutputClassifier(RB, n_jobs=2)
  y_pred = multi_target_RB.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Diabetes + Weight Variables - RusBoost")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Diabetes + Weight Variables - RusBoost")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Diabetes + Weight Variables - RusBoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))


X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  AB = AdaBoostClassifier(n_estimators=200,learning_rate=1)
  multi_target_AB = MultiOutputClassifier(AB, n_jobs=2)
  y_pred = multi_target_AB.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Diabetes + Weight Variables - AdaBoost")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Diabetes + Weight Variables - AdaBoost")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Diabetes + Weight Variables - AdaBoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))
# Out:
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Diabetes + Weight Variables - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.91      0.52      0.66     80941
#            1       0.00      0.00      0.00      1273
#            2       0.00      0.00      0.00       281
#            3       0.00      0.00      0.00       167
#            4       0.00      0.00      0.00       122
#            5       0.00      0.00      0.00        29
#            6       0.00      0.00      0.00        23
#            7       0.00      0.00      0.00        38
#            8       0.00      0.00      0.00       202
#            9       0.00      0.25      0.00         4
#           10       0.00      0.00      0.00       307
#           11       0.00      0.00      0.00        23
#           12       0.00      0.00      0.00        26
#           13       0.00      0.00      0.00        23
#           14       0.00      0.00      0.00        32
#           15       0.00      0.00      0.00        34
#           16       0.00      0.00      0.00        66
#           17       0.00      0.00      0.00       107
#           18       0.00      0.00      0.00       104
#           19       0.00      0.00      0.00       736
#           20       0.00      0.00      0.00        36
#           21       0.00      0.00      0.00      1306
#           22       0.04      0.44      0.07      2931
#           24       0.00      0.00      0.00       200
#           25       0.00      0.00      0.00       162
#           26       0.00      0.00      0.00        87
#           27       0.00      0.00      0.00        40
#           28       0.00      0.00      0.00        26
#           29       0.00      0.00      0.00         3
#           30       0.00      0.00      0.00       427
#           77       0.00      0.00      0.00       393
#           99       0.00      0.00      0.00        41
#
#     accuracy                           0.48     90190
#    macro avg       0.03      0.04      0.02     90190
# weighted avg       0.82      0.48      0.59     90190
#
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Diabetes + Weight Variables - MultinomialNB
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#          100       0.91      0.52      0.66     80728
#          101       0.08      0.38      0.14      7042
#          102       0.00      0.00      0.00      1808
#          103       0.01      0.19      0.01       420
#          107       0.00      0.00      0.00       118
#          109       0.00      0.00      0.00        74
#
#     accuracy                           0.49     90190
#    macro avg       0.17      0.18      0.13     90190
# weighted avg       0.82      0.49      0.60     90190
#
# Hamming Loss: 0.5229293713271982
# Hamming Loss: 0.5076394278744872
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Diabetes + Weight Variables - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.92      0.86      0.89     82564
#            1       0.00      0.00      0.00      1050
#            2       0.00      0.00      0.00       251
#            3       0.00      0.00      0.00       144
#            4       0.00      0.00      0.00       100
#            5       0.00      0.00      0.00        37
#            6       0.00      0.00      0.00        16
#            7       0.00      0.00      0.00        32
#            8       0.00      0.00      0.00       149
#            9       0.00      0.00      0.00        15
#           10       0.00      0.00      0.00       278
#           11       0.00      0.00      0.00        16
#           12       0.00      0.33      0.00        33
#           13       0.00      0.00      0.00        20
#           14       0.00      0.00      0.00        33
#           15       0.00      0.00      0.00        30
#           16       0.00      0.00      0.00        57
#           17       0.00      0.00      0.00       100
#           18       0.00      0.00      0.00        84
#           19       0.00      0.00      0.00       687
#           20       0.00      0.00      0.00        26
#           21       0.00      0.00      0.00      1100
#           22       0.00      0.00      0.00      2250
#           23       0.00      0.00      0.00         1
#           24       0.00      0.00      0.00       149
#           25       0.00      0.00      0.00       161
#           26       0.00      0.00      0.00       106
#           27       0.00      0.00      0.00        30
#           28       0.00      0.00      0.00        16
#           29       0.00      0.00      0.00         4
#           30       0.00      0.00      0.00       321
#           77       0.00      0.00      0.00       296
#           99       0.00      0.00      0.00        33
#
#     accuracy                           0.79     90189
#    macro avg       0.03      0.04      0.03     90189
# weighted avg       0.84      0.79      0.81     90189
#
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Diabetes + Weight Variables - MultinomialNB
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#          100       0.92      0.86      0.89     82402
#          101       0.00      0.00      0.00      5956
#          102       0.00      0.00      0.00      1354
#          103       0.00      0.00      0.00       322
#          107       0.00      0.19      0.00        84
#          109       0.00      0.00      0.00        71
#
#     accuracy                           0.79     90189
#    macro avg       0.15      0.18      0.15     90189
# weighted avg       0.84      0.79      0.81     90189
#
# Hamming Loss: 0.21141159121400616
# Hamming Loss: 0.21279756954839282
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Diabetes + Weight Variables - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.93      0.84      0.88     83129
#            1       0.00      0.00      0.00       941
#            2       0.00      0.00      0.00       186
#            3       0.00      0.00      0.00       145
#            4       0.00      0.00      0.00        80
#            5       0.00      0.00      0.00        16
#            6       0.00      0.00      0.00        21
#            7       0.00      0.00      0.00        20
#            8       0.00      0.00      0.00       141
#            9       0.00      0.50      0.00         4
#           10       0.00      0.00      0.00       224
#           11       0.00      0.00      0.00        19
#           12       0.00      0.04      0.00        28
#           13       0.00      0.00      0.00        23
#           14       0.00      0.00      0.00        20
#           15       0.00      0.00      0.00        21
#           16       0.00      0.00      0.00        39
#           17       0.00      0.00      0.00        93
#           18       0.00      0.00      0.00        91
#           19       0.00      0.00      0.00       602
#           20       0.00      0.00      0.00        32
#           21       0.00      0.00      0.00      1044
#           22       0.04      0.05      0.05      2278
#           23       0.00      0.00      0.00         2
#           24       0.00      0.00      0.00       113
#           25       0.00      0.00      0.00       134
#           26       0.00      0.00      0.00        91
#           27       0.00      0.00      0.00        26
#           28       0.00      0.00      0.00        22
#           29       0.00      0.00      0.00         1
#           30       0.00      0.00      0.00       324
#           77       0.00      0.00      0.00       234
#           99       0.00      0.00      0.00        45
#
#     accuracy                           0.77     90189
#    macro avg       0.03      0.04      0.03     90189
# weighted avg       0.86      0.77      0.81     90189
#
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Diabetes + Weight Variables - MultinomialNB
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#          100       0.93      0.84      0.88     82994
#          101       0.09      0.05      0.06      5503
#          102       0.00      0.00      0.00      1285
#          103       0.01      0.23      0.01       282
#          107       0.00      0.00      0.00        60
#          109       0.00      0.00      0.00        65
#
#     accuracy                           0.78     90189
#    macro avg       0.17      0.19      0.16     90189
# weighted avg       0.86      0.78      0.81     90189
#
# Hamming Loss: 0.2251272328110967
# Hamming Loss: 0.22366363968998437
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Diabetes + Weight Variables - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.97      0.86      0.91     87184
#            1       0.00      0.00      0.00       385
#            2       0.00      0.00      0.00        75
#            3       0.00      0.00      0.00        66
#            4       0.00      0.00      0.00        45
#            5       0.00      0.00      0.00        11
#            6       0.00      0.00      0.00         4
#            7       0.00      0.00      0.00        10
#            8       0.00      0.00      0.00        61
#            9       0.00      0.00      0.00         2
#           10       0.00      0.00      0.00       101
#           11       0.00      0.00      0.00         8
#           12       0.00      0.10      0.00        10
#           13       0.00      0.00      0.00         5
#           14       0.00      0.00      0.00         8
#           15       0.00      0.00      0.00        10
#           16       0.00      0.00      0.00        30
#           17       0.00      0.00      0.00        40
#           18       0.00      0.00      0.00        36
#           19       0.01      0.06      0.02       270
#           20       0.00      0.06      0.00        17
#           21       0.00      0.00      0.00       419
#           22       0.00      0.00      0.00       939
#           24       0.00      0.00      0.00        63
#           25       0.00      0.00      0.00        61
#           26       0.00      0.00      0.00        33
#           27       0.00      0.00      0.00         9
#           28       0.00      0.00      0.00         6
#           29       0.00      0.00      0.00         2
#           30       0.00      0.00      0.00       111
#           77       0.00      0.00      0.00       142
#           99       0.00      0.00      0.00        26
#
#     accuracy                           0.83     90189
#    macro avg       0.03      0.03      0.03     90189
# weighted avg       0.94      0.83      0.88     90189
#
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Diabetes + Weight Variables - MultinomialNB
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#          100       0.97      0.86      0.91     87129
#          101       0.04      0.09      0.06      2378
#          102       0.00      0.00      0.00       528
#          103       0.00      0.00      0.00       104
#          107       0.00      0.00      0.00        28
#          109       0.00      0.05      0.00        22
#
#     accuracy                           0.84     90189
#    macro avg       0.17      0.17      0.16     90189
# weighted avg       0.94      0.84      0.88     90189
#
# Hamming Loss: 0.1660402044595239
# Hamming Loss: 0.16448790872501082
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Diabetes + Weight Variables - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.96      0.93      0.95     86105
#            1       0.00      0.00      0.00       519
#            2       0.00      0.00      0.00       117
#            3       0.00      0.00      0.00        81
#            4       0.00      0.00      0.00        48
#            5       0.00      0.00      0.00         6
#            6       0.00      0.00      0.00         9
#            7       0.00      0.00      0.00        10
#            8       0.00      0.00      0.00       102
#            9       0.00      0.00      0.00         3
#           10       0.00      0.00      0.00       121
#           11       0.00      0.00      0.00        10
#           12       0.00      0.00      0.00        18
#           13       0.00      0.00      0.00        16
#           14       0.00      0.00      0.00         9
#           15       0.00      0.00      0.00        11
#           16       0.00      0.00      0.00        36
#           17       0.00      0.00      0.00        68
#           18       0.00      0.00      0.00        47
#           19       0.00      0.00      0.00       355
#           20       0.00      0.06      0.01        33
#           21       0.00      0.00      0.00       632
#           22       0.00      0.00      0.00      1269
#           23       0.00      0.00      0.00         1
#           24       0.00      0.00      0.00        60
#           25       0.00      0.00      0.00        77
#           26       0.00      0.00      0.00        45
#           27       0.00      0.00      0.00        13
#           28       0.00      0.00      0.00         7
#           29       0.00      0.00      0.00         2
#           30       0.00      0.00      0.00       156
#           77       0.00      0.00      0.00       185
#           99       0.00      0.00      0.00        18
#
#     accuracy                           0.89     90189
#    macro avg       0.03      0.03      0.03     90189
# weighted avg       0.91      0.89      0.90     90189
#
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Diabetes + Weight Variables - MultinomialNB
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#          100       0.96      0.94      0.95     86042
#          101       0.00      0.00      0.00      3175
#          102       0.00      0.00      0.00       768
#          103       0.00      0.13      0.01       150
#          107       0.00      0.00      0.00        35
#          109       0.00      0.00      0.00        19
#
#     accuracy                           0.90     90189
#    macro avg       0.16      0.18      0.16     90189
# weighted avg       0.91      0.90      0.90     90189
#
# Hamming Loss: 0.10849438401578906
# Hamming Loss: 0.10413686813247736
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Diabetes + Weight Variables - MultinomialNB AGGREGATE
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.92      0.74      0.82    246634
#            1       0.00      0.00      0.00      3264
#            2       0.00      0.00      0.00       718
#            3       0.00      0.00      0.00       456
#            4       0.00      0.00      0.00       302
#            5       0.00      0.00      0.00        82
#            6       0.00      0.00      0.00        60
#            7       0.00      0.00      0.00        90
#            8       0.00      0.00      0.00       492
#            9       0.00      0.13      0.00        23
#           10       0.00      0.00      0.00       809
#           11       0.00      0.00      0.00        58
#           12       0.00      0.14      0.00        87
#           13       0.00      0.00      0.00        66
#           14       0.00      0.00      0.00        85
#           15       0.00      0.00      0.00        85
#           16       0.00      0.00      0.00       162
#           17       0.00      0.00      0.00       300
#           18       0.00      0.00      0.00       279
#           19       0.00      0.00      0.00      2025
#           20       0.00      0.00      0.00        94
#           21       0.00      0.00      0.00      3450
#           22       0.04      0.19      0.07      7459
#           23       0.00      0.00      0.00         3
#           24       0.00      0.00      0.00       462
#           25       0.00      0.00      0.00       457
#           26       0.00      0.00      0.00       284
#           27       0.00      0.00      0.00        96
#           28       0.00      0.00      0.00        64
#           29       0.00      0.00      0.00         8
#           30       0.00      0.00      0.00      1072
#           77       0.00      0.00      0.00       923
#           99       0.00      0.00      0.00       119
#          100       0.92      0.69      0.79    163130
#          101       0.08      0.21      0.12     12998
#          102       0.00      0.00      0.00      3162
#          103       0.01      0.11      0.01       742
#          107       0.00      0.08      0.00       202
#          109       0.00      0.00      0.00       145
#
#     accuracy                           0.66    450947
#    macro avg       0.05      0.06      0.05    450947
# weighted avg       0.84      0.66      0.74    450947
#
# Hamming Loss: 0.3329075269071489
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Diabetes + Weight Variables - RusBoost
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00     80941
#            1       0.00      0.00      0.00      1273
#            2       0.00      0.00      0.00       281
#            3       0.00      0.00      0.00       167
#            4       0.00      0.00      0.00       122
#            5       0.00      0.72      0.00        29
#            6       0.00      0.00      0.00        23
#            7       0.00      0.00      0.00        38
#            8       0.00      0.45      0.01       202
#            9       0.00      0.00      0.00         4
#           10       0.00      0.00      0.00       307
#           11       0.00      0.00      0.00        23
#           12       0.00      0.00      0.00        26
#           13       0.00      0.00      0.00        23
#           14       0.00      0.00      0.00        32
#           15       0.00      0.00      0.00        34
#           16       0.00      0.00      0.00        66
#           17       0.00      0.00      0.00       107
#           18       0.00      0.00      0.00       104
#           19       0.00      0.00      0.00       736
#           20       0.00      0.00      0.00        36
#           21       0.04      0.03      0.04      1306
#           22       0.00      0.00      0.00      2931
#           24       0.00      0.00      0.00       200
#           25       0.00      0.00      0.00       162
#           26       0.00      0.00      0.00        87
#           27       0.00      0.00      0.00        40
#           28       0.00      0.00      0.00        26
#           29       0.00      0.00      0.00         3
#           30       0.00      0.00      0.00       427
#           77       0.00      0.00      0.00       393
#           99       0.00      0.00      0.00        41
#
#     accuracy                           0.00     90190
#    macro avg       0.00      0.04      0.00     90190
# weighted avg       0.00      0.00      0.00     90190
#
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Diabetes + Weight Variables - RusBoost
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#          100       0.90      0.26      0.40     80728
#          101       0.08      0.35      0.14      7042
#          102       0.00      0.00      0.00      1808
#          103       0.00      0.38      0.01       420
#          107       0.00      0.00      0.00       118
#          109       0.00      0.00      0.00        74
#
#     accuracy                           0.26     90190
#    macro avg       0.16      0.16      0.09     90190
# weighted avg       0.81      0.26      0.37     90190
#
# Hamming Loss: 0.9983035813283069
# Hamming Loss: 0.7421554496063865
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Diabetes + Weight Variables - RusBoost
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00     82564
#            1       0.03      0.16      0.04      1050
#            2       0.00      0.00      0.00       251
#            3       0.00      0.00      0.00       144
#            4       0.00      0.01      0.01       100
#            5       0.00      0.08      0.00        37
#            6       0.00      0.00      0.00        16
#            7       0.00      0.00      0.00        32
#            8       0.00      0.00      0.00       149
#            9       0.00      0.00      0.00        15
#           10       0.00      0.00      0.00       278
#           11       0.00      0.00      0.00        16
#           12       0.00      0.00      0.00        33
#           13       0.00      0.10      0.00        20
#           14       0.00      0.00      0.00        33
#           15       0.00      0.00      0.00        30
#           16       0.00      0.47      0.00        57
#           17       0.00      0.00      0.00       100
#           18       0.00      0.04      0.00        84
#           19       0.00      0.00      0.00       687
#           20       0.00      0.00      0.00        26
#           21       0.00      0.00      0.00      1100
#           22       0.00      0.00      0.00      2250
#           23       0.00      0.00      0.00         1
#           24       0.00      0.11      0.00       149
#           25       0.00      0.12      0.01       161
#           26       0.00      0.00      0.00       106
#           27       0.00      0.00      0.00        30
#           28       0.00      0.00      0.00        16
#           29       0.00      0.00      0.00         4
#           30       0.00      0.00      0.00       321
#           77       0.00      0.00      0.00       296
#           99       0.00      0.00      0.00        33
#
#     accuracy                           0.00     90189
#    macro avg       0.00      0.03      0.00     90189
# weighted avg       0.00      0.00      0.00     90189
#
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Diabetes + Weight Variables - RusBoost
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#          100       0.00      0.00      0.00     82402
#          101       0.00      0.00      0.00      5956
#          102       0.00      0.00      0.00      1354
#          103       0.00      0.20      0.01       322
#          107       0.00      0.49      0.00        84
#          109       0.00      0.31      0.00        71
#
#     accuracy                           0.00     90189
#    macro avg       0.00      0.17      0.00     90189
# weighted avg       0.00      0.00      0.00     90189
#
# Hamming Loss: 0.9972945702912772
# Hamming Loss: 0.9986029338389383
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Diabetes + Weight Variables - RusBoost
#               precision    recall  f1-score   support
#
#            0       0.98      0.28      0.43     83129
#            1       0.01      0.00      0.00       941
#            2       0.00      0.00      0.00       186
#            3       0.00      0.00      0.00       145
#            4       0.00      0.00      0.00        80
#            5       0.00      0.06      0.00        16
#            6       0.00      0.33      0.00        21
#            7       0.00      0.00      0.00        20
#            8       0.00      0.26      0.01       141
#            9       0.00      0.25      0.00         4
#           10       0.01      0.08      0.02       224
#           11       0.00      0.00      0.00        19
#           12       0.00      0.00      0.00        28
#           13       0.00      0.04      0.00        23
#           14       0.00      0.00      0.00        20
#           15       0.00      0.00      0.00        21
#           16       0.00      0.00      0.00        39
#           17       0.00      0.00      0.00        93
#           18       0.00      0.00      0.00        91
#           19       0.03      0.35      0.05       602
#           20       0.00      0.00      0.00        32
#           21       0.00      0.00      0.00      1044
#           22       0.00      0.00      0.00      2278
#           23       0.00      0.00      0.00         2
#           24       0.00      0.00      0.00       113
#           25       0.00      0.00      0.00       134
#           26       0.00      0.02      0.00        91
#           27       0.00      0.00      0.00        26
#           28       0.00      0.00      0.00        22
#           29       0.00      0.00      0.00         1
#           30       0.00      0.00      0.00       324
#           77       0.00      0.00      0.00       234
#           99       0.00      0.00      0.00        45
#
#     accuracy                           0.26     90189
#    macro avg       0.03      0.05      0.02     90189
# weighted avg       0.91      0.26      0.40     90189
#
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Diabetes + Weight Variables - RusBoost
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#          100       1.00      0.00      0.00     82994
#          101       0.07      0.57      0.12      5503
#          102       0.01      0.45      0.03      1285
#          103       0.00      0.00      0.00       282
#          107       0.00      0.00      0.00        60
#          109       0.00      0.00      0.00        65
#
#     accuracy                           0.04     90189
#    macro avg       0.18      0.17      0.02     90189
# weighted avg       0.92      0.04      0.01     90189
#
# Hamming Loss: 0.7395026000953553
# Hamming Loss: 0.9562252602867312
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Diabetes + Weight Variables - RusBoost
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00     87184
#            1       0.00      0.00      0.00       385
#            2       0.00      0.00      0.00        75
#            3       0.00      0.00      0.00        66
#            4       0.00      0.00      0.00        45
#            5       0.00      0.00      0.00        11
#            6       0.00      0.00      0.00         4
#            7       0.00      0.10      0.00        10
#            8       0.00      0.00      0.00        61
#            9       0.00      0.00      0.00         2
#           10       0.00      0.00      0.00       101
#           11       0.00      0.00      0.00         8
#           12       0.00      0.00      0.00        10
#           13       0.00      0.40      0.00         5
#           14       0.00      0.00      0.00         8
#           15       0.00      0.00      0.00        10
#           16       0.00      0.00      0.00        30
#           17       0.00      0.00      0.00        40
#           18       0.00      0.00      0.00        36
#           19       0.00      0.00      0.00       270
#           20       0.00      0.00      0.00        17
#           21       0.00      0.00      0.00       419
#           22       0.00      0.00      0.00       939
#           23       0.00      0.00      0.00         0
#           24       0.00      0.06      0.00        63
#           25       0.00      0.00      0.00        61
#           26       0.00      0.00      0.00        33
#           27       0.00      0.00      0.00         9
#           28       0.00      0.00      0.00         6
#           29       0.00      0.00      0.00         2
#           30       0.00      0.00      0.00       111
#           77       0.00      0.00      0.00       142
#           99       0.00      0.00      0.00        26
#
#     accuracy                           0.00     90189
#    macro avg       0.00      0.02      0.00     90189
# weighted avg       0.00      0.00      0.00     90189
#
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Diabetes + Weight Variables - RusBoost
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#          100       0.96      0.14      0.24     87129
#          101       0.00      0.00      0.00      2378
#          102       0.00      0.00      0.00       528
#          103       0.00      0.00      0.00       104
#          107       0.00      0.89      0.00        28
#          109       0.00      0.00      0.00        22
#
#     accuracy                           0.13     90189
#    macro avg       0.16      0.17      0.04     90189
# weighted avg       0.92      0.13      0.23     90189
#
# Hamming Loss: 0.9999223852132744
# Hamming Loss: 0.8668906407655036
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Diabetes + Weight Variables - RusBoost
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00     86105
#            1       0.04      0.21      0.06       519
#            2       0.00      0.00      0.00       117
#            3       0.00      0.00      0.00        81
#            4       0.00      0.00      0.00        48
#            5       0.00      0.00      0.00         6
# ...
#           77       0.00      0.00      0.00       234
#           99       0.00      0.00      0.00        45
#
#     accuracy                           0.84     90189
#    macro avg       0.03      0.04      0.03     90189
# weighted avg       0.86      0.84      0.85     90189
#
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Diabetes + Weight Variables - AdaBoost
#               precision    recall  f1-score   support
#
#          100       0.92      1.00      0.96     82994
#          101       0.00      0.00      0.00      5503
#          102       0.00      0.00      0.00      1285
#          103       0.00      0.00      0.00       282
#          107       0.00      0.00      0.00        60
#          109       0.00      0.00      0.00        65
#
#     accuracy                           0.92     90189
#    macro avg       0.15      0.17      0.16     90189
# weighted avg       0.85      0.92      0.88     90189
#
# Hamming Loss: 0.16041867633525153
# Hamming Loss: 0.07977691292729712
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Diabetes + Weight Variables - AdaBoost
#               precision    recall  f1-score   support
#
#            0       0.97      0.94      0.95     87184
#            1       0.00      0.00      0.00       385
#            2       0.00      0.00      0.00        75
#            3       0.00      0.20      0.00        66
#            4       0.00      0.00      0.00        45
#            5       0.00      0.00      0.00        11
#            6       0.00      0.00      0.00         4
#            7       0.00      0.00      0.00        10
#            8       0.00      0.00      0.00        61
#            9       0.00      0.00      0.00         2
#           10       0.00      0.00      0.00       101
#           11       0.00      0.00      0.00         8
#           12       0.00      0.00      0.00        10
#           13       0.00      0.00      0.00         5
#           14       0.00      0.00      0.00         8
#           15       0.00      0.00      0.00        10
#           16       0.00      0.00      0.00        30
#           17       0.00      0.00      0.00        40
#           18       0.00      0.00      0.00        36
#           19       0.00      0.00      0.00       270
#           20       0.00      0.00      0.00        17
#           21       0.00      0.00      0.00       419
#           22       0.00      0.00      0.00       939
#           24       0.00      0.00      0.00        63
#           25       0.00      0.00      0.00        61
#           26       0.00      0.00      0.00        33
#           27       0.00      0.00      0.00         9
#           28       0.00      0.00      0.00         6
#           29       0.00      0.00      0.00         2
#           30       0.00      0.00      0.00       111
#           77       0.00      0.00      0.00       142
#           99       0.00      0.00      0.00        26
#
#     accuracy                           0.90     90189
#    macro avg       0.03      0.04      0.03     90189
# weighted avg       0.93      0.90      0.92     90189
#
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Diabetes + Weight Variables - AdaBoost
#               precision    recall  f1-score   support
#
#          100       0.97      1.00      0.98     87129
#          101       0.00      0.00      0.00      2378
#          102       0.00      0.00      0.00       528
#          103       0.00      0.00      0.00       104
#          107       0.00      0.00      0.00        28
#          109       0.00      0.00      0.00        22
#
#     accuracy                           0.97     90189
#    macro avg       0.16      0.17      0.16     90189
# weighted avg       0.93      0.97      0.95     90189
#
# Hamming Loss: 0.09503376243222567
# Hamming Loss: 0.03392874962578585
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Diabetes + Weight Variables - AdaBoost
#               precision    recall  f1-score   support
#
#            0       0.96      0.47      0.63     86105
#            1       0.00      0.00      0.00       519
#            2       0.00      0.00      0.00       117
#            3       0.00      0.00      0.00        81
#            4       0.00      0.94      0.00        48
#            5       0.00      0.00      0.00         6
#            6       0.00      0.00      0.00         9
#            7       0.00      0.00      0.00        10
#            8       0.00      0.00      0.00       102
#            9       0.00      0.00      0.00         3
#           10       0.00      0.00      0.00       121
#           11       0.00      0.00      0.00        10
#           12       0.00      0.00      0.00        18
#           13       0.00      0.00      0.00        16
#           14       0.00      0.00      0.00         9
#           15       0.00      0.00      0.00        11
#           16       0.00      0.00      0.00        36
#           17       0.00      0.00      0.00        68
#           18       0.00      0.00      0.00        47
#           19       0.01      0.25      0.02       355
#           20       0.00      0.00      0.00        33
#           21       0.00      0.00      0.00       632
#           22       0.00      0.00      0.00      1269
#           23       0.00      0.00      0.00         1
#           24       0.00      0.00      0.00        60
#           25       0.00      0.00      0.00        77
#           26       0.00      0.00      0.00        45
#           27       0.00      0.00      0.00        13
#           28       0.00      0.00      0.00         7
#           29       0.00      0.00      0.00         2
#           30       0.00      0.00      0.00       156
#           77       0.00      0.00      0.00       185
#           99       0.00      0.00      0.00        18
#
#     accuracy                           0.45     90189
#    macro avg       0.03      0.05      0.02     90189
# weighted avg       0.92      0.45      0.60     90189
#
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Diabetes + Weight Variables - AdaBoost
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#          100       0.95      1.00      0.98     86042
#          101       0.00      0.00      0.00      3175
#          102       0.00      0.00      0.00       768
#          103       0.00      0.00      0.00       150
#          107       0.00      0.00      0.00        35
#          109       0.00      0.00      0.00        19
#
#     accuracy                           0.95     90189
#    macro avg       0.16      0.17      0.16     90189
# weighted avg       0.91      0.95      0.93     90189
#
# Hamming Loss: 0.5483041169100444
# Hamming Loss: 0.04598121722161239
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Diabetes + Weight Variables - AdaBoost AGGREGATE
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.91      0.92      0.91    246634
#            1       0.00      0.00      0.00      3264
#            2       0.00      0.00      0.00       718
#            3       0.00      0.00      0.00       456
#            4       0.00      0.00      0.00       302
#            5       0.00      0.00      0.00        82
#            6       0.00      0.00      0.00        60
#            7       0.00      0.00      0.00        90
#            8       0.00      0.00      0.00       492
#            9       0.00      0.00      0.00        23
#           10       0.00      0.00      0.00       809
#           11       0.00      0.00      0.00        58
#           12       0.00      0.00      0.00        87
#           13       0.00      0.00      0.00        66
#           14       0.00      0.00      0.00        85
#           15       0.00      0.00      0.00        85
#           16       0.00      0.00      0.00       162
#           17       0.00      0.00      0.00       300
#           18       0.00      0.00      0.00       279
#           19       0.02      0.27      0.04      2025
#           20       0.00      0.00      0.00        94
#           21       0.00      0.00      0.00      3450
#           22       0.00      0.00      0.00      7459
#           23       0.00      0.00      0.00         3
#           24       0.00      0.00      0.00       462
#           25       0.00      0.00      0.00       457
#           26       0.00      0.00      0.00       284
#           27       0.00      0.00      0.00        96
#           28       0.00      0.00      0.00        64
#           29       0.00      0.00      0.00         8
#           30       0.00      0.00      0.00      1072
#           77       0.00      0.00      0.00       923
#           99       0.00      0.00      0.00       119
#          100       0.90      1.00      0.95    163130
#          101       0.00      0.00      0.00     12998
#          102       0.00      0.00      0.00      3162
#          103       0.00      0.00      0.00       742
#          107       0.00      0.00      0.00       202
#          109       0.00      0.00      0.00       145
#
#     accuracy                           0.86    450947
#    macro avg       0.05      0.06      0.05    450947
# weighted avg       0.83      0.86      0.84    450947
#
# Hamming Loss: 0.09245648621515815
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
 folder = "C:/Users/mdjaw/OneDrive/Documents/Markian Training/Research_USQ/USCenterDiseaseControlPrevention/LLCP2020XPT" 
os.chdir(folder)

BRFSS_Grounded = pd.read_csv("LLCP2021XPT_SMOKE.csv")

print(BRFSS_Grounded.shape)

BRFSS_Grounded_X = BRFSS_Grounded.drop(['CNCRTYP1', 'CNCRDIFF'], axis = 1)

print(BRFSS_Grounded_X.shape)
# Out:
# (450946, 30)
# (450946, 28)

# %%
X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  MNB = model = MultinomialNB()
  multi_target_MNB = MultiOutputClassifier(MNB, n_jobs=2)
  y_pred = multi_target_MNB.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - MultinomialNB")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - MultinomialNB")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - MultinomialNB AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))









X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  RB = RUSBoostClassifier(random_state=0)
  multi_target_RB = MultiOutputClassifier(RB, n_jobs=2)
  y_pred = multi_target_RB.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - RusBoost")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - RusBoost")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - RusBoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))


X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  AB = AdaBoostClassifier(n_estimators=200,learning_rate=1)
  multi_target_AB = MultiOutputClassifier(AB, n_jobs=2)
  y_pred = multi_target_AB.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - AdaBoost")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - AdaBoost")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - AdaBoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))
# Out:
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.89      0.87      0.88     80941
#            1       0.00      0.00      0.00      1273
#            2       0.01      0.27      0.01       281
#            3       0.00      0.00      0.00       167
#            4       0.00      0.00      0.00       122
#            5       0.00      0.00      0.00        29
#            6       0.00      0.00      0.00        23
#            7       0.00      0.00      0.00        38
#            8       0.00      0.00      0.00       202
#            9       0.00      0.00      0.00         4
#           10       0.00      0.00      0.00       307
#           11       0.00      0.00      0.00        23
#           12       0.00      0.00      0.00        26
#           13       0.00      0.00      0.00        23
#           14       0.00      0.00      0.00        32
#           15       0.00      0.00      0.00        34
#           16       0.00      0.00      0.00        66
#           17       0.00      0.00      0.00       107
#           18       0.00      0.00      0.00       104
#           19       0.00      0.00      0.00       736
#           20       0.00      0.00      0.00        36
#           21       0.00      0.00      0.00      1306
#           22       0.00      0.00      0.00      2931
#           24       0.00      0.00      0.00       200
#           25       0.00      0.00      0.00       162
#           26       0.00      0.00      0.00        87
#           27       0.00      0.00      0.00        40
#           28       0.00      0.00      0.00        26
#           29       0.00      0.00      0.00         3
#           30       0.00      0.00      0.00       427
#           77       0.00      0.00      0.00       393
#           99       0.00      0.00      0.00        41
#
#     accuracy                           0.78     90190
#    macro avg       0.03      0.04      0.03     90190
# weighted avg       0.80      0.78      0.79     90190
#
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - MultinomialNB
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#          100       0.90      1.00      0.94     80728
#          101       0.00      0.00      0.00      7042
#          102       0.00      0.00      0.00      1808
#          103       0.00      0.00      0.00       420
#          107       0.00      0.00      0.00       118
#          109       0.00      0.00      0.00        74
#
#     accuracy                           0.90     90190
#    macro avg       0.15      0.17      0.16     90190
# weighted avg       0.80      0.90      0.85     90190
#
# Hamming Loss: 0.2225634771038918
# Hamming Loss: 0.10491185275529438
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.91      0.85      0.88     82564
#            1       0.00      0.00      0.00      1050
#            2       0.01      0.31      0.01       251
#            3       0.00      0.00      0.00       144
#            4       0.00      0.00      0.00       100
#            5       0.00      0.00      0.00        37
#            6       0.00      0.00      0.00        16
#            7       0.00      0.00      0.00        32
#            8       0.00      0.00      0.00       149
#            9       0.00      0.00      0.00        15
#           10       0.00      0.00      0.00       278
#           11       0.00      0.00      0.00        16
#           12       0.00      0.00      0.00        33
#           13       0.00      0.00      0.00        20
#           14       0.00      0.00      0.00        33
#           15       0.00      0.00      0.00        30
#           16       0.00      0.00      0.00        57
#           17       0.00      0.00      0.00       100
#           18       0.00      0.00      0.00        84
#           19       0.00      0.00      0.00       687
#           20       0.00      0.00      0.00        26
#           21       0.00      0.00      0.00      1100
#           22       0.00      0.00      0.00      2250
#           23       0.00      0.00      0.00         1
#           24       0.00      0.00      0.00       149
#           25       0.00      0.00      0.00       161
#           26       0.00      0.00      0.00       106
#           27       0.00      0.00      0.00        30
#           28       0.00      0.00      0.00        16
#           29       0.00      0.00      0.00         4
#           30       0.00      0.00      0.00       321
#           77       0.00      0.00      0.00       296
#           99       0.00      0.00      0.00        33
#
#     accuracy                           0.78     90189
#    macro avg       0.03      0.04      0.03     90189
# weighted avg       0.83      0.78      0.81     90189
#
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - MultinomialNB
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#          100       0.91      1.00      0.95     82402
#          101       0.00      0.00      0.00      5956
#          102       0.00      0.00      0.00      1354
#          103       0.00      0.00      0.00       322
#          107       0.00      0.00      0.00        84
#          109       0.00      0.00      0.00        71
#
#     accuracy                           0.91     90189
#    macro avg       0.15      0.17      0.16     90189
# weighted avg       0.83      0.91      0.87     90189
#
# Hamming Loss: 0.21648981583119892
# Hamming Loss: 0.08634090631895243
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.92      0.90      0.91     83129
#            1       0.00      0.00      0.00       941
#            2       0.01      0.27      0.01       186
#            3       0.00      0.00      0.00       145
#            4       0.00      0.00      0.00        80
#            5       0.00      0.00      0.00        16
#            6       0.00      0.00      0.00        21
#            7       0.00      0.00      0.00        20
#            8       0.00      0.00      0.00       141
#            9       0.00      0.00      0.00         4
#           10       0.00      0.00      0.00       224
#           11       0.00      0.00      0.00        19
#           12       0.00      0.00      0.00        28
#           13       0.00      0.00      0.00        23
#           14       0.00      0.00      0.00        20
#           15       0.00      0.00      0.00        21
#           16       0.00      0.00      0.00        39
#           17       0.00      0.00      0.00        93
#           18       0.00      0.00      0.00        91
#           19       0.00      0.00      0.00       602
#           20       0.00      0.00      0.00        32
#           21       0.00      0.00      0.00      1044
#           22       0.00      0.00      0.00      2278
#           23       0.00      0.00      0.00         2
#           24       0.00      0.00      0.00       113
#           25       0.00      0.00      0.00       134
#           26       0.00      0.00      0.00        91
#           27       0.00      0.00      0.00        26
#           28       0.00      0.00      0.00        22
#           29       0.00      0.00      0.00         1
#           30       0.00      0.00      0.00       324
#           77       0.00      0.00      0.00       234
#           99       0.00      0.00      0.00        45
#
#     accuracy                           0.83     90189
#    macro avg       0.03      0.04      0.03     90189
# weighted avg       0.85      0.83      0.84     90189
#
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - MultinomialNB
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#          100       0.92      0.98      0.95     82994
#          101       0.02      0.00      0.01      5503
#          102       0.00      0.00      0.00      1285
#          103       0.00      0.00      0.00       282
#          107       0.00      0.00      0.00        60
#          109       0.00      0.00      0.00        65
#
#     accuracy                           0.91     90189
#    macro avg       0.16      0.16      0.16     90189
# weighted avg       0.85      0.91      0.88     90189
#
# Hamming Loss: 0.165696481832596
# Hamming Loss: 0.09370322323121445
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.97     87184
#            1       0.00      0.00      0.00       385
#            2       0.00      0.05      0.00        75
#            3       0.00      0.00      0.00        66
#            4       0.00      0.00      0.00        45
#            5       0.00      0.00      0.00        11
#            6       0.00      0.00      0.00         4
#            7       0.00      0.00      0.00        10
#            8       0.00      0.00      0.00        61
#            9       0.00      0.00      0.00         2
#           10       0.00      0.00      0.00       101
#           11       0.00      0.00      0.00         8
#           12       0.00      0.00      0.00        10
#           13       0.00      0.00      0.00         5
#           14       0.00      0.00      0.00         8
#           15       0.00      0.00      0.00        10
#           16       0.00      0.00      0.00        30
#           17       0.00      0.00      0.00        40
#           18       0.00      0.00      0.00        36
#           19       0.00      0.00      0.00       270
#           20       0.00      0.00      0.00        17
#           21       0.00      0.00      0.00       419
#           22       0.00      0.00      0.00       939
#           24       0.00      0.00      0.00        63
#           25       0.00      0.00      0.00        61
#           26       0.00      0.00      0.00        33
#           27       0.00      0.00      0.00         9
#           28       0.00      0.00      0.00         6
#           29       0.00      0.00      0.00         2
#           30       0.00      0.00      0.00       111
#           77       0.00      0.00      0.00       142
#           99       0.00      0.00      0.00        26
#
#     accuracy                           0.94     90189
#    macro avg       0.03      0.03      0.03     90189
# weighted avg       0.93      0.94      0.94     90189
#
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - MultinomialNB
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#          100       0.97      0.98      0.98     87129
#          101       0.03      0.01      0.02      2378
#          102       0.00      0.00      0.00       528
#          103       0.00      0.00      0.00       104
#          107       0.00      0.00      0.00        28
#          109       0.00      0.00      0.00        22
#
#     accuracy                           0.95     90189
#    macro avg       0.17      0.17      0.17     90189
# weighted avg       0.93      0.95      0.94     90189
#
# Hamming Loss: 0.05698034128330506
# Hamming Loss: 0.048209870383306166
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.98     86105
#            1       0.00      0.00      0.00       519
#            2       0.02      0.04      0.03       117
#            3       0.00      0.00      0.00        81
#            4       0.00      0.00      0.00        48
#            5       0.00      0.00      0.00         6
#            6       0.00      0.00      0.00         9
#            7       0.00      0.00      0.00        10
#            8       0.00      0.00      0.00       102
#            9       0.00      0.00      0.00         3
#           10       0.00      0.00      0.00       121
#           11       0.00      0.00      0.00        10
#           12       0.00      0.00      0.00        18
#           13       0.00      0.00      0.00        16
#           14       0.00      0.00      0.00         9
#           15       0.00      0.00      0.00        11
#           16       0.00      0.00      0.00        36
#           17       0.00      0.00      0.00        68
#           18       0.00      0.00      0.00        47
#           19       0.00      0.00      0.00       355
#           20       0.00      0.00      0.00        33
#           21       0.00      0.00      0.00       632
#           22       0.00      0.00      0.00      1269
#           23       0.00      0.00      0.00         1
#           24       0.00      0.00      0.00        60
#           25       0.00      0.00      0.00        77
#           26       0.00      0.00      0.00        45
#           27       0.00      0.00      0.00        13
#           28       0.00      0.00      0.00         7
#           29       0.00      0.00      0.00         2
#           30       0.00      0.00      0.00       156
#           77       0.00      0.00      0.00       185
#           99       0.00      0.00      0.00        18
#
#     accuracy                           0.95     90189
#    macro avg       0.03      0.03      0.03     90189
# weighted avg       0.91      0.95      0.93     90189
#
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - MultinomialNB
#               precision    recall  f1-score   support
#
#          100       0.95      1.00      0.98     86042
#          101       0.00      0.00      0.00      3175
#          102       0.00      0.00      0.00       768
#          103       0.00      0.00      0.00       150
#          107       0.00      0.00      0.00        35
#          109       0.00      0.00      0.00        19
#
#     accuracy                           0.95     90189
#    macro avg       0.16      0.17      0.16     90189
# weighted avg       0.91      0.95      0.93     90189
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Hamming Loss: 0.04721196598254776
# Hamming Loss: 0.04598121722161239
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - MultinomialNB AGGREGATE
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.91      0.88      0.89    246634
#            1       0.00      0.00      0.00      3264
#            2       0.01      0.28      0.01       718
#            3       0.00      0.00      0.00       456
#            4       0.00      0.00      0.00       302
#            5       0.00      0.00      0.00        82
#            6       0.00      0.00      0.00        60
#            7       0.00      0.00      0.00        90
#            8       0.00      0.00      0.00       492
#            9       0.00      0.00      0.00        23
#           10       0.00      0.00      0.00       809
#           11       0.00      0.00      0.00        58
#           12       0.00      0.00      0.00        87
#           13       0.00      0.00      0.00        66
#           14       0.00      0.00      0.00        85
#           15       0.00      0.00      0.00        85
#           16       0.00      0.00      0.00       162
#           17       0.00      0.00      0.00       300
#           18       0.00      0.00      0.00       279
#           19       0.00      0.00      0.00      2025
#           20       0.00      0.00      0.00        94
#           21       0.00      0.00      0.00      3450
#           22       0.00      0.00      0.00      7459
#           23       0.00      0.00      0.00         3
#           24       0.00      0.00      0.00       462
#           25       0.00      0.00      0.00       457
#           26       0.00      0.00      0.00       284
#           27       0.00      0.00      0.00        96
#           28       0.00      0.00      0.00        64
#           29       0.00      0.00      0.00         8
#           30       0.00      0.00      0.00      1072
#           77       0.00      0.00      0.00       923
#           99       0.00      0.00      0.00       119
#          100       0.90      1.00      0.95    163130
#          101       0.00      0.00      0.00     12998
#          102       0.00      0.00      0.00      3162
#          103       0.00      0.00      0.00       742
#          107       0.00      0.00      0.00       202
#          109       0.00      0.00      0.00       145
#
#     accuracy                           0.84    450947
#    macro avg       0.05      0.06      0.05    450947
# weighted avg       0.82      0.84      0.83    450947
#
# Hamming Loss: 0.0952417482759416
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - RusBoost
#               precision    recall  f1-score   support
#
#            0       0.91      0.12      0.21     80941
#            1       0.00      0.00      0.00      1273
#            2       0.00      0.00      0.00       281
#            3       0.00      0.00      0.00       167
#            4       0.00      0.00      0.00       122
#            5       0.00      0.00      0.00        29
#            6       0.00      0.00      0.00        23
#            7       0.00      0.00      0.00        38
#            8       0.00      0.00      0.00       202
#            9       0.00      0.00      0.00         4
#           10       0.00      0.00      0.00       307
#           11       0.00      0.00      0.00        23
#           12       0.00      0.00      0.00        26
#           13       0.00      0.00      0.00        23
#           14       0.00      0.03      0.00        32
#           15       0.00      0.38      0.00        34
#           16       0.00      0.00      0.00        66
#           17       0.00      0.00      0.00       107
#           18       0.00      0.00      0.00       104
#           19       0.00      0.00      0.00       736
#           20       0.00      0.00      0.00        36
#           21       0.00      0.00      0.00      1306
#           22       0.00      0.00      0.00      2931
#           24       0.00      0.00      0.00       200
#           25       0.00      0.20      0.00       162
#           26       0.00      0.00      0.00        87
#           27       0.00      0.00      0.00        40
#           28       0.00      0.00      0.00        26
#           29       0.00      0.67      0.00         3
#           30       0.00      0.00      0.00       427
#           77       0.01      0.07      0.01       393
#           99       0.00      0.00      0.00        41
#
#     accuracy                           0.11     90190
#    macro avg       0.03      0.05      0.01     90190
# weighted avg       0.82      0.11      0.19     90190
#
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - RusBoost
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#          100       0.90      0.90      0.90     80728
#          101       0.08      0.11      0.10      7042
#          102       0.00      0.00      0.00      1808
#          103       0.00      0.00      0.00       420
#          107       0.00      0.00      0.00       118
#          109       0.00      0.00      0.00        74
#
#     accuracy                           0.81     90190
#    macro avg       0.16      0.17      0.17     90190
# weighted avg       0.81      0.81      0.81     90190
#
# Hamming Loss: 0.8921831688657279
# Hamming Loss: 0.18966626011752966
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - RusBoost
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00     82564
#            1       0.00      0.00      0.00      1050
#            2       0.02      0.22      0.04       251
#            3       0.00      0.00      0.00       144
#            4       0.00      0.45      0.00       100
#            5       0.00      0.00      0.00        37
#            6       0.00      0.00      0.00        16
#            7       0.00      0.03      0.00        32
#            8       0.00      0.30      0.01       149
#            9       0.00      0.00      0.00        15
#           10       0.00      0.00      0.00       278
#           11       0.00      0.00      0.00        16
#           12       0.00      0.00      0.00        33
#           13       0.00      0.00      0.00        20
#           14       0.00      0.00      0.00        33
#           15       0.00      0.00      0.00        30
#           16       0.00      0.00      0.00        57
#           17       0.00      0.00      0.00       100
#           18       0.00      0.00      0.00        84
#           19       0.00      0.00      0.00       687
#           20       0.00      0.00      0.00        26
#           21       0.00      0.00      0.00      1100
#           22       0.00      0.00      0.00      2250
#           23       0.00      0.00      0.00         1
#           24       0.00      0.00      0.00       149
#           25       0.00      0.00      0.00       161
#           26       0.00      0.00      0.00       106
#           27       0.00      0.00      0.00        30
#           28       0.00      0.31      0.00        16
#           29       0.00      0.00      0.00         4
#           30       0.00      0.00      0.00       321
#           77       0.00      0.00      0.00       296
#           99       0.00      0.00      0.00        33
#
#     accuracy                           0.00     90189
#    macro avg       0.00      0.04      0.00     90189
# weighted avg       0.00      0.00      0.00     90189
#
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - RusBoost
#               precision    recall  f1-score   support
#
#          100       0.00      0.00      0.00     82402
#          101       0.00      0.00      0.00      5956
#          102       0.00      0.00      0.00      1354
#          103       0.00      0.00      0.00       322
#          107       0.00      1.00      0.00        84
#          109       0.00      0.00      0.00        71
#
#     accuracy                           0.00     90189
#    macro avg       0.00      0.17      0.00     90189
# weighted avg       0.00      0.00      0.00     90189
#
# Hamming Loss: 0.9983479138254111
# Hamming Loss: 0.9990686225592922
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - RusBoost
#               precision    recall  f1-score   support
#
#            0       1.00      0.01      0.01     83129
#            1       0.00      0.00      0.00       941
#            2       0.00      0.00      0.00       186
#            3       0.00      0.00      0.00       145
#            4       0.00      0.00      0.00        80
#            5       0.00      0.00      0.00        16
#            6       0.00      0.00      0.00        21
#            7       0.00      0.00      0.00        20
#            8       0.00      0.00      0.00       141
#            9       0.00      0.00      0.00         4
#           10       0.00      0.00      0.00       224
#           11       0.00      0.00      0.00        19
#           12       0.00      0.00      0.00        28
#           13       0.00      0.00      0.00        23
#           14       0.00      0.00      0.00        20
#           15       0.00      0.00      0.00        21
#           16       0.00      0.38      0.00        39
#           17       0.00      0.00      0.00        93
#           18       0.00      0.00      0.00        91
#           19       0.00      0.00      0.00       602
#           20       0.00      0.00      0.00        32
#           21       0.00      0.00      0.00      1044
#           22       0.00      0.00      0.00      2278
#           23       0.00      0.00      0.00         2
#           24       0.00      0.00      0.00       113
#           25       0.00      0.51      0.01       134
#           26       0.00      0.00      0.00        91
#           27       0.00      0.08      0.00        26
#           28       0.00      0.00      0.00        22
#           29       0.00      0.00      0.00         1
#           30       0.00      0.00      0.00       324
#           77       0.00      0.00      0.00       234
#           99       0.00      0.00      0.00        45
#
#     accuracy                           0.01     90189
#    macro avg       0.03      0.03      0.00     90189
# weighted avg       0.92      0.01      0.01     90189
#
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - RusBoost
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#          100       1.00      0.00      0.00     82994
#          101       0.00      0.00      0.00      5503
#          102       0.00      0.00      0.00      1285
#          103       0.00      1.00      0.01       282
#          107       0.00      0.00      0.00        60
#          109       0.00      0.00      0.00        65
#
#     accuracy                           0.01     90189
#    macro avg       0.17      0.17      0.00     90189
# weighted avg       0.92      0.01      0.00     90189
#
# Hamming Loss: 0.9929370544079655
# Hamming Loss: 0.9945669649292043
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - RusBoost
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00     87184
#            1       0.00      0.00      0.00       385
#            2       0.00      0.00      0.00        75
#            3       0.00      0.00      0.00        66
#            4       0.00      0.00      0.00        45
#            5       0.00      0.00      0.00        11
#            6       0.00      0.00      0.00         4
#            7       0.00      0.10      0.00        10
#            8       0.00      0.00      0.00        61
#            9       0.00      0.00      0.00         2
#           10       0.00      0.00      0.00       101
#           11       0.00      0.00      0.00         8
#           12       0.00      0.00      0.00        10
#           13       0.00      0.00      0.00         5
#           14       0.00      0.00      0.00         8
#           15       0.00      0.00      0.00        10
#           16       0.00      0.00      0.00        30
#           17       0.00      0.00      0.00        40
#           18       0.00      0.00      0.00        36
#           19       0.00      0.00      0.00       270
#           20       0.00      0.00      0.00        17
#           21       0.00      0.00      0.00       419
#           22       0.00      0.00      0.00       939
#           23       0.00      0.00      0.00         0
#           24       0.00      0.03      0.01        63
#           25       0.00      0.00      0.00        61
#           26       0.00      0.00      0.00        33
#           27       0.00      0.00      0.00         9
#           28       0.00      0.00      0.00         6
#           29       0.00      0.00      0.00         2
#           30       0.00      0.00      0.00       111
#           77       0.00      0.00      0.00       142
#           99       0.00      0.00      0.00        26
#
#     accuracy                           0.00     90189
#    macro avg       0.00      0.00      0.00     90189
# weighted avg       0.00      0.00      0.00     90189
#
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - RusBoost
#               precision    recall  f1-score   support
#
#          100       0.98      0.13      0.24     87129
#          101       0.03      0.91      0.05      2378
#          102       0.00      0.00      0.00       528
#          103       0.00      0.00      0.00       104
#          107       0.00      0.00      0.00        28
#          109       0.00      0.00      0.00        22
#
#     accuracy                           0.15     90189
#    macro avg       0.17      0.17      0.05     90189
# weighted avg       0.94      0.15      0.23     90189
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Hamming Loss: 0.9999667365199747
# Hamming Loss: 0.8464446883766313
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - RusBoost
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00     86105
#            1       0.02      0.58      0.04       519
#            2       0.01      0.21      0.02       117
#            3       0.00      0.00      0.00        81
#            4       0.00      0.00      0.00        48
#            5       0.00      0.00      0.00         6
#            6       0.00      0.00      0.00         9
#            7       0.00      0.00      0.00        10
#            8       0.00      0.00      0.00       102
#            9       0.00      0.00      0.00         3
# ...
#           30       0.00      0.00      0.00       324
#           77       0.00      0.00      0.00       234
#           99       0.00      0.00      0.00        45
#
#     accuracy                           0.50     90189
#    macro avg       0.03      0.04      0.02     90189
# weighted avg       0.85      0.50      0.62     90189
#
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - AdaBoost
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#          100       0.92      1.00      0.96     82994
#          101       0.00      0.00      0.00      5503
#          102       0.00      0.00      0.00      1285
#          103       0.00      0.00      0.00       282
#          107       0.00      0.00      0.00        60
#          109       0.00      0.00      0.00        65
#
#     accuracy                           0.92     90189
#    macro avg       0.15      0.17      0.16     90189
# weighted avg       0.85      0.92      0.88     90189
#
# Hamming Loss: 0.4996174699797093
# Hamming Loss: 0.07977691292729712
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - AdaBoost
#               precision    recall  f1-score   support
#
#            0       0.97      0.55      0.70     87184
#            1       0.00      0.00      0.00       385
#            2       0.00      0.00      0.00        75
#            3       0.00      0.00      0.00        66
#            4       0.00      0.78      0.00        45
#            5       0.00      0.00      0.00        11
#            6       0.00      0.00      0.00         4
#            7       0.00      0.00      0.00        10
#            8       0.00      0.00      0.00        61
#            9       0.00      0.00      0.00         2
#           10       0.00      0.00      0.00       101
#           11       0.00      0.00      0.00         8
#           12       0.00      0.00      0.00        10
#           13       0.00      0.00      0.00         5
#           14       0.00      0.00      0.00         8
#           15       0.00      0.00      0.00        10
#           16       0.00      0.00      0.00        30
#           17       0.00      0.00      0.00        40
#           18       0.00      0.00      0.00        36
#           19       0.00      0.00      0.00       270
#           20       0.00      0.00      0.00        17
#           21       0.00      0.00      0.00       419
#           22       0.00      0.00      0.00       939
#           24       0.00      0.00      0.00        63
#           25       0.00      0.00      0.00        61
#           26       0.00      0.00      0.00        33
#           27       0.00      0.00      0.00         9
#           28       0.00      0.00      0.00         6
#           29       0.00      0.00      0.00         2
#           30       0.00      0.00      0.00       111
#           77       0.00      0.00      0.00       142
#           99       0.00      0.00      0.00        26
#
#     accuracy                           0.54     90189
#    macro avg       0.03      0.04      0.02     90189
# weighted avg       0.93      0.54      0.68     90189
#
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - AdaBoost
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#          100       0.97      1.00      0.98     87129
#          101       0.00      0.00      0.00      2378
#          102       0.00      0.00      0.00       528
#          103       0.00      0.00      0.00       104
#          107       0.00      0.00      0.00        28
#          109       0.00      0.00      0.00        22
#
#     accuracy                           0.97     90189
#    macro avg       0.16      0.17      0.16     90189
# weighted avg       0.93      0.97      0.95     90189
#
# Hamming Loss: 0.46397010721928394
# Hamming Loss: 0.03392874962578585
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - AdaBoost
#               precision    recall  f1-score   support
#
#            0       0.98      0.10      0.18     86105
#            1       0.00      0.00      0.00       519
#            2       0.00      0.00      0.00       117
#            3       0.00      0.88      0.00        81
#            4       0.00      0.00      0.00        48
#            5       0.00      0.00      0.00         6
#            6       0.00      0.00      0.00         9
#            7       0.00      0.00      0.00        10
#            8       0.00      0.00      0.00       102
#            9       0.00      0.00      0.00         3
#           10       0.00      0.00      0.00       121
#           11       0.00      0.00      0.00        10
#           12       0.00      0.00      0.00        18
#           13       0.00      0.00      0.00        16
#           14       0.00      0.00      0.00         9
#           15       0.00      0.00      0.00        11
#           16       0.00      0.00      0.00        36
#           17       0.00      0.00      0.00        68
#           18       0.00      0.00      0.00        47
#           19       0.00      0.05      0.01       355
#           20       0.00      0.00      0.00        33
#           21       0.00      0.00      0.00       632
#           22       0.00      0.00      0.00      1269
#           23       0.00      0.00      0.00         1
#           24       0.00      0.00      0.00        60
#           25       0.00      0.00      0.00        77
#           26       0.00      0.00      0.00        45
#           27       0.00      0.00      0.00        13
#           28       0.00      0.00      0.00         7
#           29       0.00      1.00      0.00         2
#           30       0.00      0.00      0.00       156
#           77       0.00      0.00      0.00       185
#           99       0.00      0.00      0.00        18
#
#     accuracy                           0.09     90189
#    macro avg       0.03      0.06      0.01     90189
# weighted avg       0.94      0.09      0.17     90189
#
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - AdaBoost
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#          100       0.95      1.00      0.98     86042
#          101       0.00      0.00      0.00      3175
#          102       0.00      0.00      0.00       768
#          103       0.00      0.00      0.00       150
#          107       0.00      0.00      0.00        35
#          109       0.00      0.00      0.00        19
#
#     accuracy                           0.95     90189
#    macro avg       0.16      0.17      0.16     90189
# weighted avg       0.91      0.95      0.93     90189
#
# Hamming Loss: 0.9055871558615796
# Hamming Loss: 0.04598121722161239
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - AdaBoost AGGREGATE
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.91      0.67      0.77    246634
#            1       0.00      0.00      0.00      3264
#            2       0.00      0.00      0.00       718
#            3       0.00      0.00      0.00       456
#            4       0.00      0.00      0.00       302
#            5       0.00      0.00      0.00        82
#            6       0.00      0.00      0.00        60
#            7       0.00      0.00      0.00        90
#            8       0.00      0.00      0.00       492
#            9       0.00      0.09      0.00        23
#           10       0.00      0.00      0.00       809
#           11       0.00      0.00      0.00        58
#           12       0.00      0.00      0.00        87
#           13       0.00      0.00      0.00        66
#           14       0.00      0.00      0.00        85
#           15       0.00      0.00      0.00        85
#           16       0.00      0.00      0.00       162
#           17       0.00      0.00      0.00       300
#           18       0.00      0.00      0.00       279
#           19       0.02      0.27      0.03      2025
#           20       0.00      0.00      0.00        94
#           21       0.00      0.00      0.00      3450
#           22       0.00      0.00      0.00      7459
#           23       0.00      0.00      0.00         3
#           24       0.00      0.00      0.00       462
#           25       0.00      0.00      0.00       457
#           26       0.00      0.00      0.00       284
#           27       0.00      0.00      0.00        96
#           28       0.00      0.00      0.00        64
#           29       0.00      0.00      0.00         8
#           30       0.00      0.00      0.00      1072
#           77       0.00      0.00      0.00       923
#           99       0.00      0.00      0.00       119
#          100       0.90      1.00      0.95    163130
#          101       0.00      0.00      0.00     12998
#          102       0.00      0.00      0.00      3162
#          103       0.00      0.00      0.00       742
#          107       0.00      0.00      0.00       202
#          109       0.00      0.00      0.00       145
#
#     accuracy                           0.73    450947
#    macro avg       0.05      0.05      0.04    450947
# weighted avg       0.82      0.73      0.77    450947
#
# Hamming Loss: 0.09245648621515815
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
folder = "C:/Users/mdjaw/OneDrive/Documents/Markian Training/Research_USQ/USCenterDiseaseControlPrevention/LLCP2020XPT" 
os.chdir(folder)

BRFSS_Grounded = pd.read_csv("LLCP2021XPT_GENDER_INJURY_FATIGUE.csv")

print(BRFSS_Grounded.shape)

BRFSS_Grounded_X = BRFSS_Grounded.drop(['CNCRTYP1', 'CNCRDIFF'], axis = 1)

print(BRFSS_Grounded_X.shape)
# Out:
# (450946, 82)
# (450946, 80)

# %%
X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  MNB = model = MultinomialNB()
  multi_target_MNB = MultiOutputClassifier(MNB, n_jobs=2)
  y_pred = multi_target_MNB.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - MultinomialNB")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - MultinomialNB")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - MultinomialNB AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))









X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  RB = RUSBoostClassifier(random_state=0)
  multi_target_RB = MultiOutputClassifier(RB, n_jobs=2)
  y_pred = multi_target_RB.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - RusBoost")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - RusBoost")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - RusBoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))


X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  AB = AdaBoostClassifier(n_estimators=200,learning_rate=1)
  multi_target_AB = MultiOutputClassifier(AB, n_jobs=2)
  y_pred = multi_target_AB.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - AdaBoost")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - AdaBoost")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - AdaBoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))
# Out:
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00     80941
#            1       0.03      0.30      0.05      1273
#            2       0.00      0.06      0.00       281
#            3       0.00      0.00      0.00       167
#            4       0.00      0.00      0.00       122
#            5       0.00      0.07      0.00        29
#            6       0.00      0.00      0.00        23
#            7       0.00      0.00      0.00        38
#            8       0.00      0.00      0.00       202
#            9       0.00      0.00      0.00         4
#           10       0.00      0.00      0.00       307
#           11       0.00      0.00      0.00        23
#           12       0.00      0.00      0.00        26
#           13       0.00      0.00      0.00        23
#           14       0.00      0.00      0.00        32
#           15       0.00      0.00      0.00        34
#           16       0.00      0.00      0.00        66
#           17       0.00      0.00      0.00       107
#           18       0.00      0.00      0.00       104
#           19       0.00      0.00      0.00       736
#           20       0.00      0.00      0.00        36
#           21       0.00      0.00      0.00      1306
#           22       0.03      0.09      0.05      2931
#           23       0.00      0.00      0.00         0
#           24       0.00      0.00      0.00       200
#           25       0.00      0.00      0.00       162
#           26       0.00      0.00      0.00        87
#           27       0.00      0.00      0.00        40
#           28       0.00      0.69      0.00        26
#           29       0.00      0.00      0.00         3
#           30       0.00      0.00      0.00       427
#           77       0.00      0.00      0.00       393
#           99       0.00      0.00      0.00        41
#
#     accuracy                           0.01     90190
#    macro avg       0.00      0.04      0.00     90190
# weighted avg       0.00      0.01      0.00     90190
#
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - MultinomialNB
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#          100       0.90      0.22      0.35     80728
#          101       0.00      0.00      0.00      7042
#          102       0.00      0.00      0.00      1808
#          103       0.01      0.47      0.01       420
#          107       0.00      0.00      0.00       118
#          109       0.00      0.39      0.00        74
#
#     accuracy                           0.20     90190
#    macro avg       0.15      0.18      0.06     90190
# weighted avg       0.80      0.20      0.31     90190
#
# Hamming Loss: 0.9922718704956204
# Hamming Loss: 0.8030491185275529
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.92      0.73      0.82     82564
#            1       0.00      0.00      0.00      1050
#            2       0.00      0.00      0.00       251
#            3       0.00      0.00      0.00       144
#            4       0.00      0.00      0.00       100
#            5       0.00      0.00      0.00        37
#            6       0.00      0.00      0.00        16
#            7       0.00      0.00      0.00        32
#            8       0.00      0.00      0.00       149
#            9       0.00      0.00      0.00        15
#           10       0.00      0.00      0.00       278
#           11       0.00      0.00      0.00        16
#           12       0.00      0.00      0.00        33
#           13       0.00      0.00      0.00        20
#           14       0.00      0.00      0.00        33
#           15       0.00      0.00      0.00        30
#           16       0.00      0.00      0.00        57
#           17       0.00      0.00      0.00       100
#           18       0.00      0.00      0.00        84
#           19       0.00      0.00      0.00       687
#           20       0.00      0.00      0.00        26
#           21       0.00      0.00      0.00      1100
#           22       0.00      0.00      0.00      2250
#           23       0.00      0.00      0.00         1
#           24       0.00      0.00      0.00       149
#           25       0.00      0.00      0.00       161
#           26       0.00      0.00      0.00       106
#           27       0.00      0.00      0.00        30
#           28       0.00      0.56      0.00        16
#           29       0.00      0.00      0.00         4
#           30       0.00      0.00      0.00       321
#           77       0.00      0.00      0.00       296
#           99       0.00      0.00      0.00        33
#
#     accuracy                           0.67     90189
#    macro avg       0.03      0.04      0.02     90189
# weighted avg       0.85      0.67      0.75     90189
#
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - MultinomialNB
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#          100       0.92      0.73      0.82     82402
#          101       0.00      0.00      0.00      5956
#          102       0.00      0.00      0.00      1354
#          103       0.01      0.43      0.01       322
#          107       0.00      0.00      0.00        84
#          109       0.00      0.00      0.00        71
#
#     accuracy                           0.67     90189
#    macro avg       0.15      0.19      0.14     90189
# weighted avg       0.84      0.67      0.75     90189
#
# Hamming Loss: 0.33082748450476224
# Hamming Loss: 0.33045049839780904
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       1.00      0.00      0.00     83129
#            1       0.01      0.06      0.02       941
#            2       0.00      0.00      0.00       186
#            3       0.00      0.00      0.00       145
#            4       0.00      0.00      0.00        80
#            5       0.00      0.00      0.00        16
#            6       0.00      0.00      0.00        21
#            7       0.00      0.00      0.00        20
#            8       0.00      0.00      0.00       141
#            9       0.00      0.00      0.00         4
#           10       0.00      0.00      0.00       224
#           11       0.00      0.00      0.00        19
#           12       0.00      0.00      0.00        28
#           13       0.00      0.00      0.00        23
#           14       0.00      0.00      0.00        20
#           15       0.00      0.00      0.00        21
#           16       0.00      0.00      0.00        39
#           17       0.00      0.00      0.00        93
#           18       0.00      0.00      0.00        91
#           19       0.00      0.00      0.00       602
#           20       0.00      0.00      0.00        32
#           21       0.00      0.00      0.00      1044
#           22       0.00      0.00      0.00      2278
#           23       0.00      0.50      0.00         2
#           24       0.00      0.00      0.00       113
#           25       0.00      0.00      0.00       134
#           26       0.00      0.00      0.00        91
#           27       0.00      0.00      0.00        26
#           28       0.00      0.73      0.00        22
#           29       0.00      0.00      0.00         1
#           30       0.00      0.00      0.00       324
#           77       0.00      0.00      0.00       234
#           99       0.00      0.00      0.00        45
#
#     accuracy                           0.00     90189
#    macro avg       0.03      0.04      0.00     90189
# weighted avg       0.92      0.00      0.00     90189
#
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - MultinomialNB
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#          100       0.92      0.59      0.71     82994
#          101       0.03      0.05      0.04      5503
#          102       0.00      0.00      0.00      1285
#          103       0.01      0.46      0.01       282
#          107       0.00      0.00      0.00        60
#          109       0.00      0.00      0.00        65
#
#     accuracy                           0.54     90189
#    macro avg       0.16      0.18      0.13     90189
# weighted avg       0.85      0.54      0.66     90189
#
# Hamming Loss: 0.998225947731985
# Hamming Loss: 0.45709565468072605
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.95      0.16      0.28     87184
#            1       0.00      0.00      0.00       385
#            2       0.00      0.00      0.00        75
#            3       0.00      0.00      0.00        66
#            4       0.00      0.00      0.00        45
#            5       0.00      0.00      0.00        11
#            6       0.00      0.00      0.00         4
#            7       0.00      0.00      0.00        10
#            8       0.00      0.00      0.00        61
#            9       0.00      0.00      0.00         2
#           10       0.00      0.00      0.00       101
#           11       0.00      0.00      0.00         8
#           12       0.00      0.00      0.00        10
#           13       0.00      0.00      0.00         5
#           14       0.00      0.00      0.00         8
#           15       0.00      0.00      0.00        10
#           16       0.00      0.00      0.00        30
#           17       0.00      0.00      0.00        40
#           18       0.00      0.00      0.00        36
#           19       0.00      0.00      0.00       270
#           20       0.00      0.00      0.00        17
#           21       0.00      0.00      0.00       419
#           22       0.00      0.00      0.00       939
#           23       0.00      0.00      0.00         0
#           24       0.00      0.00      0.00        63
#           25       0.00      0.00      0.00        61
#           26       0.00      0.00      0.00        33
#           27       0.00      0.00      0.00         9
#           28       0.00      0.50      0.00         6
#           29       0.00      0.00      0.00         2
#           30       0.00      0.00      0.00       111
#           77       0.00      0.00      0.00       142
#           99       0.00      0.00      0.00        26
#
#     accuracy                           0.16     90189
#    macro avg       0.03      0.02      0.01     90189
# weighted avg       0.92      0.16      0.27     90189
#
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - MultinomialNB
#               precision    recall  f1-score   support
#
#          100       0.96      0.85      0.90     87129
#          101       0.00      0.00      0.00      2378
#          102       0.00      0.02      0.00       528
#          103       0.00      0.14      0.01       104
#          107       0.00      0.04      0.01        28
#          109       0.00      0.00      0.00        22
#
#     accuracy                           0.82     90189
#    macro avg       0.16      0.17      0.15     90189
# weighted avg       0.93      0.82      0.87     90189
#
# Hamming Loss: 0.8424308951202475
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Hamming Loss: 0.18110856091097585
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.86      0.03      0.06     86105
#            1       0.00      0.00      0.00       519
#            2       0.00      0.00      0.00       117
#            3       0.00      0.00      0.00        81
#            4       0.00      0.00      0.00        48
#            5       0.00      0.00      0.00         6
#            6       0.00      0.00      0.00         9
#            7       0.00      0.00      0.00        10
#            8       0.00      0.00      0.00       102
#            9       0.00      0.00      0.00         3
#           10       0.00      0.00      0.00       121
#           11       0.00      0.00      0.00        10
#           12       0.00      0.00      0.00        18
#           13       0.00      0.00      0.00        16
#           14       0.00      0.00      0.00         9
#           15       0.00      0.00      0.00        11
#           16       0.00      0.00      0.00        36
#           17       0.00      0.00      0.00        68
#           18       0.00      0.00      0.00        47
#           19       0.00      0.00      0.00       355
#           20       0.00      0.00      0.00        33
#           21       0.00      0.00      0.00       632
#           22       0.00      0.00      0.00      1269
#           23       0.00      0.00      0.00         1
#           24       0.00      0.00      0.00        60
#           25       0.00      0.00      0.00        77
#           26       0.00      0.00      0.00        45
#           27       0.00      0.00      0.00        13
#           28       0.00      0.57      0.00         7
#           29       0.00      0.00      0.00         2
#           30       0.00      0.00      0.00       156
#           77       0.00      0.00      0.00       185
#           99       0.00      0.00      0.00        18
#
#     accuracy                           0.03     90189
#    macro avg       0.03      0.02      0.00     90189
# weighted avg       0.82      0.03      0.06     90189
#
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - MultinomialNB
#               precision    recall  f1-score   support
#
#          100       0.96      0.85      0.90     86042
#          101       0.00      0.00      0.00      3175
#          102       0.00      0.00      0.00       768
#          103       0.00      0.37      0.01       150
#          107       0.00      0.00      0.00        35
#          109       0.00      0.00      0.00        19
#
#     accuracy                           0.81     90189
#    macro avg       0.16      0.20      0.15     90189
# weighted avg       0.92      0.81      0.86     90189
#
# Hamming Loss: 0.9699409018838218
# Hamming Loss: 0.1904666866247547
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - MultinomialNB AGGREGATE
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.92      0.25      0.39    246634
#            1       0.02      0.13      0.04      3264
#            2       0.00      0.03      0.00       718
#            3       0.00      0.00      0.00       456
#            4       0.00      0.00      0.00       302
#            5       0.00      0.02      0.00        82
#            6       0.00      0.00      0.00        60
#            7       0.00      0.00      0.00        90
#            8       0.00      0.00      0.00       492
#            9       0.00      0.00      0.00        23
#           10       0.00      0.00      0.00       809
#           11       0.00      0.00      0.00        58
#           12       0.00      0.00      0.00        87
#           13       0.00      0.00      0.00        66
#           14       0.00      0.00      0.00        85
#           15       0.00      0.00      0.00        85
#           16       0.00      0.00      0.00       162
#           17       0.00      0.00      0.00       300
#           18       0.00      0.00      0.00       279
#           19       0.00      0.00      0.00      2025
#           20       0.00      0.00      0.00        94
#           21       0.00      0.00      0.00      3450
#           22       0.03      0.04      0.03      7459
#           23       0.00      0.33      0.00         3
#           24       0.00      0.00      0.00       462
#           25       0.00      0.00      0.00       457
#           26       0.00      0.00      0.00       284
#           27       0.00      0.00      0.00        96
#           28       0.00      0.67      0.00        64
#           29       0.00      0.00      0.00         8
#           30       0.00      0.00      0.00      1072
#           77       0.00      0.00      0.00       923
#           99       0.00      0.00      0.00       119
#          100       0.92      0.48      0.63    163130
#          101       0.00      0.00      0.00     12998
#          102       0.00      0.00      0.00      3162
#          103       0.01      0.45      0.01       742
#          107       0.00      0.00      0.00       202
#          109       0.00      0.20      0.00       145
#
#     accuracy                           0.31    450947
#    macro avg       0.05      0.07      0.03    450947
# weighted avg       0.84      0.31      0.44    450947
#
# Hamming Loss: 0.54481897770629
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - RusBoost
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00     80941
#            1       0.00      0.00      0.00      1273
#            2       0.00      0.00      0.00       281
#            3       0.00      0.00      0.00       167
#            4       0.00      0.00      0.00       122
#            5       0.00      0.00      0.00        29
#            6       0.00      0.00      0.00        23
#            7       0.00      0.00      0.00        38
#            8       0.00      0.00      0.00       202
#            9       0.00      0.00      0.00         4
#           10       0.00      0.00      0.00       307
#           11       0.00      0.00      0.00        23
#           12       0.00      0.00      0.00        26
#           13       0.00      0.00      0.00        23
#           14       0.00      0.00      0.00        32
#           15       0.00      0.00      0.00        34
#           16       0.00      0.00      0.00        66
#           17       0.00      0.00      0.00       107
#           18       0.00      0.00      0.00       104
#           19       0.00      0.00      0.00       736
#           20       0.00      0.00      0.00        36
#           21       0.00      0.00      0.00      1306
#           22       0.00      0.00      0.00      2931
#           24       0.00      0.00      0.00       200
#           25       0.00      0.58      0.00       162
#           26       0.00      0.00      0.00        87
#           27       0.00      0.00      0.00        40
#           28       0.00      0.69      0.00        26
#           29       0.00      0.00      0.00         3
#           30       0.00      0.00      0.00       427
#           77       0.00      0.00      0.00       393
#           99       0.00      0.00      0.00        41
#
#     accuracy                           0.00     90190
#    macro avg       0.00      0.04      0.00     90190
# weighted avg       0.00      0.00      0.00     90190
#
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - RusBoost
#               precision    recall  f1-score   support
#
#          100       0.90      0.27      0.41     80728
#          101       0.00      0.00      0.00      7042
#          102       0.02      0.73      0.04      1808
#          103       0.00      0.00      0.00       420
#          107       0.00      0.00      0.00       118
#          109       0.00      0.00      0.00        74
#
#     accuracy                           0.26     90190
#    macro avg       0.15      0.17      0.08     90190
# weighted avg       0.80      0.26      0.37     90190
#
# Hamming Loss: 0.9987581771815057
# Hamming Loss: 0.7449273755405256
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - RusBoost
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00     82564
#            1       0.00      0.00      0.00      1050
#            2       0.00      0.00      0.00       251
#            3       0.00      0.00      0.00       144
#            4       0.00      0.00      0.00       100
#            5       0.00      0.00      0.00        37
#            6       0.00      0.06      0.00        16
#            7       0.00      0.00      0.00        32
#            8       0.00      0.21      0.01       149
#            9       0.00      0.00      0.00        15
#           10       0.00      0.00      0.00       278
#           11       0.00      0.00      0.00        16
#           12       0.00      0.00      0.00        33
#           13       0.00      0.00      0.00        20
#           14       0.00      0.00      0.00        33
#           15       0.00      0.00      0.00        30
#           16       0.00      0.28      0.00        57
#           17       0.00      0.00      0.00       100
#           18       0.00      0.00      0.00        84
#           19       0.00      0.00      0.00       687
#           20       0.00      0.00      0.00        26
#           21       0.00      0.00      0.00      1100
#           22       0.02      0.22      0.04      2250
#           23       0.00      0.00      0.00         1
#           24       0.00      0.00      0.00       149
#           25       0.00      0.00      0.00       161
#           26       0.00      0.00      0.00       106
#           27       0.00      0.00      0.00        30
#           28       0.00      0.12      0.00        16
#           29       0.00      0.25      0.00         4
#           30       0.00      0.00      0.00       321
#           77       0.00      0.00      0.00       296
#           99       0.00      0.00      0.00        33
#
#     accuracy                           0.01     90189
#    macro avg       0.00      0.03      0.00     90189
# weighted avg       0.00      0.01      0.00     90189
#
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - RusBoost
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#          100       0.00      0.00      0.00     82402
#          101       0.00      0.00      0.00      5956
#          102       0.00      0.00      0.00      1354
#          103       0.01      0.43      0.01       322
#          107       0.00      0.31      0.00        84
#          109       0.00      0.28      0.00        71
#
#     accuracy                           0.00     90189
#    macro avg       0.00      0.17      0.00     90189
# weighted avg       0.00      0.00      0.00     90189
#
# Hamming Loss: 0.9939793101154243
# Hamming Loss: 0.9979376642384327
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - RusBoost
#               precision    recall  f1-score   support
#
#            0       0.97      0.03      0.06     83129
#            1       0.03      0.70      0.07       941
#            2       0.00      0.00      0.00       186
#            3       0.00      0.06      0.00       145
#            4       0.00      0.00      0.00        80
#            5       0.00      0.00      0.00        16
#            6       0.00      0.00      0.00        21
#            7       0.00      0.00      0.00        20
#            8       0.00      0.00      0.00       141
#            9       0.00      0.00      0.00         4
#           10       0.00      0.00      0.00       224
#           11       0.00      0.00      0.00        19
#           12       0.00      0.00      0.00        28
#           13       0.00      0.00      0.00        23
#           14       0.00      0.00      0.00        20
#           15       0.00      0.00      0.00        21
#           16       0.00      0.00      0.00        39
#           17       0.00      0.39      0.00        93
#           18       0.00      0.00      0.00        91
#           19       0.00      0.00      0.00       602
#           20       0.00      0.00      0.00        32
#           21       0.00      0.00      0.00      1044
#           22       0.00      0.00      0.00      2278
#           23       0.00      0.00      0.00         2
#           24       0.00      0.00      0.00       113
#           25       0.00      0.00      0.00       134
#           26       0.00      0.00      0.00        91
#           27       0.00      0.00      0.00        26
#           28       0.00      0.00      0.00        22
#           29       0.00      0.00      0.00         1
#           30       0.00      0.04      0.00       324
#           77       0.00      0.03      0.00       234
#           99       0.00      0.00      0.00        45
#
#     accuracy                           0.04     90189
#    macro avg       0.03      0.04      0.00     90189
# weighted avg       0.89      0.04      0.06     90189
#
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - RusBoost
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#          100       0.92      0.64      0.76     82994
#          101       0.06      0.25      0.09      5503
#          102       0.00      0.00      0.00      1285
#          103       0.01      0.11      0.01       282
#          107       0.00      0.00      0.00        60
#          109       0.00      0.00      0.00        65
#
#     accuracy                           0.61     90189
#    macro avg       0.16      0.17      0.14     90189
# weighted avg       0.85      0.61      0.70     90189
#
# Hamming Loss: 0.9622015988646065
# Hamming Loss: 0.392520152124982
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - RusBoost
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00     87184
#            1       0.00      0.00      0.00       385
#            2       0.00      0.00      0.00        75
#            3       0.00      0.00      0.00        66
#            4       0.00      0.00      0.00        45
#            5       0.00      0.00      0.00        11
#            6       0.00      0.00      0.00         4
#            7       0.00      0.10      0.00        10
#            8       0.00      0.13      0.00        61
#            9       0.00      0.00      0.00         2
#           10       0.00      0.00      0.00       101
#           11       0.00      0.00      0.00         8
#           12       0.00      0.30      0.00        10
#           13       0.00      0.00      0.00         5
#           14       0.00      0.00      0.00         8
#           15       0.00      0.00      0.00        10
#           16       0.00      0.00      0.00        30
#           17       0.00      0.00      0.00        40
#           18       0.00      0.00      0.00        36
#           19       0.00      0.00      0.00       270
#           20       0.00      0.00      0.00        17
#           21       0.00      0.00      0.00       419
#           22       0.00      0.00      0.00       939
#           23       0.00      0.00      0.00         0
#           24       0.00      0.00      0.00        63
#           25       0.00      0.05      0.00        61
#           26       0.00      0.00      0.00        33
#           27       0.00      0.00      0.00         9
#           28       0.00      0.00      0.00         6
#           29       0.00      0.00      0.00         2
#           30       0.00      0.00      0.00       111
#           77       0.00      0.00      0.00       142
#           99       0.00      0.00      0.00        26
#
#     accuracy                           0.00     90189
#    macro avg       0.00      0.02      0.00     90189
# weighted avg       0.00      0.00      0.00     90189
#
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - RusBoost
#               precision    recall  f1-score   support
#
#          100       0.00      0.00      0.00     87129
#          101       0.03      1.00      0.05      2378
#          102       0.00      0.00      0.00       528
#          103       0.00      0.00      0.00       104
#          107       0.00      0.00      0.00        28
#          109       0.00      0.00      0.00        22
#
#     accuracy                           0.03     90189
#    macro avg       0.00      0.17      0.01     90189
# weighted avg       0.00      0.03      0.00     90189
#
# Hamming Loss: 0.9998336825998736
# Hamming Loss: 0.9736331481666278
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...
#           30       0.00      0.00      0.00       324
#           77       0.00      0.00      0.00       234
#           99       0.00      0.00      0.00        45
#
#     accuracy                           0.50     90189
#    macro avg       0.03      0.04      0.02     90189
# weighted avg       0.85      0.50      0.62     90189
#
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - AdaBoost
#               precision    recall  f1-score   support
#
#          100       0.92      1.00      0.96     82994
#          101       0.00      0.00      0.00      5503
#          102       0.00      0.00      0.00      1285
#          103       0.00      0.00      0.00       282
#          107       0.00      0.00      0.00        60
#          109       0.00      0.00      0.00        65
#
#     accuracy                           0.92     90189
#    macro avg       0.15      0.17      0.16     90189
# weighted avg       0.85      0.92      0.88     90189
#
# Hamming Loss: 0.4996174699797093
# Hamming Loss: 0.07977691292729712
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - AdaBoost
#               precision    recall  f1-score   support
#
#            0       0.97      0.55      0.70     87184
#            1       0.00      0.00      0.00       385
#            2       0.00      0.00      0.00        75
#            3       0.00      0.00      0.00        66
#            4       0.00      0.78      0.00        45
#            5       0.00      0.00      0.00        11
#            6       0.00      0.00      0.00         4
#            7       0.00      0.00      0.00        10
#            8       0.00      0.00      0.00        61
#            9       0.00      0.00      0.00         2
#           10       0.00      0.00      0.00       101
#           11       0.00      0.00      0.00         8
#           12       0.00      0.00      0.00        10
#           13       0.00      0.00      0.00         5
#           14       0.00      0.00      0.00         8
#           15       0.00      0.00      0.00        10
#           16       0.00      0.00      0.00        30
#           17       0.00      0.00      0.00        40
#           18       0.00      0.00      0.00        36
#           19       0.00      0.00      0.00       270
#           20       0.00      0.00      0.00        17
#           21       0.00      0.00      0.00       419
#           22       0.00      0.00      0.00       939
#           24       0.00      0.00      0.00        63
#           25       0.00      0.00      0.00        61
#           26       0.00      0.00      0.00        33
#           27       0.00      0.00      0.00         9
#           28       0.00      0.00      0.00         6
#           29       0.00      0.00      0.00         2
#           30       0.00      0.00      0.00       111
#           77       0.00      0.00      0.00       142
#           99       0.00      0.00      0.00        26
#
#     accuracy                           0.54     90189
#    macro avg       0.03      0.04      0.02     90189
# weighted avg       0.93      0.54      0.68     90189
#
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - AdaBoost
#               precision    recall  f1-score   support
#
#          100       0.97      1.00      0.98     87129
#          101       0.00      0.00      0.00      2378
#          102       0.00      0.00      0.00       528
#          103       0.00      0.00      0.00       104
#          107       0.00      0.00      0.00        28
#          109       0.00      0.00      0.00        22
#
#     accuracy                           0.97     90189
#    macro avg       0.16      0.17      0.16     90189
# weighted avg       0.93      0.97      0.95     90189
#
# Hamming Loss: 0.46397010721928394
# Hamming Loss: 0.03392874962578585
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - AdaBoost
#               precision    recall  f1-score   support
#
#            0       0.98      0.10      0.18     86105
#            1       0.00      0.00      0.00       519
#            2       0.00      0.00      0.00       117
#            3       0.00      0.88      0.00        81
#            4       0.00      0.00      0.00        48
#            5       0.00      0.00      0.00         6
#            6       0.00      0.00      0.00         9
#            7       0.00      0.00      0.00        10
#            8       0.00      0.00      0.00       102
#            9       0.00      0.00      0.00         3
#           10       0.00      0.00      0.00       121
#           11       0.00      0.00      0.00        10
#           12       0.00      0.00      0.00        18
#           13       0.00      0.00      0.00        16
#           14       0.00      0.00      0.00         9
#           15       0.00      0.00      0.00        11
#           16       0.00      0.00      0.00        36
#           17       0.00      0.00      0.00        68
#           18       0.00      0.00      0.00        47
#           19       0.00      0.05      0.01       355
#           20       0.00      0.00      0.00        33
#           21       0.00      0.00      0.00       632
#           22       0.00      0.00      0.00      1269
#           23       0.00      0.00      0.00         1
#           24       0.00      0.00      0.00        60
#           25       0.00      0.00      0.00        77
#           26       0.00      0.00      0.00        45
#           27       0.00      0.00      0.00        13
#           28       0.00      0.00      0.00         7
#           29       0.00      1.00      0.00         2
#           30       0.00      0.00      0.00       156
#           77       0.00      0.00      0.00       185
#           99       0.00      0.00      0.00        18
#
#     accuracy                           0.09     90189
#    macro avg       0.03      0.06      0.01     90189
# weighted avg       0.94      0.09      0.17     90189
#
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - AdaBoost
#               precision    recall  f1-score   support
#
#          100       0.95      1.00      0.98     86042
#          101       0.00      0.00      0.00      3175
#          102       0.00      0.00      0.00       768
#          103       0.00      0.00      0.00       150
#          107       0.00      0.00      0.00        35
#          109       0.00      0.00      0.00        19
#
#     accuracy                           0.95     90189
#    macro avg       0.16      0.17      0.16     90189
# weighted avg       0.91      0.95      0.93     90189
#
# Hamming Loss: 0.9055871558615796
# Hamming Loss: 0.04598121722161239
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - AdaBoost AGGREGATE
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.91      0.84      0.88    246634
#            1       0.00      0.00      0.00      3264
#            2       0.00      0.00      0.00       718
#            3       0.00      0.00      0.00       456
#            4       0.00      0.00      0.00       302
#            5       0.00      0.00      0.00        82
#            6       0.00      0.00      0.00        60
#            7       0.00      0.00      0.00        90
#            8       0.00      0.00      0.00       492
#            9       0.00      0.00      0.00        23
#           10       0.00      0.00      0.00       809
#           11       0.00      0.00      0.00        58
#           12       0.00      0.00      0.00        87
#           13       0.00      0.00      0.00        66
#           14       0.00      0.00      0.00        85
#           15       0.00      0.00      0.00        85
#           16       0.00      0.00      0.00       162
#           17       0.00      0.00      0.00       300
#           18       0.00      0.00      0.00       279
#           19       0.02      0.27      0.03      2025
#           20       0.00      0.00      0.00        94
#           21       0.00      0.00      0.00      3450
#           22       0.00      0.00      0.00      7459
#           23       0.00      0.00      0.00         3
#           24       0.00      0.00      0.00       462
#           25       0.00      0.00      0.00       457
#           26       0.00      0.00      0.00       284
#           27       0.00      0.00      0.00        96
#           28       0.00      0.00      0.00        64
#           29       0.00      0.00      0.00         8
#           30       0.00      0.00      0.00      1072
#           77       0.00      0.00      0.00       923
#           99       0.00      0.00      0.00       119
#          100       0.90      1.00      0.95    163130
#          101       0.00      0.00      0.00     12998
#          102       0.00      0.00      0.00      3162
#          103       0.00      0.00      0.00       742
#          107       0.00      0.00      0.00       202
#          109       0.00      0.00      0.00       145
#
#     accuracy                           0.82    450947
#    macro avg       0.05      0.05      0.05    450947
# weighted avg       0.82      0.82      0.82    450947
#
# Hamming Loss: 0.09245648621515815
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
folder = "C:/Users/mdjaw/OneDrive/Documents/Markian Training/Research_USQ/USCenterDiseaseControlPrevention/LLCP2020XPT" 
os.chdir(folder)

BRFSS_Grounded = pd.read_csv("LLCP2021XPT_GENDER_FATIGUE.csv")

print(BRFSS_Grounded.shape)

BRFSS_Grounded_X = BRFSS_Grounded.drop(['CNCRTYP1', 'CNCRDIFF'], axis = 1)

print(BRFSS_Grounded_X.shape)
# Out:
# (450946, 30)
# (450946, 28)

# %%
X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  MNB = model = MultinomialNB()
  multi_target_MNB = MultiOutputClassifier(MNB, n_jobs=2)
  y_pred = multi_target_MNB.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - MultinomialNB")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - MultinomialNB")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - MultinomialNB AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))









X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  RB = RUSBoostClassifier(random_state=0)
  multi_target_RB = MultiOutputClassifier(RB, n_jobs=2)
  y_pred = multi_target_RB.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - RusBoost")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - RusBoost")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - RusBoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))


X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  AB = AdaBoostClassifier(n_estimators=200,learning_rate=1)
  multi_target_AB = MultiOutputClassifier(AB, n_jobs=2)
  y_pred = multi_target_AB.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - AdaBoost")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - AdaBoost")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - AdaBoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))
# Out:
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.89      0.87      0.88     80941
#            1       0.00      0.00      0.00      1273
#            2       0.01      0.27      0.01       281
#            3       0.00      0.00      0.00       167
#            4       0.00      0.00      0.00       122
#            5       0.00      0.00      0.00        29
#            6       0.00      0.00      0.00        23
#            7       0.00      0.00      0.00        38
#            8       0.00      0.00      0.00       202
#            9       0.00      0.00      0.00         4
#           10       0.00      0.00      0.00       307
#           11       0.00      0.00      0.00        23
#           12       0.00      0.00      0.00        26
#           13       0.00      0.00      0.00        23
#           14       0.00      0.00      0.00        32
#           15       0.00      0.00      0.00        34
#           16       0.00      0.00      0.00        66
#           17       0.00      0.00      0.00       107
#           18       0.00      0.00      0.00       104
#           19       0.00      0.00      0.00       736
#           20       0.00      0.00      0.00        36
#           21       0.00      0.00      0.00      1306
#           22       0.00      0.00      0.00      2931
#           24       0.00      0.00      0.00       200
#           25       0.00      0.00      0.00       162
#           26       0.00      0.00      0.00        87
#           27       0.00      0.00      0.00        40
#           28       0.00      0.00      0.00        26
#           29       0.00      0.00      0.00         3
#           30       0.00      0.00      0.00       427
#           77       0.00      0.00      0.00       393
#           99       0.00      0.00      0.00        41
#
#     accuracy                           0.78     90190
#    macro avg       0.03      0.04      0.03     90190
# weighted avg       0.80      0.78      0.79     90190
#
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - MultinomialNB
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#          100       0.90      1.00      0.94     80728
#          101       0.00      0.00      0.00      7042
#          102       0.00      0.00      0.00      1808
#          103       0.00      0.00      0.00       420
#          107       0.00      0.00      0.00       118
#          109       0.00      0.00      0.00        74
#
#     accuracy                           0.90     90190
#    macro avg       0.15      0.17      0.16     90190
# weighted avg       0.80      0.90      0.85     90190
#
# Hamming Loss: 0.2225634771038918
# Hamming Loss: 0.10491185275529438
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - MultinomialNB
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.91      0.85      0.88     82564
#            1       0.00      0.00      0.00      1050
#            2       0.01      0.31      0.01       251
#            3       0.00      0.00      0.00       144
#            4       0.00      0.00      0.00       100
#            5       0.00      0.00      0.00        37
#            6       0.00      0.00      0.00        16
#            7       0.00      0.00      0.00        32
#            8       0.00      0.00      0.00       149
#            9       0.00      0.00      0.00        15
#           10       0.00      0.00      0.00       278
#           11       0.00      0.00      0.00        16
#           12       0.00      0.00      0.00        33
#           13       0.00      0.00      0.00        20
#           14       0.00      0.00      0.00        33
#           15       0.00      0.00      0.00        30
#           16       0.00      0.00      0.00        57
#           17       0.00      0.00      0.00       100
#           18       0.00      0.00      0.00        84
#           19       0.00      0.00      0.00       687
#           20       0.00      0.00      0.00        26
#           21       0.00      0.00      0.00      1100
#           22       0.00      0.00      0.00      2250
#           23       0.00      0.00      0.00         1
#           24       0.00      0.00      0.00       149
#           25       0.00      0.00      0.00       161
#           26       0.00      0.00      0.00       106
#           27       0.00      0.00      0.00        30
#           28       0.00      0.00      0.00        16
#           29       0.00      0.00      0.00         4
#           30       0.00      0.00      0.00       321
#           77       0.00      0.00      0.00       296
#           99       0.00      0.00      0.00        33
#
#     accuracy                           0.78     90189
#    macro avg       0.03      0.04      0.03     90189
# weighted avg       0.83      0.78      0.81     90189
#
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - MultinomialNB
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#          100       0.91      1.00      0.95     82402
#          101       0.00      0.00      0.00      5956
#          102       0.00      0.00      0.00      1354
#          103       0.00      0.00      0.00       322
#          107       0.00      0.00      0.00        84
#          109       0.00      0.00      0.00        71
#
#     accuracy                           0.91     90189
#    macro avg       0.15      0.17      0.16     90189
# weighted avg       0.83      0.91      0.87     90189
#
# Hamming Loss: 0.21648981583119892
# Hamming Loss: 0.08634090631895243
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - MultinomialNB
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.92      0.90      0.91     83129
#            1       0.00      0.00      0.00       941
#            2       0.01      0.27      0.01       186
#            3       0.00      0.00      0.00       145
#            4       0.00      0.00      0.00        80
#            5       0.00      0.00      0.00        16
#            6       0.00      0.00      0.00        21
#            7       0.00      0.00      0.00        20
#            8       0.00      0.00      0.00       141
#            9       0.00      0.00      0.00         4
#           10       0.00      0.00      0.00       224
#           11       0.00      0.00      0.00        19
#           12       0.00      0.00      0.00        28
#           13       0.00      0.00      0.00        23
#           14       0.00      0.00      0.00        20
#           15       0.00      0.00      0.00        21
#           16       0.00      0.00      0.00        39
#           17       0.00      0.00      0.00        93
#           18       0.00      0.00      0.00        91
#           19       0.00      0.00      0.00       602
#           20       0.00      0.00      0.00        32
#           21       0.00      0.00      0.00      1044
#           22       0.00      0.00      0.00      2278
#           23       0.00      0.00      0.00         2
#           24       0.00      0.00      0.00       113
#           25       0.00      0.00      0.00       134
#           26       0.00      0.00      0.00        91
#           27       0.00      0.00      0.00        26
#           28       0.00      0.00      0.00        22
#           29       0.00      0.00      0.00         1
#           30       0.00      0.00      0.00       324
#           77       0.00      0.00      0.00       234
#           99       0.00      0.00      0.00        45
#
#     accuracy                           0.83     90189
#    macro avg       0.03      0.04      0.03     90189
# weighted avg       0.85      0.83      0.84     90189
#
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - MultinomialNB
#               precision    recall  f1-score   support
#
#          100       0.92      0.98      0.95     82994
#          101       0.02      0.00      0.01      5503
#          102       0.00      0.00      0.00      1285
#          103       0.00      0.00      0.00       282
#          107       0.00      0.00      0.00        60
#          109       0.00      0.00      0.00        65
#
#     accuracy                           0.91     90189
#    macro avg       0.16      0.16      0.16     90189
# weighted avg       0.85      0.91      0.88     90189
#
# Hamming Loss: 0.165696481832596
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Hamming Loss: 0.09370322323121445
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.97     87184
#            1       0.00      0.00      0.00       385
#            2       0.00      0.05      0.00        75
#            3       0.00      0.00      0.00        66
#            4       0.00      0.00      0.00        45
#            5       0.00      0.00      0.00        11
#            6       0.00      0.00      0.00         4
#            7       0.00      0.00      0.00        10
#            8       0.00      0.00      0.00        61
#            9       0.00      0.00      0.00         2
#           10       0.00      0.00      0.00       101
#           11       0.00      0.00      0.00         8
#           12       0.00      0.00      0.00        10
#           13       0.00      0.00      0.00         5
#           14       0.00      0.00      0.00         8
#           15       0.00      0.00      0.00        10
#           16       0.00      0.00      0.00        30
#           17       0.00      0.00      0.00        40
#           18       0.00      0.00      0.00        36
#           19       0.00      0.00      0.00       270
#           20       0.00      0.00      0.00        17
#           21       0.00      0.00      0.00       419
#           22       0.00      0.00      0.00       939
#           24       0.00      0.00      0.00        63
#           25       0.00      0.00      0.00        61
#           26       0.00      0.00      0.00        33
#           27       0.00      0.00      0.00         9
#           28       0.00      0.00      0.00         6
#           29       0.00      0.00      0.00         2
#           30       0.00      0.00      0.00       111
#           77       0.00      0.00      0.00       142
#           99       0.00      0.00      0.00        26
#
#     accuracy                           0.94     90189
#    macro avg       0.03      0.03      0.03     90189
# weighted avg       0.93      0.94      0.94     90189
#
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - MultinomialNB
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#          100       0.97      0.98      0.98     87129
#          101       0.03      0.01      0.02      2378
#          102       0.00      0.00      0.00       528
#          103       0.00      0.00      0.00       104
#          107       0.00      0.00      0.00        28
#          109       0.00      0.00      0.00        22
#
#     accuracy                           0.95     90189
#    macro avg       0.17      0.17      0.17     90189
# weighted avg       0.93      0.95      0.94     90189
#
# Hamming Loss: 0.05698034128330506
# Hamming Loss: 0.048209870383306166
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.98     86105
#            1       0.00      0.00      0.00       519
#            2       0.02      0.04      0.03       117
#            3       0.00      0.00      0.00        81
#            4       0.00      0.00      0.00        48
#            5       0.00      0.00      0.00         6
#            6       0.00      0.00      0.00         9
#            7       0.00      0.00      0.00        10
#            8       0.00      0.00      0.00       102
#            9       0.00      0.00      0.00         3
#           10       0.00      0.00      0.00       121
#           11       0.00      0.00      0.00        10
#           12       0.00      0.00      0.00        18
#           13       0.00      0.00      0.00        16
#           14       0.00      0.00      0.00         9
#           15       0.00      0.00      0.00        11
#           16       0.00      0.00      0.00        36
#           17       0.00      0.00      0.00        68
#           18       0.00      0.00      0.00        47
#           19       0.00      0.00      0.00       355
#           20       0.00      0.00      0.00        33
#           21       0.00      0.00      0.00       632
#           22       0.00      0.00      0.00      1269
#           23       0.00      0.00      0.00         1
#           24       0.00      0.00      0.00        60
#           25       0.00      0.00      0.00        77
#           26       0.00      0.00      0.00        45
#           27       0.00      0.00      0.00        13
#           28       0.00      0.00      0.00         7
#           29       0.00      0.00      0.00         2
#           30       0.00      0.00      0.00       156
#           77       0.00      0.00      0.00       185
#           99       0.00      0.00      0.00        18
#
#     accuracy                           0.95     90189
#    macro avg       0.03      0.03      0.03     90189
# weighted avg       0.91      0.95      0.93     90189
#
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - MultinomialNB
#               precision    recall  f1-score   support
#
#          100       0.95      1.00      0.98     86042
#          101       0.00      0.00      0.00      3175
#          102       0.00      0.00      0.00       768
#          103       0.00      0.00      0.00       150
#          107       0.00      0.00      0.00        35
#          109       0.00      0.00      0.00        19
#
#     accuracy                           0.95     90189
#    macro avg       0.16      0.17      0.16     90189
# weighted avg       0.91      0.95      0.93     90189
#
# Hamming Loss: 0.04721196598254776
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Hamming Loss: 0.04598121722161239
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - MultinomialNB AGGREGATE
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.91      0.88      0.89    246634
#            1       0.00      0.00      0.00      3264
#            2       0.01      0.28      0.01       718
#            3       0.00      0.00      0.00       456
#            4       0.00      0.00      0.00       302
#            5       0.00      0.00      0.00        82
#            6       0.00      0.00      0.00        60
#            7       0.00      0.00      0.00        90
#            8       0.00      0.00      0.00       492
#            9       0.00      0.00      0.00        23
#           10       0.00      0.00      0.00       809
#           11       0.00      0.00      0.00        58
#           12       0.00      0.00      0.00        87
#           13       0.00      0.00      0.00        66
#           14       0.00      0.00      0.00        85
#           15       0.00      0.00      0.00        85
#           16       0.00      0.00      0.00       162
#           17       0.00      0.00      0.00       300
#           18       0.00      0.00      0.00       279
#           19       0.00      0.00      0.00      2025
#           20       0.00      0.00      0.00        94
#           21       0.00      0.00      0.00      3450
#           22       0.00      0.00      0.00      7459
#           23       0.00      0.00      0.00         3
#           24       0.00      0.00      0.00       462
#           25       0.00      0.00      0.00       457
#           26       0.00      0.00      0.00       284
#           27       0.00      0.00      0.00        96
#           28       0.00      0.00      0.00        64
#           29       0.00      0.00      0.00         8
#           30       0.00      0.00      0.00      1072
#           77       0.00      0.00      0.00       923
#           99       0.00      0.00      0.00       119
#          100       0.90      1.00      0.95    163130
#          101       0.00      0.00      0.00     12998
#          102       0.00      0.00      0.00      3162
#          103       0.00      0.00      0.00       742
#          107       0.00      0.00      0.00       202
#          109       0.00      0.00      0.00       145
#
#     accuracy                           0.84    450947
#    macro avg       0.05      0.06      0.05    450947
# weighted avg       0.82      0.84      0.83    450947
#
# Hamming Loss: 0.0952417482759416
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - RusBoost
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\mdjaw\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.91      0.12      0.21     80941
#            1       0.00      0.00      0.00      1273
#            2       0.00      0.00      0.00       281
#            3       0.00      0.00      0.00       167
#            4       0.00      0.00      0.00       122
#            5       0.00      0.00      0.00        29
#            6       0.00      0.00      0.00        23
#            7       0.00      0.00      0.00        38
#            8       0.00      0.00      0.00       202
#            9       0.00      0.00      0.00         4
#           10       0.00      0.00      0.00       307
#           11       0.00      0.00      0.00        23
#           12       0.00      0.00      0.00        26
#           13       0.00      0.00      0.00        23
#           14       0.00      0.03      0.00        32
#           15       0.00      0.38      0.00        34
#           16       0.00      0.00      0.00        66
#           17       0.00      0.00      0.00       107
#           18       0.00      0.00      0.00       104
#           19       0.00      0.00      0.00       736
#           20       0.00      0.00      0.00        36
#           21       0.00      0.00      0.00      1306
