# %%
#import os
#import pandas as pd

#!pip install scikit-learn==1.2.2
#!pip install scikit-multilearn

# %%
from sklearn.datasets import make_multilabel_classification
from sklearn.multioutput import MultiOutputClassifier
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.neural_network import MLPRegressor

from imblearn.ensemble import RUSBoostClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import hamming_loss
from sklearn.model_selection import KFold
from sklearn.metrics import classification_report
from skmultilearn.problem_transform import BinaryRelevance
from skmultilearn.problem_transform import ClassifierChain
from skmultilearn.problem_transform import LabelPowerset
from sklearn.datasets import make_classification
from sklearn.multioutput import MultiOutputClassifier
from sklearn.utils import shuffle
from sklearn.metrics import multilabel_confusion_matrix
from sklearn.metrics import confusion_matrix
import numpy as np
import os
import pandas as pd

# %%
folder = "C:/Users/mdjaw/OneDrive/Documents/Markian Training/Research_USQ/USCenterDiseaseControlPrevention/LLCP2021XPT" 
os.chdir(folder)

BRFSS_Grounded = pd.read_csv("LLCP2021XPT_LINEAR_GENDER.csv")

print(BRFSS_Grounded.shape)

BRFSS_Grounded_X = BRFSS_Grounded.drop(['CNCRTYP1', 'CNCRDIFF'], axis = 1)

print(BRFSS_Grounded_X.shape)
# Out:
# (226296, 30)
# (226296, 28)

# %%
X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  MNB = model = MultinomialNB()
  multi_target_MNB = MultiOutputClassifier(MNB, n_jobs=2)
  y_pred = multi_target_MNB.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - MultinomialNB")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - MultinomialNB")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - MultinomialNB AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))




X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  RF = RandomForestClassifier(max_depth=100, random_state=0)
  multi_target_RF = MultiOutputClassifier(RF, n_jobs=2)
  y_pred = multi_target_RF.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - Random Forest")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - Random Forest")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - Random Forest AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))



X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  RB = RUSBoostClassifier(random_state=0)
  multi_target_RB = MultiOutputClassifier(RB, n_jobs=2)
  y_pred = multi_target_RB.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - RusBoost")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - RusBoost")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - RusBoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))


X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  AB = AdaBoostClassifier(n_estimators=200,learning_rate=1)
  multi_target_AB = MultiOutputClassifier(AB, n_jobs=2)
  y_pred = multi_target_AB.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - AdaBoost")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - AdaBoost")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - AdaBoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))
# Out:
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00     44066
#            1       0.00      0.00      0.00       187
#            2       0.00      0.00      0.00        27
#            3       0.00      0.00      0.00        22
#            4       0.00      1.00      0.00         9
#            5       0.00      0.67      0.00         3
#            6       0.00      0.00      0.00         1
#            7       0.00      0.00      0.00         2
#            8       0.00      0.00      0.00        21
#            9       0.00      0.00      0.00         1
#           10       0.00      0.00      0.00        35
#           11       0.00      0.00      0.00         1
#           12       0.00      0.00      0.00         5
#           13       0.00      0.00      0.00         7
#           14       0.00      0.00      0.00         6
# ...

# %%
folder = "C:/Users/mdjaw/OneDrive/Documents/Markian Training/Research_USQ/USCenterDiseaseControlPrevention/LLCP2021XPT" 
os.chdir(folder)

BRFSS_Grounded = pd.read_csv("LLCP2021XPT_LINEAR_ALCOHOL.csv")

print(BRFSS_Grounded.shape)

BRFSS_Grounded_X = BRFSS_Grounded.drop(['CNCRTYP1', 'CNCRDIFF'], axis = 1)

print(BRFSS_Grounded_X.shape)
# Out:
# (226296, 29)
# (226296, 27)

# %%
X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  MNB = model = MultinomialNB()
  multi_target_MNB = MultiOutputClassifier(MNB, n_jobs=2)
  y_pred = multi_target_MNB.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - MultinomialNB")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - MultinomialNB")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - MultinomialNB AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))




X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  RF = RandomForestClassifier(max_depth=100, random_state=0)
  multi_target_RF = MultiOutputClassifier(RF, n_jobs=2)
  y_pred = multi_target_RF.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - Random Forest")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - Random Forest")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - Random Forest AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))



X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  RB = RUSBoostClassifier(random_state=0)
  multi_target_RB = MultiOutputClassifier(RB, n_jobs=2)
  y_pred = multi_target_RB.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - RusBoost")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - RusBoost")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - RusBoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))


X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  AB = AdaBoostClassifier(n_estimators=200,learning_rate=1)
  multi_target_AB = MultiOutputClassifier(AB, n_jobs=2)
  y_pred = multi_target_AB.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - AdaBoost")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - AdaBoost")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - AdaBoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))
# Out:
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Gender Variables - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.97      0.87      0.92     44066
#            1       0.00      0.00      0.00       187
#            2       0.00      0.00      0.00        27
#            3       0.00      0.00      0.00        22
#            4       0.00      0.00      0.00         9
#            5       0.00      0.00      0.00         3
#            6       0.00      0.00      0.00         1
#            7       0.00      0.00      0.00         2
#            8       0.00      0.00      0.00        21
#            9       0.00      0.00      0.00         1
#           10       0.00      0.00      0.00        35
#           11       0.00      0.00      0.00         1
#           12       0.00      0.00      0.00         5
#           13       0.00      0.00      0.00         7
#           14       0.00      0.00      0.00         6
# ...

# %%
folder = "C:/Users/mdjaw/OneDrive/Documents/Markian Training/Research_USQ/USCenterDiseaseControlPrevention/LLCP2021XPT" 
os.chdir(folder)

BRFSS_Grounded = pd.read_csv("LLCP2021XPT_LINEAR_DIABETES.csv")

print(BRFSS_Grounded.shape)

BRFSS_Grounded_X = BRFSS_Grounded.drop(['CNCRTYP1', 'CNCRDIFF'], axis = 1)

print(BRFSS_Grounded_X.shape)
# Out:
# (226296, 56)
# (226296, 54)

# %%
X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  MNB = model = MultinomialNB()
  multi_target_MNB = MultiOutputClassifier(MNB, n_jobs=2)
  y_pred = multi_target_MNB.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Diabetes + Weight Variables - MultinomialNB")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Diabetes + Weight Variables - MultinomialNB")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Diabetes + Weight Variables - MultinomialNB AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))




X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  RF = RandomForestClassifier(max_depth=100, random_state=0)
  multi_target_RF = MultiOutputClassifier(RF, n_jobs=2)
  y_pred = multi_target_RF.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Diabetes + Weight Variables - Random Forest")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Diabetes + Weight Variables - Random Forest")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Diabetes + Weight Variables - Random Forest AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))



X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  RB = RUSBoostClassifier(random_state=0)
  multi_target_RB = MultiOutputClassifier(RB, n_jobs=2)
  y_pred = multi_target_RB.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Diabetes + Weight Variables - RusBoost")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Diabetes + Weight Variables - RusBoost")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Diabetes + Weight Variables - RusBoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))


X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  AB = AdaBoostClassifier(n_estimators=200,learning_rate=1)
  multi_target_AB = MultiOutputClassifier(AB, n_jobs=2)
  y_pred = multi_target_AB.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Diabetes + Weight Variables - AdaBoost")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Diabetes + Weight Variables - AdaBoost")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Diabetes + Weight Variables - AdaBoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))
# Out:
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Diabetes + Weight Variables - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.97      0.86      0.91     44066
#            1       0.00      0.00      0.00       187
#            2       0.00      0.00      0.00        27
#            3       0.00      0.00      0.00        22
#            4       0.00      0.00      0.00         9
#            5       0.00      0.00      0.00         3
#            6       0.00      0.00      0.00         1
#            7       0.00      0.00      0.00         2
#            8       0.00      0.00      0.00        21
#            9       0.00      0.00      0.00         1
#           10       0.00      0.00      0.00        35
#           11       0.00      0.00      0.00         1
#           12       0.00      0.00      0.00         5
#           13       0.00      0.00      0.00         7
#           14       0.00      0.00      0.00         6
# ...

# %%
 folder = "C:/Users/mdjaw/OneDrive/Documents/Markian Training/Research_USQ/USCenterDiseaseControlPrevention/LLCP2021XPT" 
os.chdir(folder)

BRFSS_Grounded = pd.read_csv("LLCP2021XPT_LINEAR_SMOKING.csv")

print(BRFSS_Grounded.shape)

BRFSS_Grounded_X = BRFSS_Grounded.drop(['CNCRTYP1', 'CNCRDIFF'], axis = 1)

print(BRFSS_Grounded_X.shape)
# Out:
# (226296, 29)
# (226296, 27)

# %%
X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  MNB = model = MultinomialNB()
  multi_target_MNB = MultiOutputClassifier(MNB, n_jobs=2)
  y_pred = multi_target_MNB.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - MultinomialNB")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - MultinomialNB")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - MultinomialNB AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))





X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  RF = RandomForestClassifier(max_depth=100, random_state=0)
  multi_target_RF = MultiOutputClassifier(RF, n_jobs=2)
  y_pred = multi_target_RF.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - Random Forest")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - Random Forest")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - Random Forest AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))



X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  RB = RUSBoostClassifier(random_state=0)
  multi_target_RB = MultiOutputClassifier(RB, n_jobs=2)
  y_pred = multi_target_RB.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - RusBoost")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - RusBoost")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - RusBoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))


X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  AB = AdaBoostClassifier(n_estimators=200,learning_rate=1)
  multi_target_AB = MultiOutputClassifier(AB, n_jobs=2)
  y_pred = multi_target_AB.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - AdaBoost")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - AdaBoost")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - AdaBoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))
# Out:
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Smoking Variables - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99     44066
#            1       0.00      0.00      0.00       187
#            2       0.00      0.00      0.00        27
#            3       0.00      0.00      0.00        22
#            4       0.00      0.00      0.00         9
#            5       0.00      0.00      0.00         3
#            6       0.00      0.00      0.00         1
#            7       0.00      0.00      0.00         2
#            8       0.00      0.00      0.00        21
#            9       0.00      0.00      0.00         1
#           10       0.00      0.00      0.00        35
#           11       0.00      0.00      0.00         1
#           12       0.00      0.00      0.00         5
#           13       0.00      0.00      0.00         7
#           14       0.00      0.00      0.00         6
# ...

# %%
 folder = "C:/Users/mdjaw/OneDrive/Documents/Markian Training/Research_USQ/USCenterDiseaseControlPrevention/LLCP2021XPT" 
os.chdir(folder)

BRFSS_Grounded = pd.read_csv("LLCP2021XPT_LINEAR_WEIGHT.csv")

print(BRFSS_Grounded.shape)

BRFSS_Grounded_X = BRFSS_Grounded.drop(['CNCRTYP1', 'CNCRDIFF'], axis = 1)

print(BRFSS_Grounded_X.shape)
# Out:
# (226296, 30)
# (226296, 28)

# %%
X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  MNB = model = MultinomialNB()
  multi_target_MNB = MultiOutputClassifier(MNB, n_jobs=2)
  y_pred = multi_target_MNB.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - MultinomialNB")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - MultinomialNB")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - MultinomialNB AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))




X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  RF = RandomForestClassifier(max_depth=100, random_state=0)
  multi_target_RF = MultiOutputClassifier(RF, n_jobs=2)
  y_pred = multi_target_RF.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - Random Forest")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - Random Forest")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - Random Forest AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))



X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  RB = RUSBoostClassifier(random_state=0)
  multi_target_RB = MultiOutputClassifier(RB, n_jobs=2)
  y_pred = multi_target_RB.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - RusBoost")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - RusBoost")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - RusBoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))


X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  AB = AdaBoostClassifier(n_estimators=200,learning_rate=1)
  multi_target_AB = MultiOutputClassifier(AB, n_jobs=2)
  y_pred = multi_target_AB.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - AdaBoost")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - AdaBoost")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - AdaBoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))
# Out:
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.97      0.71      0.82     44066
#            1       0.00      0.00      0.00       187
#            2       0.00      0.00      0.00        27
#            3       0.00      0.00      0.00        22
#            4       0.00      0.00      0.00         9
#            5       0.00      0.00      0.00         3
#            6       0.00      0.00      0.00         1
#            7       0.00      0.00      0.00         2
#            8       0.00      0.00      0.00        21
#            9       0.00      0.00      0.00         1
#           10       0.00      0.00      0.00        35
#           11       0.00      0.00      0.00         1
#           12       0.00      0.00      0.00         5
#           13       0.00      0.00      0.00         7
#           14       0.00      0.00      0.00         6
# ...

# %%
folder = "C:/Users/mdjaw/OneDrive/Documents/Markian Training/Research_USQ/USCenterDiseaseControlPrevention/LLCP2021XPT" 
os.chdir(folder)

BRFSS_Grounded = pd.read_csv("LLCP2021XPT_Grounded_ML_nona.csv")

print(BRFSS_Grounded.shape)

BRFSS_Grounded_X = BRFSS_Grounded.drop(['CNCRTYP1', 'CNCRDIFF'], axis = 1)

print(BRFSS_Grounded_X.shape)
# Out:
# (616, 156)
# (616, 154)

# %%
X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  clf = MLPClassifier(solver='lbfgs', alpha=1e-5, hidden_layer_sizes=(5, 2), random_state=1)
  multi_target_clf = MultiOutputClassifier(clf, n_jobs=2)
  y_pred = multi_target_clf.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Standard Data Preparation - CNN")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Standard Data Preparation - CNN")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Standard Data Preparation - CNN AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))
# Out:
# BRFSS MultiLabel Cancer Subtypes - Grounded, Standard Data Preparation - CNN
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00        20
#            2       0.00      0.00      0.00         6
#            3       0.00      0.00      0.00         5
#            4       0.00      0.00      0.00         3
#            6       0.00      0.00      0.00         1
#            7       0.00      0.00      0.00         1
#            8       0.00      0.00      0.00         2
#            9       0.00      0.00      0.00         1
#           10       0.00      0.00      0.00         4
#           14       0.00      0.00      0.00         1
#           16       0.00      0.00      0.00         2
#           18       0.00      0.00      0.00         2
#           19       0.00      0.00      0.00         6
#           21       0.00      0.00      0.00        19
#           22       0.27      1.00      0.43        34
# ...

# %%
folder = "C:/Users/mdjaw/OneDrive/Documents/Markian Training/Research_USQ/USCenterDiseaseControlPrevention/LLCP2021XPT" 
os.chdir(folder)

BRFSS_Grounded = pd.read_csv("LLCP2021XPT_LINEAR_ML.csv")

print(BRFSS_Grounded.shape)

BRFSS_Grounded_X = BRFSS_Grounded.drop(['CNCRTYP1', 'CNCRDIFF'], axis = 1)

print(BRFSS_Grounded_X.shape)
# Out:
# (226296, 189)
# (226296, 187)

# %%
X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  clf = MLPClassifier(solver='lbfgs', alpha=1e-5, hidden_layer_sizes=(5, 2), random_state=1)
  multi_target_AB = MultiOutputClassifier(clf, n_jobs=2)
  y_pred = multi_target_AB.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - CNN")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - CNN")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - CNN AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))
# Out:
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - CNN
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99     44066
#            1       0.00      0.00      0.00       187
#            2       0.00      0.00      0.00        27
#            3       0.00      0.00      0.00        22
#            4       0.00      0.00      0.00         9
#            5       0.00      0.00      0.00         3
#            6       0.00      0.00      0.00         1
#            7       0.00      0.00      0.00         2
#            8       0.00      0.00      0.00        21
#            9       0.00      0.00      0.00         1
#           10       0.00      0.00      0.00        35
#           11       0.00      0.00      0.00         1
#           12       0.00      0.00      0.00         5
#           13       0.00      0.00      0.00         7
#           14       0.00      0.00      0.00         6
# ...

# %%
folder = "C:/Users/mdjaw/OneDrive/Documents/Markian Training/Research_USQ/USCenterDiseaseControlPrevention/LLCP2021XPT" 
os.chdir(folder)

BRFSS_Grounded = pd.read_csv("LLCP2021XPT_LINEAR_PHYSICAL.csv")

print(BRFSS_Grounded.shape)

BRFSS_Grounded_X = BRFSS_Grounded.drop(['CNCRTYP1', 'CNCRDIFF'], axis = 1)

print(BRFSS_Grounded_X.shape)
# Out:
# (226296, 55)
# (226296, 53)

# %%
X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  MNB = model = MultinomialNB()
  multi_target_MNB = MultiOutputClassifier(MNB, n_jobs=2)
  y_pred = multi_target_MNB.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Symptom Variables - MultinomialNB")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Symptom Variables - MultinomialNB")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Symptom Variables - MultinomialNB AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))




X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  RF = RandomForestClassifier(max_depth=100, random_state=0)
  multi_target_RF = MultiOutputClassifier(RF, n_jobs=2)
  y_pred = multi_target_RF.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Symptom Variables - Random Forest")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Symptom Variables - Random Forest")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Symptom Variables - Random Forest AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))



X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  RB = RUSBoostClassifier(random_state=0)
  multi_target_RB = MultiOutputClassifier(RB, n_jobs=2)
  y_pred = multi_target_RB.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Symptom Variables - RusBoost")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Symptom Variables - RusBoost")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Symptom Variables - RusBoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))


X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  AB = AdaBoostClassifier(n_estimators=200,learning_rate=1)
  multi_target_AB = MultiOutputClassifier(AB, n_jobs=2)
  y_pred = multi_target_AB.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Symptom Variables - AdaBoost")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Symptom Variables - AdaBoost")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Symptom Variables - AdaBoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))
# Out:
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Symptom Variables - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       1.00      0.06      0.11     44066
#            1       0.00      0.00      0.00       187
#            2       0.00      0.00      0.00        27
#            3       0.00      0.00      0.00        22
#            4       0.00      0.00      0.00         9
#            5       0.00      0.00      0.00         3
#            6       0.00      0.00      0.00         1
#            7       0.00      0.00      0.00         2
#            8       0.00      0.00      0.00        21
#            9       0.00      0.00      0.00         1
#           10       0.00      0.00      0.00        35
#           11       0.00      0.00      0.00         1
#           12       0.00      0.00      0.00         5
#           13       0.00      0.00      0.00         7
#           14       0.00      0.00      0.00         6
# ...

# %%
 folder = "C:/Users/mdjaw/OneDrive/Documents/Markian Training/Research_USQ/USCenterDiseaseControlPrevention/LLCP2021XPT" 
os.chdir(folder)

BRFSS_Grounded = pd.read_csv("LLCP2021XPT_LINEAR_ALCOHOL.csv")

print(BRFSS_Grounded.shape)

BRFSS_Grounded_X = BRFSS_Grounded.drop(['CNCRTYP1', 'CNCRDIFF'], axis = 1)

print(BRFSS_Grounded_X.shape)
# Out:
# (226296, 29)
# (226296, 27)

# %%
X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  MNB = model = MultinomialNB()
  multi_target_MNB = MultiOutputClassifier(MNB, n_jobs=2)
  y_pred = multi_target_MNB.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Symptom Variables - MultinomialNB")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Symptom Variables - MultinomialNB")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Symptom Variables - MultinomialNB AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))




X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  RF = RandomForestClassifier(max_depth=100, random_state=0)
  multi_target_RF = MultiOutputClassifier(RF, n_jobs=2)
  y_pred = multi_target_RF.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Symptom Variables - Random Forest")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Symptom Variables - Random Forest")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Symptom Variables - Random Forest AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))



X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  RB = RUSBoostClassifier(random_state=0)
  multi_target_RB = MultiOutputClassifier(RB, n_jobs=2)
  y_pred = multi_target_RB.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Symptom Variables - RusBoost")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Symptom Variables - RusBoost")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Symptom Variables - RusBoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))


X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  AB = AdaBoostClassifier(n_estimators=200,learning_rate=1)
  multi_target_AB = MultiOutputClassifier(AB, n_jobs=2)
  y_pred = multi_target_AB.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Symptom Variables - AdaBoost")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Symptom Variables - AdaBoost")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Symptom Variables - AdaBoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))
# Out:
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Symptom Variables - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.97      0.87      0.92     44066
#            1       0.00      0.00      0.00       187
#            2       0.00      0.00      0.00        27
#            3       0.00      0.00      0.00        22
#            4       0.00      0.00      0.00         9
#            5       0.00      0.00      0.00         3
#            6       0.00      0.00      0.00         1
#            7       0.00      0.00      0.00         2
#            8       0.00      0.00      0.00        21
#            9       0.00      0.00      0.00         1
#           10       0.00      0.00      0.00        35
#           11       0.00      0.00      0.00         1
#           12       0.00      0.00      0.00         5
#           13       0.00      0.00      0.00         7
#           14       0.00      0.00      0.00         6
# ...

# %%
folder = "C:/Users/mdjaw/OneDrive/Documents/Markian Training/Research_USQ/USCenterDiseaseControlPrevention/LLCP2021XPT" 
os.chdir(folder)

BRFSS_Grounded = pd.read_csv("LLCP2021XPT_LINEAR_MENTAL.csv")

print(BRFSS_Grounded.shape)

BRFSS_Grounded_X = BRFSS_Grounded.drop(['CNCRTYP1', 'CNCRDIFF'], axis = 1)

print(BRFSS_Grounded_X.shape)
# Out:
# (226296, 55)
# (226296, 53)

# %%
X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  MNB = model = MultinomialNB()
  multi_target_MNB = MultiOutputClassifier(MNB, n_jobs=2)
  y_pred = multi_target_MNB.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Symptom Variables - MultinomialNB")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Symptom Variables - MultinomialNB")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Symptom Variables - MultinomialNB AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))




X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  RF = RandomForestClassifier(max_depth=100, random_state=0)
  multi_target_RF = MultiOutputClassifier(RF, n_jobs=2)
  y_pred = multi_target_RF.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Symptom Variables - Random Forest")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Symptom Variables - Random Forest")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Symptom Variables - Random Forest AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))



X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  RB = RUSBoostClassifier(random_state=0)
  multi_target_RB = MultiOutputClassifier(RB, n_jobs=2)
  y_pred = multi_target_RB.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Symptom Variables - RusBoost")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Symptom Variables - RusBoost")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Symptom Variables - RusBoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))


X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  AB = AdaBoostClassifier(n_estimators=200,learning_rate=1)
  multi_target_AB = MultiOutputClassifier(AB, n_jobs=2)
  y_pred = multi_target_AB.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Symptom Variables - AdaBoost")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Symptom Variables - AdaBoost")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Symptom Variables - AdaBoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))
# Out:
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Symptom Variables - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.97      0.59      0.73     44066
#            1       0.00      0.00      0.00       187
#            2       0.00      0.30      0.00        27
#            3       0.00      0.00      0.00        22
#            4       0.00      0.00      0.00         9
#            5       0.00      0.00      0.00         3
#            6       0.00      0.00      0.00         1
#            7       0.00      0.00      0.00         2
#            8       0.00      0.00      0.00        21
#            9       0.00      1.00      0.00         1
#           10       0.00      0.00      0.00        35
#           11       0.00      0.00      0.00         1
#           12       0.00      0.00      0.00         5
#           13       0.00      0.00      0.00         7
#           14       0.00      0.00      0.00         6
# ...

# %%
import os
import pandas as pd

folder = "C:/Users/mdjaw/OneDrive/Documents/Markian Training/Research_USQ/USCenterDiseaseControlPrevention/LLCP2021XPT" 
os.chdir(folder)

BRFSS_Grounded = pd.read_csv("LLCP2021XPT_LINEAR_ML.csv")

print(BRFSS_Grounded.shape)

BRFSS_Grounded_X = BRFSS_Grounded.drop(['CNCRTYP1', 'CNCRDIFF'], axis = 1)

print(BRFSS_Grounded_X.shape)
# Out:
# (226296, 237)
# (226296, 235)

# %%
X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  MNB = model = MultinomialNB()
  multi_target_MNB = MultiOutputClassifier(MNB, n_jobs=2)
  y_pred = multi_target_MNB.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - MultinomialNB")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - MultinomialNB")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - MultinomialNB AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))




X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  RF = RandomForestClassifier(max_depth=100, random_state=0)
  multi_target_RF = MultiOutputClassifier(RF, n_jobs=2)
  y_pred = multi_target_RF.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - Random Forest")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - Random Forest")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - Random Forest AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))



X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  RB = RUSBoostClassifier(random_state=0)
  multi_target_RB = MultiOutputClassifier(RB, n_jobs=2)
  y_pred = multi_target_RB.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - RusBoost")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - RusBoost")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - RusBoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))


X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  AB = AdaBoostClassifier(n_estimators=200,learning_rate=1)
  multi_target_AB = MultiOutputClassifier(AB, n_jobs=2)
  y_pred = multi_target_AB.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - AdaBoost")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - AdaBoost")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - AdaBoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))
# Out:
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.99      0.02      0.03     44066
#            1       0.00      0.00      0.00       187
#            2       0.00      0.00      0.00        27
#            3       0.00      0.00      0.00        22
#            4       0.00      0.00      0.00         9
#            5       0.00      0.00      0.00         3
#            6       0.00      0.00      0.00         1
#            7       0.00      0.00      0.00         2
#            8       0.00      0.00      0.00        21
#            9       0.00      0.00      0.00         1
#           10       0.00      0.00      0.00        35
#           11       0.00      0.00      0.00         1
#           12       0.00      0.00      0.00         5
#           13       0.00      0.00      0.00         7
#           14       0.00      0.00      0.00         6
# ...

# %%
folder = "C:/Users/mdjaw/OneDrive/Documents/Markian Training/Research_USQ/USCenterDiseaseControlPrevention/LLCP2021XPT" 
os.chdir(folder)

BRFSS_Grounded = pd.read_csv("LLCP2021XPT_LINEAR_ASTHMA.csv")

print(BRFSS_Grounded.shape)

BRFSS_Grounded_X = BRFSS_Grounded.drop(['CNCRTYP1', 'CNCRDIFF'], axis = 1)

print(BRFSS_Grounded_X.shape)
# Out:
# (226296, 29)
# (226296, 27)

# %%
X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  MNB = model = MultinomialNB()
  multi_target_MNB = MultiOutputClassifier(MNB, n_jobs=2)
  y_pred = multi_target_MNB.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - MultinomialNB")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - MultinomialNB")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - MultinomialNB AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))




X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  RF = RandomForestClassifier(max_depth=100, random_state=0)
  multi_target_RF = MultiOutputClassifier(RF, n_jobs=2)
  y_pred = multi_target_RF.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - Random Forest")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - Random Forest")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - Random Forest AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))



X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  RB = RUSBoostClassifier(random_state=0)
  multi_target_RB = MultiOutputClassifier(RB, n_jobs=2)
  y_pred = multi_target_RB.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - RusBoost")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - RusBoost")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - RusBoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))


X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  AB = AdaBoostClassifier(n_estimators=200,learning_rate=1)
  multi_target_AB = MultiOutputClassifier(AB, n_jobs=2)
  y_pred = multi_target_AB.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - AdaBoost")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - AdaBoost")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - AdaBoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))
# Out:
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.97      0.86      0.91     44066
#            1       0.00      0.00      0.00       187
#            2       0.00      0.00      0.00        27
#            3       0.00      0.00      0.00        22
#            4       0.00      0.00      0.00         9
#            5       0.00      0.00      0.00         3
#            6       0.00      0.00      0.00         1
#            7       0.00      0.00      0.00         2
#            8       0.00      0.00      0.00        21
#            9       0.00      0.00      0.00         1
#           10       0.00      0.00      0.00        35
#           11       0.00      0.00      0.00         1
#           12       0.00      0.00      0.00         5
#           13       0.00      0.00      0.00         7
#           14       0.00      0.00      0.00         6
# ...

# %%
folder = "C:/Users/mdjaw/OneDrive/Documents/Markian Training/Research_USQ/USCenterDiseaseControlPrevention/LLCP2021XPT" 
os.chdir(folder)

BRFSS_Grounded = pd.read_csv("LLCP2021XPT_GENDER_DIABETES.csv")

print(BRFSS_Grounded.shape)

BRFSS_Grounded_X = BRFSS_Grounded.drop(['CNCRTYP1', 'CNCRDIFF'], axis = 1)

print(BRFSS_Grounded_X.shape)
# Out:
# (226296, 55)
# (226296, 53)

# %%
X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  MNB = model = MultinomialNB()
  multi_target_MNB = MultiOutputClassifier(MNB, n_jobs=2)
  y_pred = multi_target_MNB.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - MultinomialNB")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - MultinomialNB")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - MultinomialNB AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))




X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  RF = RandomForestClassifier(max_depth=100, random_state=0)
  multi_target_RF = MultiOutputClassifier(RF, n_jobs=2)
  y_pred = multi_target_RF.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - Random Forest")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - Random Forest")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - Random Forest AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))



X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  RB = RUSBoostClassifier(random_state=0)
  multi_target_RB = MultiOutputClassifier(RB, n_jobs=2)
  y_pred = multi_target_RB.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - RusBoost")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - RusBoost")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - RusBoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))


X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  AB = AdaBoostClassifier(n_estimators=200,learning_rate=1)
  multi_target_AB = MultiOutputClassifier(AB, n_jobs=2)
  y_pred = multi_target_AB.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - AdaBoost")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - AdaBoost")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - AdaBoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))
# Out:
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.96      0.20      0.34     44066
#            1       0.00      0.00      0.00       187
#            2       0.00      0.00      0.00        27
#            3       0.00      0.00      0.00        22
#            4       0.00      0.89      0.00         9
#            5       0.00      0.00      0.00         3
#            6       0.00      0.00      0.00         1
#            7       0.00      0.00      0.00         2
#            8       0.00      0.00      0.00        21
#            9       0.00      0.00      0.00         1
#           10       0.00      0.00      0.00        35
#           11       0.00      0.00      0.00         1
#           12       0.00      0.00      0.00         5
#           13       0.00      0.00      0.00         7
#           14       0.00      0.00      0.00         6
# ...

# %%
folder = "C:/Users/mdjaw/OneDrive/Documents/Markian Training/Research_USQ/USCenterDiseaseControlPrevention/LLCP2021XPT" 
os.chdir(folder)

BRFSS_Grounded = pd.read_csv("LLCP2021XPT_GENDER_WEIGHT.csv")

print(BRFSS_Grounded.shape)

BRFSS_Grounded_X = BRFSS_Grounded.drop(['CNCRTYP1', 'CNCRDIFF'], axis = 1)

print(BRFSS_Grounded_X.shape)
# Out:
# (226296, 55)
# (226296, 53)

# %%
X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  MNB = model = MultinomialNB()
  multi_target_MNB = MultiOutputClassifier(MNB, n_jobs=2)
  y_pred = multi_target_MNB.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - MultinomialNB")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - MultinomialNB")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - MultinomialNB AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))




X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  RF = RandomForestClassifier(max_depth=100, random_state=0)
  multi_target_RF = MultiOutputClassifier(RF, n_jobs=2)
  y_pred = multi_target_RF.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - Random Forest")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - Random Forest")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - Random Forest AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))



X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  RB = RUSBoostClassifier(random_state=0)
  multi_target_RB = MultiOutputClassifier(RB, n_jobs=2)
  y_pred = multi_target_RB.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - RusBoost")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - RusBoost")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - RusBoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))


X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  AB = AdaBoostClassifier(n_estimators=200,learning_rate=1)
  multi_target_AB = MultiOutputClassifier(AB, n_jobs=2)
  y_pred = multi_target_AB.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - AdaBoost")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - AdaBoost")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - AdaBoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))
# Out:
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00     44066
#            1       0.00      0.00      0.00       187
#            2       0.00      0.00      0.00        27
#            3       0.00      0.27      0.00        22
#            4       0.00      0.78      0.00         9
#            5       0.00      0.67      0.00         3
#            6       0.00      0.00      0.00         1
#            7       0.00      0.00      0.00         2
#            8       0.00      0.00      0.00        21
#            9       0.00      0.00      0.00         1
#           10       0.00      0.00      0.00        35
#           11       0.00      0.00      0.00         1
#           12       0.00      0.00      0.00         5
#           13       0.00      0.00      0.00         7
#           14       0.00      0.00      0.00         6
# ...

# %%
folder = "C:/Users/mdjaw/OneDrive/Documents/Markian Training/Research_USQ/USCenterDiseaseControlPrevention/LLCP2021XPT" 
os.chdir(folder)

BRFSS_Grounded = pd.read_csv("LLCP2021XPT_GENDER_SMOKE.csv")

print(BRFSS_Grounded.shape)

BRFSS_Grounded_X = BRFSS_Grounded.drop(['CNCRTYP1', 'CNCRDIFF'], axis = 1)

print(BRFSS_Grounded_X.shape)
# Out:
# (226296, 55)
# (226296, 53)

# %%
X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  MNB = model = MultinomialNB()
  multi_target_MNB = MultiOutputClassifier(MNB, n_jobs=2)
  y_pred = multi_target_MNB.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - MultinomialNB")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - MultinomialNB")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - MultinomialNB AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))




X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  RF = RandomForestClassifier(max_depth=100, random_state=0)
  multi_target_RF = MultiOutputClassifier(RF, n_jobs=2)
  y_pred = multi_target_RF.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - Random Forest")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - Random Forest")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - Random Forest AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))



X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  RB = RUSBoostClassifier(random_state=0)
  multi_target_RB = MultiOutputClassifier(RB, n_jobs=2)
  y_pred = multi_target_RB.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - RusBoost")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - RusBoost")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - RusBoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))


X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  AB = AdaBoostClassifier(n_estimators=200,learning_rate=1)
  multi_target_AB = MultiOutputClassifier(AB, n_jobs=2)
  y_pred = multi_target_AB.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - AdaBoost")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - AdaBoost")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - AdaBoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))
# Out:
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00     44066
#            1       0.00      0.00      0.00       187
#            2       0.00      0.00      0.00        27
#            3       0.00      0.00      0.00        22
#            4       0.00      1.00      0.00         9
#            5       0.00      0.67      0.00         3
#            6       0.00      0.00      0.00         1
#            7       0.00      0.00      0.00         2
#            8       0.00      0.00      0.00        21
#            9       0.00      0.00      0.00         1
#           10       0.00      0.00      0.00        35
#           11       0.00      0.00      0.00         1
#           12       0.00      0.00      0.00         5
#           13       0.00      0.00      0.00         7
#           14       0.00      0.00      0.00         6
# ...

# %%
folder = "C:/Users/mdjaw/OneDrive/Documents/Markian Training/Research_USQ/USCenterDiseaseControlPrevention/LLCP2021XPT" 
os.chdir(folder)

BRFSS_Grounded = pd.read_csv("LLCP2021XPT_GENDER_INJURY.csv")

print(BRFSS_Grounded.shape)

BRFSS_Grounded_X = BRFSS_Grounded.drop(['CNCRTYP1', 'CNCRDIFF'], axis = 1)

print(BRFSS_Grounded_X.shape)
# Out:
# (226296, 55)
# (226296, 53)

# %%
X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  MNB = model = MultinomialNB()
  multi_target_MNB = MultiOutputClassifier(MNB, n_jobs=2)
  y_pred = multi_target_MNB.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - MultinomialNB")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - MultinomialNB")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - MultinomialNB AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))




X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  RF = RandomForestClassifier(max_depth=100, random_state=0)
  multi_target_RF = MultiOutputClassifier(RF, n_jobs=2)
  y_pred = multi_target_RF.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - Random Forest")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - Random Forest")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - Random Forest AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))



X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  RB = RUSBoostClassifier(random_state=0)
  multi_target_RB = MultiOutputClassifier(RB, n_jobs=2)
  y_pred = multi_target_RB.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - RusBoost")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - RusBoost")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - RusBoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))


X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  AB = AdaBoostClassifier(n_estimators=200,learning_rate=1)
  multi_target_AB = MultiOutputClassifier(AB, n_jobs=2)
  y_pred = multi_target_AB.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - AdaBoost")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - AdaBoost")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - AdaBoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))
# Out:
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00     44066
#            1       0.00      0.00      0.00       187
#            2       0.00      0.00      0.00        27
#            3       0.00      0.00      0.00        22
#            4       0.00      0.00      0.00         9
#            5       0.00      0.00      0.00         3
#            6       0.00      0.00      0.00         1
#            7       0.00      0.00      0.00         2
#            8       0.00      0.00      0.00        21
#            9       0.00      0.00      0.00         1
#           10       0.00      0.00      0.00        35
#           11       0.00      0.00      0.00         1
#           12       0.00      0.00      0.00         5
#           13       0.00      0.00      0.00         7
#           14       0.00      0.00      0.00         6
# ...

# %%
folder = "C:/Users/mdjaw/OneDrive/Documents/Markian Training/Research_USQ/USCenterDiseaseControlPrevention/LLCP2021XPT" 
os.chdir(folder)

BRFSS_Grounded = pd.read_csv("LLCP2021XPT_GENDER_FATIGUE.csv")

print(BRFSS_Grounded.shape)

BRFSS_Grounded_X = BRFSS_Grounded.drop(['CNCRTYP1', 'CNCRDIFF'], axis = 1)

print(BRFSS_Grounded_X.shape)
# Out:
# (226296, 55)
# (226296, 53)

# %%
X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  MNB = model = MultinomialNB()
  multi_target_MNB = MultiOutputClassifier(MNB, n_jobs=2)
  y_pred = multi_target_MNB.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - MultinomialNB")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - MultinomialNB")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - MultinomialNB AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))




X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  RF = RandomForestClassifier(max_depth=100, random_state=0)
  multi_target_RF = MultiOutputClassifier(RF, n_jobs=2)
  y_pred = multi_target_RF.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - Random Forest")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - Random Forest")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - Random Forest AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))



X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  RB = RUSBoostClassifier(random_state=0)
  multi_target_RB = MultiOutputClassifier(RB, n_jobs=2)
  y_pred = multi_target_RB.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - RusBoost")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - RusBoost")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - RusBoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))


X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  AB = AdaBoostClassifier(n_estimators=200,learning_rate=1)
  multi_target_AB = MultiOutputClassifier(AB, n_jobs=2)
  y_pred = multi_target_AB.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - AdaBoost")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - AdaBoost")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - AdaBoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))
# Out:
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00     44066
#            1       0.00      0.00      0.00       187
#            2       0.00      0.00      0.00        27
#            3       0.00      0.00      0.00        22
#            4       0.00      1.00      0.00         9
#            5       0.00      0.67      0.00         3
#            6       0.00      0.00      0.00         1
#            7       0.00      0.00      0.00         2
#            8       0.00      0.00      0.00        21
#            9       0.00      0.00      0.00         1
#           10       0.00      0.00      0.00        35
#           11       0.00      0.00      0.00         1
#           12       0.00      0.00      0.00         5
#           13       0.00      0.00      0.00         7
#           14       0.00      0.00      0.00         6
# ...

# %%
folder = "C:/Users/mdjaw/OneDrive/Documents/Markian Training/Research_USQ/USCenterDiseaseControlPrevention/LLCP2021XPT" 
os.chdir(folder)

BRFSS_Grounded = pd.read_csv("LLCP2021XPT_GENDER_STRESS.csv")

print(BRFSS_Grounded.shape)

BRFSS_Grounded_X = BRFSS_Grounded.drop(['CNCRTYP1', 'CNCRDIFF'], axis = 1)

print(BRFSS_Grounded_X.shape)
# Out:
# (226296, 55)
# (226296, 53)

# %%
X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  MNB = model = MultinomialNB()
  multi_target_MNB = MultiOutputClassifier(MNB, n_jobs=2)
  y_pred = multi_target_MNB.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - MultinomialNB")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - MultinomialNB")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - MultinomialNB AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))




X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  RF = RandomForestClassifier(max_depth=100, random_state=0)
  multi_target_RF = MultiOutputClassifier(RF, n_jobs=2)
  y_pred = multi_target_RF.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - Random Forest")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - Random Forest")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - Random Forest AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))



X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  RB = RUSBoostClassifier(random_state=0)
  multi_target_RB = MultiOutputClassifier(RB, n_jobs=2)
  y_pred = multi_target_RB.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - RusBoost")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - RusBoost")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - RusBoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))


X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  AB = AdaBoostClassifier(n_estimators=200,learning_rate=1)
  multi_target_AB = MultiOutputClassifier(AB, n_jobs=2)
  y_pred = multi_target_AB.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - AdaBoost")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - AdaBoost")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - AdaBoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))
# Out:
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00     44066
#            1       0.00      0.00      0.00       187
#            2       0.00      0.00      0.00        27
#            3       0.00      0.00      0.00        22
#            4       0.00      1.00      0.00         9
#            5       0.00      0.67      0.00         3
#            6       0.00      0.00      0.00         1
#            7       0.00      0.00      0.00         2
#            8       0.00      0.00      0.00        21
#            9       0.00      0.00      0.00         1
#           10       0.00      0.00      0.00        35
#           11       0.00      0.00      0.00         1
#           12       0.00      0.00      0.00         5
#           13       0.00      0.00      0.00         7
#           14       0.00      0.00      0.00         6
# ...

# %%
folder = "C:/Users/mdjaw/OneDrive/Documents/Markian Training/Research_USQ/USCenterDiseaseControlPrevention/LLCP2021XPT" 
os.chdir(folder)

BRFSS_Grounded = pd.read_csv("LLCP2021XPT_GENDER_DEPRESSION.csv")

print(BRFSS_Grounded.shape)

BRFSS_Grounded_X = BRFSS_Grounded.drop(['CNCRTYP1', 'CNCRDIFF'], axis = 1)

print(BRFSS_Grounded_X.shape)
# Out:
# (226296, 55)
# (226296, 53)

# %%
X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  MNB = model = MultinomialNB()
  multi_target_MNB = MultiOutputClassifier(MNB, n_jobs=2)
  y_pred = multi_target_MNB.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - MultinomialNB")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - MultinomialNB")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - MultinomialNB AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))




X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  RF = RandomForestClassifier(max_depth=100, random_state=0)
  multi_target_RF = MultiOutputClassifier(RF, n_jobs=2)
  y_pred = multi_target_RF.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - Random Forest")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - Random Forest")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - Random Forest AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))



X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  RB = RUSBoostClassifier(random_state=0)
  multi_target_RB = MultiOutputClassifier(RB, n_jobs=2)
  y_pred = multi_target_RB.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - RusBoost")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - RusBoost")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - RusBoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))


X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  AB = AdaBoostClassifier(n_estimators=200,learning_rate=1)
  multi_target_AB = MultiOutputClassifier(AB, n_jobs=2)
  y_pred = multi_target_AB.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - AdaBoost")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - AdaBoost")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - AdaBoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))
# Out:
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00     44066
#            1       0.00      0.00      0.00       187
#            2       0.00      0.00      0.00        27
#            3       0.00      0.00      0.00        22
#            4       0.00      1.00      0.00         9
#            5       0.00      0.67      0.00         3
#            6       0.00      0.00      0.00         1
#            7       0.00      0.00      0.00         2
#            8       0.00      0.00      0.00        21
#            9       0.00      0.00      0.00         1
#           10       0.00      0.00      0.00        35
#           11       0.00      0.00      0.00         1
#           12       0.00      0.00      0.00         5
#           13       0.00      0.00      0.00         7
#           14       0.00      0.00      0.00         6
# ...

# %%
folder = "C:/Users/mdjaw/OneDrive/Documents/Markian Training/Research_USQ/USCenterDiseaseControlPrevention/LLCP2021XPT" 
os.chdir(folder)

BRFSS_Grounded = pd.read_csv("LLCP2021XPT_GENDER_WEIGHT_v2.csv")

print(BRFSS_Grounded.shape)

BRFSS_Grounded_X = BRFSS_Grounded.drop(['CNCRTYP1', 'CNCRDIFF'], axis = 1)

print(BRFSS_Grounded_X.shape)
# Out:
# (226296, 81)
# (226296, 79)

# %%
X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  MNB = model = MultinomialNB()
  multi_target_MNB = MultiOutputClassifier(MNB, n_jobs=2)
  y_pred = multi_target_MNB.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - MultinomialNB")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - MultinomialNB")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - MultinomialNB AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))




X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  RF = RandomForestClassifier(max_depth=100, random_state=0)
  multi_target_RF = MultiOutputClassifier(RF, n_jobs=2)
  y_pred = multi_target_RF.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - Random Forest")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - Random Forest")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - Random Forest AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))



X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  RB = RUSBoostClassifier(random_state=0)
  multi_target_RB = MultiOutputClassifier(RB, n_jobs=2)
  y_pred = multi_target_RB.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - RusBoost")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - RusBoost")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - RusBoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))


X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  AB = AdaBoostClassifier(n_estimators=200,learning_rate=1)
  multi_target_AB = MultiOutputClassifier(AB, n_jobs=2)
  y_pred = multi_target_AB.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - AdaBoost")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - AdaBoost")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - AdaBoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))
# Out:
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00     44066
#            1       0.00      0.00      0.00       187
#            2       0.00      0.00      0.00        27
#            3       0.00      0.27      0.00        22
#            4       0.00      0.78      0.00         9
#            5       0.00      0.00      0.00         3
#            6       0.00      0.00      0.00         1
#            7       0.00      0.00      0.00         2
#            8       0.00      0.00      0.00        21
#            9       0.00      0.00      0.00         1
#           10       0.00      0.00      0.00        35
#           11       0.00      0.00      0.00         1
#           12       0.00      0.00      0.00         5
#           13       0.00      0.00      0.00         7
#           14       0.00      0.00      0.00         6
# ...

# %%
folder = "C:/Users/mdjaw/OneDrive/Documents/Markian Training/Research_USQ/USCenterDiseaseControlPrevention/LLCP2021XPT" 
os.chdir(folder)

BRFSS_Grounded = pd.read_csv("LLCP2021XPT_MALE_WEIGHT.csv")

print(BRFSS_Grounded.shape)

BRFSS_Grounded_X = BRFSS_Grounded.drop(['CNCRTYP1', 'CNCRDIFF'], axis = 1)

print(BRFSS_Grounded_X.shape)
# Out:
# (226296, 55)
# (226296, 53)

# %%
X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  MNB = model = MultinomialNB()
  multi_target_MNB = MultiOutputClassifier(MNB, n_jobs=2)
  y_pred = multi_target_MNB.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - MultinomialNB")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - MultinomialNB")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - MultinomialNB AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))




X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  RF = RandomForestClassifier(max_depth=100, random_state=0)
  multi_target_RF = MultiOutputClassifier(RF, n_jobs=2)
  y_pred = multi_target_RF.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - Random Forest")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - Random Forest")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - Random Forest AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))



X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  RB = RUSBoostClassifier(random_state=0)
  multi_target_RB = MultiOutputClassifier(RB, n_jobs=2)
  y_pred = multi_target_RB.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - RusBoost")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - RusBoost")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - RusBoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))


X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  AB = AdaBoostClassifier(n_estimators=200,learning_rate=1)
  multi_target_AB = MultiOutputClassifier(AB, n_jobs=2)
  y_pred = multi_target_AB.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - AdaBoost")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - AdaBoost")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - AdaBoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))
# Out:
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       1.00      0.17      0.29     44066
#            1       0.01      0.79      0.03       187
#            2       0.00      0.00      0.00        27
#            3       0.00      0.27      0.00        22
#            4       0.00      0.00      0.00         9
#            5       0.00      0.00      0.00         3
#            6       0.00      0.00      0.00         1
#            7       0.00      0.00      0.00         2
#            8       0.00      0.00      0.00        21
#            9       0.00      0.00      0.00         1
#           10       0.00      0.00      0.00        35
#           11       0.00      0.00      0.00         1
#           12       0.00      0.00      0.00         5
#           13       0.00      0.00      0.00         7
#           14       0.00      0.00      0.00         6
# ...

# %%
folder = "C:/Users/mdjaw/OneDrive/Documents/Markian Training/Research_USQ/USCenterDiseaseControlPrevention/LLCP2021XPT" 
os.chdir(folder)

BRFSS_Grounded = pd.read_csv("LLCP2021XPT_FEMALE_WEIGHT.csv")

print(BRFSS_Grounded.shape)

BRFSS_Grounded_X = BRFSS_Grounded.drop(['CNCRTYP1', 'CNCRDIFF'], axis = 1)

print(BRFSS_Grounded_X.shape)
# Out:
# (226296, 55)
# (226296, 53)

# %%
X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  MNB = model = MultinomialNB()
  multi_target_MNB = MultiOutputClassifier(MNB, n_jobs=2)
  y_pred = multi_target_MNB.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - MultinomialNB")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - MultinomialNB")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - MultinomialNB AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))




X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  RF = RandomForestClassifier(max_depth=100, random_state=0)
  multi_target_RF = MultiOutputClassifier(RF, n_jobs=2)
  y_pred = multi_target_RF.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - Random Forest")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - Random Forest")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - Random Forest AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))



X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  RB = RUSBoostClassifier(random_state=0)
  multi_target_RB = MultiOutputClassifier(RB, n_jobs=2)
  y_pred = multi_target_RB.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - RusBoost")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - RusBoost")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - RusBoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))


X = np.array(BRFSS_Grounded_X)
#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()

y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']

Y = np.vstack((y1, y2)).T

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)


n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
    
  AB = AdaBoostClassifier(n_estimators=200,learning_rate=1)
  multi_target_AB = MultiOutputClassifier(AB, n_jobs=2)
  y_pred = multi_target_AB.fit(X_train, y_train).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - AdaBoost")
  print(classification_report(y_test[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - AdaBoost")
  print(classification_report(y_test[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - AdaBoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))
# Out:
# BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       1.00      0.09      0.17     44066
#            1       0.00      0.00      0.00       187
#            2       0.00      0.00      0.00        27
#            3       0.00      0.27      0.00        22
#            4       0.00      0.78      0.00         9
#            5       0.00      0.00      0.00         3
#            6       0.00      0.00      0.00         1
#            7       0.00      0.00      0.00         2
#            8       0.00      0.00      0.00        21
#            9       0.00      0.00      0.00         1
#           10       0.00      0.00      0.00        35
#           11       0.00      0.00      0.00         1
#           12       0.00      0.00      0.00         5
#           13       0.00      0.00      0.00         7
#           14       0.00      0.00      0.00         6
# ...

# %%
folder = "C:/Users/mdjaw/OneDrive/Documents/Markian Training/Research_USQ/USCenterDiseaseControlPrevention/LLCP2021XPT" 
os.chdir(folder)

BRFSS_Grounded = pd.read_csv("LLCP2021XPT_GENDER.csv")

print(BRFSS_Grounded.shape)

BRFSS_Grounded_X = BRFSS_Grounded.drop(['CNCRTYP1', 'CNCRDIFF'], axis = 1)

print(BRFSS_Grounded_X.shape)

#BRFSS_Grounded_X.columns
# Out:
# (226296, 30)
# (226296, 28)

# %%
X = np.array(BRFSS_Grounded_X)

#print(X)

#y = BRFSS_Grounded[['CNCRTYP1', 'CNCRDIFF']].to_numpy()


y1 = BRFSS_Grounded['CNCRTYP1']
y2 = BRFSS_Grounded['CNCRDIFF']
y3 = BRFSS_Grounded['X_SEX']

Y = np.vstack((y1, y2, y3)).T

print(Y)

n_samples, n_features = X.shape # 10,100
n_outputs = Y.shape[1] # 3
n_classes = 2
#forest = RandomForestClassifier(random_state=1)

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

print(Y.shape)

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
      
  #X_test_M = X_test['X_SEX' == 1]
  #print(X_test)
  #print(X_test[:,:].shape)
  print(y_train.shape)
  print(y_test.shape)
  y_test_M = y_test[:, y_test[0, 0, :] == 1]
  y_train_M = y_train[:, y_train[0, 0, :] == 1]
      
  #X_test_M = X_test[X_test[:,0] == 1]]  
    
  #print(X_test.shape)
  #print(X_test.shape)
  #print(y_test_M.shape)
  #print(y_train_M.shape)
  #print(y_train_M)
    
  MNB = model = MultinomialNB()
  multi_target_MNB = MultiOutputClassifier(MNB, n_jobs=2)
  y_pred = multi_target_MNB.fit(X_train, y_train_M).predict(X_test)
    
  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - MultinomialNB")
  print(classification_report(y_test_M[:,0], y_pred[:,0]))

  print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - MultinomialNB")
  print(classification_report(y_test_M[:,1], y_pred[:,1]))

  hl=hamming_loss(y_test_M[:,0], y_pred[:,0])
  print("Hamming Loss: " + str(hl))
    
  hl=hamming_loss(y_test_M[:,1], y_pred[:,1])
  print("Hamming Loss: " + str(hl))
        
  y_pred2.append(y_pred[:,0])
  #pred2.append(pred)
  y_test2.append(y_test_M[:,0])
  hl2.append(hl)
    
  y_pred2.append(y_pred[:,1])
  #pred2.append(pred)
  y_test2.append(y_test_M[:,1])
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
#pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer Subtypes - Grounded, Linear Variables - MultinomialNB AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, y_pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))
# Out:
# [[  0 100   2]
#  [  0 100   2]
#  [  0 100   2]
#  ...
#  [  0 100   2]
#  [  0 100   1]
#  [  0 100   2]]
# (226296, 3)
# (181036, 3)
# (45260, 3)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[9], line 36
#      34 print(y_train.shape)
#      35 print(y_test.shape)
# ---> 36 y_test_M = y_test[:, y_test[0, 0, :] == 1]
#      37 y_train_M = y_train[:, y_train[0, 0, :] == 1]
#      39 #X_test_M = X_test[X_test[:,0] == 1]]
#      40
#      41 #print(X_test.shape)
#    (...)
#      44 #print(y_train_M.shape)
#      45 #print(y_train_M)
#
# IndexError: too many indices for array: array is 2-dimensional, but 3 were indexed
