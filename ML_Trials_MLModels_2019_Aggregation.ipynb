# %%
import os
import pandas as pd

folder = "C:/Users/mdjaw/OneDrive/Documents/Markian Training/Research_USQ/USCenterDiseaseControlPrevention/LLCP2019XPT" 
os.chdir(folder)

BRFSS_Grounded = pd.read_csv("LLCP2019XPT_Grounded_KGFS25.csv")

print(BRFSS_Grounded.shape)

BRFSS_Grounded_X = BRFSS_Grounded.drop(['CNCRTYP1', 'DIABETE4'], axis = 1)

print(BRFSS_Grounded_X.shape)
# Out:
# (91981, 15)
# (91981, 13)

# %%
from sklearn.datasets import make_multilabel_classification
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.neural_network import MLPRegressor
from imblearn.ensemble import RUSBoostClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import hamming_loss
from sklearn.model_selection import KFold
from sklearn.metrics import classification_report
import numpy as np


X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = LogisticRegression(C=1.0, penalty='l1', dual=False, solver='liblinear')
  model = OneVsRestClassifier(model)    
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
print("y_pred shape: ")
print(np.shape(y_pred))

print("y_pred2 shape:")
print(np.shape(y_pred2))

y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = MultinomialNB()
  model = OneVsRestClassifier(MultinomialNB())   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
   
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
              solver='svd', store_covariance=False, tol=0.0001))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))
    
X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(RandomForestClassifier(max_depth=100, random_state=0))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))
    
X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(KNeighborsClassifier(n_neighbors=5))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

a = []
b = []
X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(SVC())   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded - SVM")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))  
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - SVM AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  #model = MultinomialNB()
  model = OneVsRestClassifier(RUSBoostClassifier(random_state=0))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded - RUSBoost")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
   
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)

print("y_pred shape: ")
print(np.shape(y_pred))

print("y_pred2 shape:")
print(np.shape(y_pred2))

y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - RUSBoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  #model = OneVsRestClassifier(AdaBoostClassifier(n_estimators=50,learning_rate=1))   
  
  model = OneVsRestClassifier(AdaBoostClassifier(n_estimators=200,learning_rate=1))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
   
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
print("y_pred shape: ")
print(np.shape(y_pred))

print("y_pred2 shape:")
print(np.shape(y_pred2))

y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - ADABoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))
# Out:
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94     16232
#            1       0.00      0.00      0.00      2165
#
#     accuracy                           0.88     18397
#    macro avg       0.44      0.50      0.47     18397
# weighted avg       0.78      0.88      0.83     18397
#
# Hamming Loss: 0.11768223079849975
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94     16404
#            1       0.00      0.00      0.00      1992
#
#     accuracy                           0.89     18396
#    macro avg       0.45      0.50      0.47     18396
# weighted avg       0.80      0.89      0.84     18396
#
# Hamming Loss: 0.10828440965427266
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95     16480
#            1       0.00      0.00      0.00      1916
#
#     accuracy                           0.90     18396
#    macro avg       0.45      0.50      0.47     18396
# weighted avg       0.80      0.90      0.85     18396
#
# Hamming Loss: 0.10415307675581648
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94     16309
#            1       0.00      0.00      0.00      2087
#
#     accuracy                           0.89     18396
#    macro avg       0.44      0.50      0.47     18396
# weighted avg       0.79      0.89      0.83     18396
#
# Hamming Loss: 0.1134485757773429
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95     16680
#            1       0.00      0.00      0.00      1716
#
#     accuracy                           0.91     18396
#    macro avg       0.45      0.50      0.48     18396
# weighted avg       0.82      0.91      0.86     18396
#
# Hamming Loss: 0.09328114807566862
# y_pred shape:
# (18396, 2)
# y_pred2 shape:
# (5,)
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression AGGREGATE
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94     82105
#            1       0.00      0.00      0.00      9876
#
#     accuracy                           0.89     91981
#    macro avg       0.45      0.50      0.47     91981
# weighted avg       0.80      0.89      0.84     91981
#
# Hamming Loss: 0.1073698882123201
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94     16232
#            1       0.00      0.00      0.00      2165
#
#     accuracy                           0.88     18397
#    macro avg       0.44      0.50      0.47     18397
# weighted avg       0.78      0.88      0.83     18397
#
# Hamming Loss: 0.11768223079849975
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94     16404
#            1       0.00      0.00      0.00      1992
#
#     accuracy                           0.89     18396
#    macro avg       0.45      0.50      0.47     18396
# weighted avg       0.80      0.89      0.84     18396
#
# Hamming Loss: 0.10828440965427266
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95     16480
#            1       0.00      0.00      0.00      1916
#
#     accuracy                           0.90     18396
#    macro avg       0.45      0.50      0.47     18396
# weighted avg       0.80      0.90      0.85     18396
#
# Hamming Loss: 0.10415307675581648
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94     16309
#            1       0.00      0.00      0.00      2087
#
#     accuracy                           0.89     18396
#    macro avg       0.44      0.50      0.47     18396
# weighted avg       0.79      0.89      0.83     18396
#
# Hamming Loss: 0.1134485757773429
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95     16680
#            1       0.00      0.00      0.00      1716
#
#     accuracy                           0.91     18396
#    macro avg       0.45      0.50      0.48     18396
# weighted avg       0.82      0.91      0.86     18396
#
# Hamming Loss: 0.09328114807566862
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB AGGREGATE
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94     82105
#            1       0.00      0.00      0.00      9876
#
#     accuracy                           0.89     91981
#    macro avg       0.45      0.50      0.47     91981
# weighted avg       0.80      0.89      0.84     91981
#
# Hamming Loss: 0.1073698882123201
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94     16232
#            1       0.00      0.00      0.00      2165
#
#     accuracy                           0.88     18397
#    macro avg       0.44      0.50      0.47     18397
# weighted avg       0.78      0.88      0.83     18397
#
# Hamming Loss: 0.11768223079849975
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94     16404
#            1       0.00      0.00      0.00      1992
#
#     accuracy                           0.89     18396
#    macro avg       0.45      0.50      0.47     18396
# weighted avg       0.80      0.89      0.84     18396
#
# Hamming Loss: 0.10828440965427266
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95     16480
#            1       0.00      0.00      0.00      1916
#
#     accuracy                           0.90     18396
#    macro avg       0.45      0.50      0.47     18396
# weighted avg       0.80      0.90      0.85     18396
#
# Hamming Loss: 0.10415307675581648
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94     16309
#            1       0.00      0.00      0.00      2087
#
#     accuracy                           0.89     18396
#    macro avg       0.44      0.50      0.47     18396
# weighted avg       0.79      0.89      0.83     18396
#
# Hamming Loss: 0.1134485757773429
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95     16680
#            1       0.00      0.00      0.00      1716
#
#     accuracy                           0.91     18396
#    macro avg       0.45      0.50      0.48     18396
# weighted avg       0.82      0.91      0.86     18396
#
# Hamming Loss: 0.09328114807566862
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA AGGREGATE
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94     82105
#            1       0.00      0.00      0.00      9876
#
#     accuracy                           0.89     91981
#    macro avg       0.45      0.50      0.47     91981
# weighted avg       0.80      0.89      0.84     91981
#
# Hamming Loss: 0.1073698882123201
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94     16232
#            1       0.00      0.00      0.00      2165
#
#     accuracy                           0.88     18397
#    macro avg       0.44      0.50      0.47     18397
# weighted avg       0.78      0.88      0.83     18397
#
# Hamming Loss: 0.11768223079849975
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94     16404
#            1       0.00      0.00      0.00      1992
#
#     accuracy                           0.89     18396
#    macro avg       0.45      0.50      0.47     18396
# weighted avg       0.80      0.89      0.84     18396
#
# Hamming Loss: 0.10828440965427266
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95     16480
#            1       0.00      0.00      0.00      1916
#
#     accuracy                           0.90     18396
#    macro avg       0.45      0.50      0.47     18396
# weighted avg       0.80      0.90      0.85     18396
#
# Hamming Loss: 0.10415307675581648
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94     16309
#            1       0.00      0.00      0.00      2087
#
#     accuracy                           0.89     18396
#    macro avg       0.44      0.50      0.47     18396
# weighted avg       0.79      0.89      0.83     18396
#
# Hamming Loss: 0.1134485757773429
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95     16680
#            1       0.00      0.00      0.00      1716
#
#     accuracy                           0.91     18396
#    macro avg       0.45      0.50      0.48     18396
# weighted avg       0.82      0.91      0.86     18396
#
# Hamming Loss: 0.09328114807566862
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest AGGREGATE
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94     82105
#            1       0.00      0.00      0.00      9876
#
#     accuracy                           0.89     91981
#    macro avg       0.45      0.50      0.47     91981
# weighted avg       0.80      0.89      0.84     91981
#
# Hamming Loss: 0.1073698882123201
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94     16232
#            1       0.00      0.00      0.00      2165
#
#     accuracy                           0.88     18397
#    macro avg       0.44      0.50      0.47     18397
# weighted avg       0.78      0.88      0.83     18397
#
# Hamming Loss: 0.11768223079849975
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94     16404
#            1       0.00      0.00      0.00      1992
#
#     accuracy                           0.89     18396
#    macro avg       0.45      0.50      0.47     18396
# weighted avg       0.80      0.89      0.84     18396
#
# Hamming Loss: 0.10828440965427266
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95     16480
#            1       0.00      0.00      0.00      1916
#
#     accuracy                           0.90     18396
#    macro avg       0.45      0.50      0.47     18396
# weighted avg       0.80      0.90      0.85     18396
#
# Hamming Loss: 0.10415307675581648
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94     16309
#            1       0.00      0.00      0.00      2087
#
#     accuracy                           0.89     18396
#    macro avg       0.44      0.50      0.47     18396
# weighted avg       0.79      0.89      0.83     18396
#
# Hamming Loss: 0.1134485757773429
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95     16680
#            1       0.00      0.00      0.00      1716
#
#     accuracy                           0.91     18396
#    macro avg       0.45      0.50      0.48     18396
# weighted avg       0.82      0.91      0.86     18396
#
# Hamming Loss: 0.09328114807566862
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN AGGREGATE
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94     82105
#            1       0.00      0.00      0.00      9876
#
#     accuracy                           0.89     91981
#    macro avg       0.45      0.50      0.47     91981
# weighted avg       0.80      0.89      0.84     91981
#
# Hamming Loss: 0.1073698882123201
# BRFSS MultiLabel Cancer + Diabetes - Grounded - SVM
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94     16232
#            1       0.00      0.00      0.00      2165
#
#     accuracy                           0.88     18397
#    macro avg       0.44      0.50      0.47     18397
# weighted avg       0.78      0.88      0.83     18397
#
# Hamming Loss: 0.11768223079849975
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - SVM
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94     16404
#            1       0.00      0.00      0.00      1992
#
#     accuracy                           0.89     18396
#    macro avg       0.45      0.50      0.47     18396
# weighted avg       0.80      0.89      0.84     18396
#
# Hamming Loss: 0.10828440965427266
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - SVM
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95     16480
#            1       0.00      0.00      0.00      1916
#
#     accuracy                           0.90     18396
#    macro avg       0.45      0.50      0.47     18396
# weighted avg       0.80      0.90      0.85     18396
#
# Hamming Loss: 0.10415307675581648
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - RUSBoost
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94     16404
#            1       0.00      0.00      0.00      1992
#
#     accuracy                           0.89     18396
#    macro avg       0.45      0.50      0.47     18396
# weighted avg       0.80      0.89      0.84     18396
#
# Hamming Loss: 0.10828440965427266
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - RUSBoost
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95     16480
#            1       0.00      0.00      0.00      1916
#
#     accuracy                           0.90     18396
#    macro avg       0.45      0.50      0.47     18396
# weighted avg       0.80      0.90      0.85     18396
#
# Hamming Loss: 0.10415307675581648
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - RUSBoost
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94     16309
#            1       0.00      0.00      0.00      2087
#
#     accuracy                           0.89     18396
#    macro avg       0.44      0.50      0.47     18396
# weighted avg       0.79      0.89      0.83     18396
#
# Hamming Loss: 0.1134485757773429
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - RUSBoost
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95     16680
#            1       0.00      0.00      0.00      1716
#
#     accuracy                           0.91     18396
#    macro avg       0.45      0.50      0.48     18396
# weighted avg       0.82      0.91      0.86     18396
#
# Hamming Loss: 0.09328114807566862
# y_pred shape:
# (18396, 2)
# y_pred2 shape:
# (5,)
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - RUSBoost AGGREGATE
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94     82105
#            1       0.00      0.00      0.00      9876
#
#     accuracy                           0.89     91981
#    macro avg       0.45      0.50      0.47     91981
# weighted avg       0.80      0.89      0.84     91981
#
# Hamming Loss: 0.1073698882123201
# BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94     16232
#            1       0.00      0.00      0.00      2165
#
#     accuracy                           0.88     18397
#    macro avg       0.44      0.50      0.47     18397
# weighted avg       0.78      0.88      0.83     18397
#
# Hamming Loss: 0.11768223079849975
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94     16404
#            1       0.00      0.00      0.00      1992
#
#     accuracy                           0.89     18396
#    macro avg       0.45      0.50      0.47     18396
# weighted avg       0.80      0.89      0.84     18396
#
# Hamming Loss: 0.10828440965427266
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95     16480
#            1       0.00      0.00      0.00      1916
#
#     accuracy                           0.90     18396
#    macro avg       0.45      0.50      0.47     18396
# weighted avg       0.80      0.90      0.85     18396
#
# Hamming Loss: 0.10415307675581648
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94     16309
#            1       0.00      0.00      0.00      2087
#
#     accuracy                           0.89     18396
#    macro avg       0.44      0.50      0.47     18396
# weighted avg       0.79      0.89      0.83     18396
#
# Hamming Loss: 0.1134485757773429
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95     16680
#            1       0.00      0.00      0.00      1716
#
#     accuracy                           0.91     18396
#    macro avg       0.45      0.50      0.48     18396
# weighted avg       0.82      0.91      0.86     18396
#
# Hamming Loss: 0.09328114807566862
# y_pred shape:
# (18396, 2)
# y_pred2 shape:
# (5,)
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - ADABoost AGGREGATE
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94     82105
#            1       0.00      0.00      0.00      9876
#
#     accuracy                           0.89     91981
#    macro avg       0.45      0.50      0.47     91981
# weighted avg       0.80      0.89      0.84     91981
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Hamming Loss: 0.1073698882123201

# %%
import os
import pandas as pd

folder = "C:/Users/mdjaw/OneDrive/Documents/Markian Training/Research_USQ/USCenterDiseaseControlPrevention/LLCP2019XPT" 
os.chdir(folder)

BRFSS_Grounded = pd.read_csv("LLCP2019XPT_Grounded_ML_nona.csv")

print(BRFSS_Grounded.shape)

BRFSS_Grounded_X = BRFSS_Grounded.drop(['CNCRTYP1', 'DIABETE4'], axis = 1)

print(BRFSS_Grounded_X.shape)
# Out:
# (27574, 75)
# (27574, 73)

# %%
from sklearn.datasets import make_multilabel_classification
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.neural_network import MLPRegressor
from imblearn.ensemble import RUSBoostClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import hamming_loss
from sklearn.model_selection import KFold
from sklearn.metrics import classification_report
import numpy as np


X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = LogisticRegression(C=1.0, penalty='l1', dual=False, solver='liblinear')
  model = OneVsRestClassifier(model)    
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
print("y_pred shape: ")
print(np.shape(y_pred))

print("y_pred2 shape:")
print(np.shape(y_pred2))

y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = MultinomialNB()
  model = OneVsRestClassifier(MultinomialNB())   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
   
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
              solver='svd', store_covariance=False, tol=0.0001))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))
    
X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(RandomForestClassifier(max_depth=100, random_state=0))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))
    
X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(KNeighborsClassifier(n_neighbors=5))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

a = []
b = []
X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(SVC())   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded - SVM")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))  
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - SVM AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  #model = MultinomialNB()
  model = OneVsRestClassifier(RUSBoostClassifier(random_state=0))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded - RUSBoost")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
   
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
print("y_pred shape: ")
print(np.shape(y_pred))

print("y_pred2 shape:")
print(np.shape(y_pred2))

y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - RUSBoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  #model = OneVsRestClassifier(AdaBoostClassifier(n_estimators=50,learning_rate=1))   
  
  model = OneVsRestClassifier(AdaBoostClassifier(n_estimators=200,learning_rate=1))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
   
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
print("y_pred shape: ")
print(np.shape(y_pred))

print("y_pred2 shape:")
print(np.shape(y_pred2))

y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - ADABoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))
# Out:
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92      4720
#            1       0.00      0.00      0.00       795
#
#     accuracy                           0.86      5515
#    macro avg       0.43      0.50      0.46      5515
# weighted avg       0.73      0.86      0.79      5515
#
# Hamming Loss: 0.1441523118766999
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.93      4764
#            1       0.00      0.00      0.00       751
#
#     accuracy                           0.86      5515
#    macro avg       0.43      0.50      0.46      5515
# weighted avg       0.75      0.86      0.80      5515
#
# Hamming Loss: 0.13617407071622847
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92      4722
#            1       0.00      0.00      0.00       793
#
#     accuracy                           0.86      5515
#    macro avg       0.43      0.50      0.46      5515
# weighted avg       0.73      0.86      0.79      5515
#
# Hamming Loss: 0.14378966455122394
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94      4853
#            1       0.00      0.00      0.00       662
#
#     accuracy                           0.88      5515
#    macro avg       0.44      0.50      0.47      5515
# weighted avg       0.77      0.88      0.82      5515
#
# Hamming Loss: 0.1200362647325476
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94      4873
#            1       0.00      0.00      0.00       641
#
#     accuracy                           0.88      5514
#    macro avg       0.44      0.50      0.47      5514
# weighted avg       0.78      0.88      0.83      5514
#
# Hamming Loss: 0.11624954660863257
# y_pred shape:
# (5514, 2)
# y_pred2 shape:
# (5,)
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression AGGREGATE
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93     23932
#            1       0.00      0.00      0.00      3642
#
#     accuracy                           0.87     27574
#    macro avg       0.43      0.50      0.46     27574
# weighted avg       0.75      0.87      0.81     27574
#
# Hamming Loss: 0.13208037169706652
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92      4720
#            1       0.00      0.00      0.00       795
#
#     accuracy                           0.86      5515
#    macro avg       0.43      0.50      0.46      5515
# weighted avg       0.73      0.86      0.79      5515
#
# Hamming Loss: 0.1441523118766999
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.93      4764
#            1       0.00      0.00      0.00       751
#
#     accuracy                           0.86      5515
#    macro avg       0.43      0.50      0.46      5515
# weighted avg       0.75      0.86      0.80      5515
#
# Hamming Loss: 0.13617407071622847
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92      4722
#            1       0.00      0.00      0.00       793
#
#     accuracy                           0.86      5515
#    macro avg       0.43      0.50      0.46      5515
# weighted avg       0.73      0.86      0.79      5515
#
# Hamming Loss: 0.14378966455122394
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94      4853
#            1       0.00      0.00      0.00       662
#
#     accuracy                           0.88      5515
#    macro avg       0.44      0.50      0.47      5515
# weighted avg       0.77      0.88      0.82      5515
#
# Hamming Loss: 0.1200362647325476
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94      4873
#            1       0.00      0.00      0.00       641
#
#     accuracy                           0.88      5514
#    macro avg       0.44      0.50      0.47      5514
# weighted avg       0.78      0.88      0.83      5514
#
# Hamming Loss: 0.11624954660863257
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB AGGREGATE
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93     23932
#            1       0.00      0.00      0.00      3642
#
#     accuracy                           0.87     27574
#    macro avg       0.43      0.50      0.46     27574
# weighted avg       0.75      0.87      0.81     27574
#
# Hamming Loss: 0.13208037169706652
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92      4720
#            1       0.00      0.00      0.00       795
#
#     accuracy                           0.86      5515
#    macro avg       0.43      0.50      0.46      5515
# weighted avg       0.73      0.86      0.79      5515
#
# Hamming Loss: 0.1441523118766999
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.93      4764
#            1       0.00      0.00      0.00       751
#
#     accuracy                           0.86      5515
#    macro avg       0.43      0.50      0.46      5515
# weighted avg       0.75      0.86      0.80      5515
#
# Hamming Loss: 0.13617407071622847
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92      4722
#            1       0.00      0.00      0.00       793
#
#     accuracy                           0.86      5515
#    macro avg       0.43      0.50      0.46      5515
# weighted avg       0.73      0.86      0.79      5515
#
# Hamming Loss: 0.14378966455122394
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94      4853
#            1       0.00      0.00      0.00       662
#
#     accuracy                           0.88      5515
#    macro avg       0.44      0.50      0.47      5515
# weighted avg       0.77      0.88      0.82      5515
#
# Hamming Loss: 0.1200362647325476
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94      4873
#            1       0.00      0.00      0.00       641
#
#     accuracy                           0.88      5514
#    macro avg       0.44      0.50      0.47      5514
# weighted avg       0.78      0.88      0.83      5514
#
# Hamming Loss: 0.11624954660863257
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA AGGREGATE
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93     23932
#            1       0.00      0.00      0.00      3642
#
#     accuracy                           0.87     27574
#    macro avg       0.43      0.50      0.46     27574
# weighted avg       0.75      0.87      0.81     27574
#
# Hamming Loss: 0.13208037169706652
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92      4720
#            1       0.00      0.00      0.00       795
#
#     accuracy                           0.86      5515
#    macro avg       0.43      0.50      0.46      5515
# weighted avg       0.73      0.86      0.79      5515
#
# Hamming Loss: 0.1441523118766999
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.93      4764
#            1       0.00      0.00      0.00       751
#
#     accuracy                           0.86      5515
#    macro avg       0.43      0.50      0.46      5515
# weighted avg       0.75      0.86      0.80      5515
#
# Hamming Loss: 0.13617407071622847
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92      4722
#            1       0.00      0.00      0.00       793
#
#     accuracy                           0.86      5515
#    macro avg       0.43      0.50      0.46      5515
# weighted avg       0.73      0.86      0.79      5515
#
# Hamming Loss: 0.14378966455122394
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94      4853
#            1       0.00      0.00      0.00       662
#
#     accuracy                           0.88      5515
#    macro avg       0.44      0.50      0.47      5515
# weighted avg       0.77      0.88      0.82      5515
#
# Hamming Loss: 0.1200362647325476
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94      4873
#            1       0.00      0.00      0.00       641
#
#     accuracy                           0.88      5514
#    macro avg       0.44      0.50      0.47      5514
# weighted avg       0.78      0.88      0.83      5514
#
# Hamming Loss: 0.11624954660863257
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest AGGREGATE
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93     23932
#            1       0.00      0.00      0.00      3642
#
#     accuracy                           0.87     27574
#    macro avg       0.43      0.50      0.46     27574
# weighted avg       0.75      0.87      0.81     27574
#
# Hamming Loss: 0.13208037169706652
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92      4720
#            1       0.00      0.00      0.00       795
#
#     accuracy                           0.86      5515
#    macro avg       0.43      0.50      0.46      5515
# weighted avg       0.73      0.86      0.79      5515
#
# Hamming Loss: 0.1441523118766999
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.93      4764
#            1       0.00      0.00      0.00       751
#
#     accuracy                           0.86      5515
#    macro avg       0.43      0.50      0.46      5515
# weighted avg       0.75      0.86      0.80      5515
#
# Hamming Loss: 0.13617407071622847
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92      4722
#            1       0.00      0.00      0.00       793
#
#     accuracy                           0.86      5515
#    macro avg       0.43      0.50      0.46      5515
# weighted avg       0.73      0.86      0.79      5515
#
# Hamming Loss: 0.14378966455122394
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94      4853
#            1       0.00      0.00      0.00       662
#
#     accuracy                           0.88      5515
#    macro avg       0.44      0.50      0.47      5515
# weighted avg       0.77      0.88      0.82      5515
#
# Hamming Loss: 0.1200362647325476
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94      4873
#            1       0.00      0.00      0.00       641
#
#     accuracy                           0.88      5514
#    macro avg       0.44      0.50      0.47      5514
# weighted avg       0.78      0.88      0.83      5514
#
# Hamming Loss: 0.11624954660863257
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN AGGREGATE
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93     23932
#            1       0.00      0.00      0.00      3642
#
#     accuracy                           0.87     27574
#    macro avg       0.43      0.50      0.46     27574
# weighted avg       0.75      0.87      0.81     27574
#
# Hamming Loss: 0.13208037169706652
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - SVM
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92      4720
#            1       0.00      0.00      0.00       795
#
#     accuracy                           0.86      5515
#    macro avg       0.43      0.50      0.46      5515
# weighted avg       0.73      0.86      0.79      5515
#
# ...
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - RUSBoost
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92      4722
#            1       0.00      0.00      0.00       793
#
#     accuracy                           0.86      5515
#    macro avg       0.43      0.50      0.46      5515
# weighted avg       0.73      0.86      0.79      5515
#
# Hamming Loss: 0.14378966455122394
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - RUSBoost
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94      4853
#            1       0.00      0.00      0.00       662
#
#     accuracy                           0.88      5515
#    macro avg       0.44      0.50      0.47      5515
# weighted avg       0.77      0.88      0.82      5515
#
# Hamming Loss: 0.1200362647325476
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - RUSBoost
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94      4873
#            1       0.00      0.00      0.00       641
#
#     accuracy                           0.88      5514
#    macro avg       0.44      0.50      0.47      5514
# weighted avg       0.78      0.88      0.83      5514
#
# Hamming Loss: 0.11624954660863257
# y_pred shape:
# (5514, 2)
# y_pred2 shape:
# (5,)
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - RUSBoost AGGREGATE
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93     23932
#            1       0.00      0.00      0.00      3642
#
#     accuracy                           0.87     27574
#    macro avg       0.43      0.50      0.46     27574
# weighted avg       0.75      0.87      0.81     27574
#
# Hamming Loss: 0.13208037169706652
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92      4720
#            1       0.00      0.00      0.00       795
#
#     accuracy                           0.86      5515
#    macro avg       0.43      0.50      0.46      5515
# weighted avg       0.73      0.86      0.79      5515
#
# Hamming Loss: 0.1441523118766999
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.93      4764
#            1       0.00      0.00      0.00       751
#
#     accuracy                           0.86      5515
#    macro avg       0.43      0.50      0.46      5515
# weighted avg       0.75      0.86      0.80      5515
#
# Hamming Loss: 0.13617407071622847
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92      4722
#            1       0.00      0.00      0.00       793
#
#     accuracy                           0.86      5515
#    macro avg       0.43      0.50      0.46      5515
# weighted avg       0.73      0.86      0.79      5515
#
# Hamming Loss: 0.14378966455122394
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94      4853
#            1       0.00      0.00      0.00       662
#
#     accuracy                           0.88      5515
#    macro avg       0.44      0.50      0.47      5515
# weighted avg       0.77      0.88      0.82      5515
#
# Hamming Loss: 0.1200362647325476
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94      4873
#            1       0.00      0.00      0.00       641
#
#     accuracy                           0.88      5514
#    macro avg       0.44      0.50      0.47      5514
# weighted avg       0.78      0.88      0.83      5514
#
# Hamming Loss: 0.11624954660863257
# y_pred shape:
# (5514, 2)
# y_pred2 shape:
# (5,)
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - ADABoost AGGREGATE
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93     23932
#            1       0.00      0.00      0.00      3642
#
#     accuracy                           0.87     27574
#    macro avg       0.43      0.50      0.46     27574
# weighted avg       0.75      0.87      0.81     27574
#
# Hamming Loss: 0.13208037169706652
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
import os
import pandas as pd

folder = "C:/Users/mdjaw/OneDrive/Documents/Markian Training/Research_USQ/USCenterDiseaseControlPrevention/LLCP2019XPT" 
os.chdir(folder)

BRFSS_Grounded = pd.read_csv("LLCP2019XPT_Grounded_KGFS10.csv")

print(BRFSS_Grounded.shape)

BRFSS_Grounded_X = BRFSS_Grounded.drop(['CNCRTYP1', 'DIABETE4'], axis = 1)

print(BRFSS_Grounded_X.shape)
# Out:
# (134086, 7)
# (134086, 5)

# %%
from sklearn.datasets import make_multilabel_classification
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.neural_network import MLPRegressor
from imblearn.ensemble import RUSBoostClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import hamming_loss
from sklearn.model_selection import KFold
from sklearn.metrics import classification_report
import numpy as np


X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = LogisticRegression(C=1.0, penalty='l1', dual=False, solver='liblinear')
  model = OneVsRestClassifier(model)    
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
print("y_pred shape: ")
print(np.shape(y_pred))

print("y_pred2 shape:")
print(np.shape(y_pred2))

y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = MultinomialNB()
  model = OneVsRestClassifier(MultinomialNB())   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
   
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
              solver='svd', store_covariance=False, tol=0.0001))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))
    
X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(RandomForestClassifier(max_depth=100, random_state=0))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))
    
X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(KNeighborsClassifier(n_neighbors=5))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

a = []
b = []
X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(SVC())   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded - SVM")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))  
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - SVM AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  #model = MultinomialNB()
  model = OneVsRestClassifier(RUSBoostClassifier(random_state=0))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded - RUSBoost")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
   
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
print("y_pred shape: ")
print(np.shape(y_pred))

print("y_pred2 shape:")
print(np.shape(y_pred2))

y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - RUSBoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  #model = OneVsRestClassifier(AdaBoostClassifier(n_estimators=50,learning_rate=1))   
  
  model = OneVsRestClassifier(AdaBoostClassifier(n_estimators=200,learning_rate=1))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
   
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
print("y_pred shape: ")
print(np.shape(y_pred))

print("y_pred2 shape:")
print(np.shape(y_pred2))

y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - ADABoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))
# Out:
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.93     23123
#            1       0.00      0.00      0.00      3695
#
#     accuracy                           0.86     26818
#    macro avg       0.43      0.50      0.46     26818
# weighted avg       0.74      0.86      0.80     26818
#
# Hamming Loss: 0.1377805951226788
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\svm\_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93     23387
#            1       0.00      0.00      0.00      3430
#
#     accuracy                           0.87     26817
#    macro avg       0.44      0.50      0.47     26817
# weighted avg       0.76      0.87      0.81     26817
#
# Hamming Loss: 0.12790394152962672
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94     23590
#            1       0.00      0.00      0.00      3227
#
#     accuracy                           0.88     26817
#    macro avg       0.44      0.50      0.47     26817
# weighted avg       0.77      0.88      0.82     26817
#
# Hamming Loss: 0.12033411641868964
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.93     23176
#            1       0.00      0.00      0.00      3641
#
#     accuracy                           0.86     26817
#    macro avg       0.43      0.50      0.46     26817
# weighted avg       0.75      0.86      0.80     26817
#
# Hamming Loss: 0.13577208487153672
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94     23908
#            1       0.00      0.00      0.00      2909
#
#     accuracy                           0.89     26817
#    macro avg       0.45      0.50      0.47     26817
# weighted avg       0.79      0.89      0.84     26817
#
# Hamming Loss: 0.10847596673751725
# y_pred shape:
# (26817, 2)
# y_pred2 shape:
# (5,)
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression AGGREGATE
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93    117184
#            1       0.00      0.00      0.00     16902
#
#     accuracy                           0.87    134086
#    macro avg       0.44      0.50      0.47    134086
# weighted avg       0.76      0.87      0.82    134086
#
# Hamming Loss: 0.1260533409360098
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.93     23123
#            1       0.00      0.00      0.00      3695
#
#     accuracy                           0.86     26818
#    macro avg       0.43      0.50      0.46     26818
# weighted avg       0.74      0.86      0.80     26818
#
# Hamming Loss: 0.1377805951226788
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93     23387
#            1       0.00      0.00      0.00      3430
#
#     accuracy                           0.87     26817
#    macro avg       0.44      0.50      0.47     26817
# weighted avg       0.76      0.87      0.81     26817
#
# Hamming Loss: 0.12790394152962672
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94     23590
#            1       0.00      0.00      0.00      3227
#
#     accuracy                           0.88     26817
#    macro avg       0.44      0.50      0.47     26817
# weighted avg       0.77      0.88      0.82     26817
#
# Hamming Loss: 0.12033411641868964
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.93     23176
#            1       0.00      0.00      0.00      3641
#
#     accuracy                           0.86     26817
#    macro avg       0.43      0.50      0.46     26817
# weighted avg       0.75      0.86      0.80     26817
#
# Hamming Loss: 0.13577208487153672
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94     23908
#            1       0.00      0.00      0.00      2909
#
#     accuracy                           0.89     26817
#    macro avg       0.45      0.50      0.47     26817
# weighted avg       0.79      0.89      0.84     26817
#
# Hamming Loss: 0.10847596673751725
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB AGGREGATE
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93    117184
#            1       0.00      0.00      0.00     16902
#
#     accuracy                           0.87    134086
#    macro avg       0.44      0.50      0.47    134086
# weighted avg       0.76      0.87      0.82    134086
#
# Hamming Loss: 0.1260533409360098
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.93     23123
#            1       0.00      0.00      0.00      3695
#
#     accuracy                           0.86     26818
#    macro avg       0.43      0.50      0.46     26818
# weighted avg       0.74      0.86      0.80     26818
#
# Hamming Loss: 0.1377805951226788
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93     23387
#            1       0.00      0.00      0.00      3430
#
#     accuracy                           0.87     26817
#    macro avg       0.44      0.50      0.47     26817
# weighted avg       0.76      0.87      0.81     26817
#
# Hamming Loss: 0.12790394152962672
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94     23590
#            1       0.00      0.00      0.00      3227
#
#     accuracy                           0.88     26817
#    macro avg       0.44      0.50      0.47     26817
# weighted avg       0.77      0.88      0.82     26817
#
# Hamming Loss: 0.12033411641868964
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.93     23176
#            1       0.00      0.00      0.00      3641
#
#     accuracy                           0.86     26817
#    macro avg       0.43      0.50      0.46     26817
# weighted avg       0.75      0.86      0.80     26817
#
# Hamming Loss: 0.13577208487153672
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94     23908
#            1       0.00      0.00      0.00      2909
#
#     accuracy                           0.89     26817
#    macro avg       0.45      0.50      0.47     26817
# weighted avg       0.79      0.89      0.84     26817
#
# Hamming Loss: 0.10847596673751725
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA AGGREGATE
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93    117184
#            1       0.00      0.00      0.00     16902
#
#     accuracy                           0.87    134086
#    macro avg       0.44      0.50      0.47    134086
# weighted avg       0.76      0.87      0.82    134086
#
# Hamming Loss: 0.1260533409360098
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.93     23123
#            1       0.00      0.00      0.00      3695
#
#     accuracy                           0.86     26818
#    macro avg       0.43      0.50      0.46     26818
# weighted avg       0.74      0.86      0.80     26818
#
# Hamming Loss: 0.1377805951226788
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93     23387
#            1       0.00      0.00      0.00      3430
#
#     accuracy                           0.87     26817
#    macro avg       0.44      0.50      0.47     26817
# weighted avg       0.76      0.87      0.81     26817
#
# Hamming Loss: 0.12790394152962672
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94     23590
#            1       0.00      0.00      0.00      3227
#
#     accuracy                           0.88     26817
#    macro avg       0.44      0.50      0.47     26817
# weighted avg       0.77      0.88      0.82     26817
#
# Hamming Loss: 0.12033411641868964
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.93     23176
#            1       0.00      0.00      0.00      3641
#
#     accuracy                           0.86     26817
#    macro avg       0.43      0.50      0.46     26817
# weighted avg       0.75      0.86      0.80     26817
#
# Hamming Loss: 0.13577208487153672
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94     23908
#            1       0.00      0.00      0.00      2909
#
#     accuracy                           0.89     26817
#    macro avg       0.45      0.50      0.47     26817
# weighted avg       0.79      0.89      0.84     26817
#
# Hamming Loss: 0.10847596673751725
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest AGGREGATE
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93    117184
#            1       0.00      0.00      0.00     16902
#
#     accuracy                           0.87    134086
#    macro avg       0.44      0.50      0.47    134086
# weighted avg       0.76      0.87      0.82    134086
#
# Hamming Loss: 0.1260533409360098
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.93     23123
#            1       0.00      0.00      0.00      3695
#
#     accuracy                           0.86     26818
#    macro avg       0.43      0.50      0.46     26818
# weighted avg       0.74      0.86      0.80     26818
#
# Hamming Loss: 0.1377805951226788
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93     23387
#            1       0.00      0.00      0.00      3430
#
#     accuracy                           0.87     26817
#    macro avg       0.44      0.50      0.47     26817
# weighted avg       0.76      0.87      0.81     26817
#
# Hamming Loss: 0.12790394152962672
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94     23590
#            1       0.00      0.00      0.00      3227
#
#     accuracy                           0.88     26817
#    macro avg       0.44      0.50      0.47     26817
# weighted avg       0.77      0.88      0.82     26817
#
# Hamming Loss: 0.12033411641868964
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.93     23176
#            1       0.00      0.00      0.00      3641
#
#     accuracy                           0.86     26817
#    macro avg       0.43      0.50      0.46     26817
# weighted avg       0.75      0.86      0.80     26817
#
# Hamming Loss: 0.13577208487153672
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94     23908
#            1       0.00      0.00      0.00      2909
#
#     accuracy                           0.89     26817
#    macro avg       0.45      0.50      0.47     26817
# weighted avg       0.79      0.89      0.84     26817
#
# Hamming Loss: 0.10847596673751725
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN AGGREGATE
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93    117184
#            1       0.00      0.00      0.00     16902
#
#     accuracy                           0.87    134086
#    macro avg       0.44      0.50      0.47    134086
# weighted avg       0.76      0.87      0.82    134086
#
# Hamming Loss: 0.1260533409360098
# BRFSS MultiLabel Cancer + Diabetes - Grounded - SVM
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.93     23123
#            1       0.00      0.00      0.00      3695
#
#     accuracy                           0.86     26818
#    macro avg       0.43      0.50      0.46     26818
# weighted avg       0.74      0.86      0.80     26818
#
# Hamming Loss: 0.1377805951226788
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - SVM
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93     23387
#            1       0.00      0.00      0.00      3430
#
#     accuracy                           0.87     26817
#    macro avg       0.44      0.50      0.47     26817
# weighted avg       0.76      0.87      0.81     26817
#
# Hamming Loss: 0.12790394152962672
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - SVM
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94     23590
#            1       0.00      0.00      0.00      3227
#
#     accuracy                           0.88     26817
#    macro avg       0.44      0.50      0.47     26817
# weighted avg       0.77      0.88      0.82     26817
#
# Hamming Loss: 0.12033411641868964
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - RUSBoost
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93     23387
#            1       0.00      0.00      0.00      3430
#
#     accuracy                           0.87     26817
#    macro avg       0.44      0.50      0.47     26817
# weighted avg       0.76      0.87      0.81     26817
#
# Hamming Loss: 0.12790394152962672
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - RUSBoost
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94     23590
#            1       0.00      0.00      0.00      3227
#
#     accuracy                           0.88     26817
#    macro avg       0.44      0.50      0.47     26817
# weighted avg       0.77      0.88      0.82     26817
#
# Hamming Loss: 0.12033411641868964
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - RUSBoost
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.93     23176
#            1       0.00      0.00      0.00      3641
#
#     accuracy                           0.86     26817
#    macro avg       0.43      0.50      0.46     26817
# weighted avg       0.75      0.86      0.80     26817
#
# Hamming Loss: 0.13577208487153672
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - RUSBoost
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94     23908
#            1       0.00      0.00      0.00      2909
#
#     accuracy                           0.89     26817
#    macro avg       0.45      0.50      0.47     26817
# weighted avg       0.79      0.89      0.84     26817
#
# Hamming Loss: 0.10847596673751725
# y_pred shape:
# (26817, 2)
# y_pred2 shape:
# (5,)
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - RUSBoost AGGREGATE
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93    117184
#            1       0.00      0.00      0.00     16902
#
#     accuracy                           0.87    134086
#    macro avg       0.44      0.50      0.47    134086
# weighted avg       0.76      0.87      0.82    134086
#
# Hamming Loss: 0.1260533409360098
# BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.93     23123
#            1       0.00      0.00      0.00      3695
#
#     accuracy                           0.86     26818
#    macro avg       0.43      0.50      0.46     26818
# weighted avg       0.74      0.86      0.80     26818
#
# Hamming Loss: 0.1377805951226788
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93     23387
#            1       0.00      0.00      0.00      3430
#
#     accuracy                           0.87     26817
#    macro avg       0.44      0.50      0.47     26817
# weighted avg       0.76      0.87      0.81     26817
#
# Hamming Loss: 0.12790394152962672
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94     23590
#            1       0.00      0.00      0.00      3227
#
#     accuracy                           0.88     26817
#    macro avg       0.44      0.50      0.47     26817
# weighted avg       0.77      0.88      0.82     26817
#
# Hamming Loss: 0.12033411641868964
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.93     23176
#            1       0.00      0.00      0.00      3641
#
#     accuracy                           0.86     26817
#    macro avg       0.43      0.50      0.46     26817
# weighted avg       0.75      0.86      0.80     26817
#
# Hamming Loss: 0.13577208487153672
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94     23908
#            1       0.00      0.00      0.00      2909
#
#     accuracy                           0.89     26817
#    macro avg       0.45      0.50      0.47     26817
# weighted avg       0.79      0.89      0.84     26817
#
# Hamming Loss: 0.10847596673751725
# y_pred shape:
# (26817, 2)
# y_pred2 shape:
# (5,)
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - ADABoost AGGREGATE
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93    117184
#            1       0.00      0.00      0.00     16902
#
#     accuracy                           0.87    134086
#    macro avg       0.44      0.50      0.47    134086
# weighted avg       0.76      0.87      0.82    134086
#
# Hamming Loss: 0.1260533409360098
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
import os
import pandas as pd

folder = "C:/Users/mdjaw/OneDrive/Documents/Markian Training/Research_USQ/USCenterDiseaseControlPrevention/LLCP2019XPT" 
os.chdir(folder)

BRFSS_Grounded = pd.read_csv("LLCP2019XPT_Grounded_KGFS20.csv")

print(BRFSS_Grounded.shape)

BRFSS_Grounded_X = BRFSS_Grounded.drop(['CNCRTYP1', 'DIABETE4'], axis = 1)

print(BRFSS_Grounded_X.shape)

# %%
from sklearn.datasets import make_multilabel_classification
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.neural_network import MLPRegressor
from imblearn.ensemble import RUSBoostClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import hamming_loss
from sklearn.model_selection import KFold
from sklearn.metrics import classification_report
import numpy as np


X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = LogisticRegression(C=1.0, penalty='l1', dual=False, solver='liblinear')
  model = OneVsRestClassifier(model)    
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
print("y_pred shape: ")
print(np.shape(y_pred))

print("y_pred2 shape:")
print(np.shape(y_pred2))

y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = MultinomialNB()
  model = OneVsRestClassifier(MultinomialNB())   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
   
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
              solver='svd', store_covariance=False, tol=0.0001))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))
    
X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(RandomForestClassifier(max_depth=100, random_state=0))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))
    
X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(KNeighborsClassifier(n_neighbors=5))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

a = []
b = []
X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(SVC())   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded - SVM")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))  
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - SVM AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  #model = MultinomialNB()
  model = OneVsRestClassifier(RUSBoostClassifier(random_state=0))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded - RUSBoost")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
   
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
print("y_pred shape: ")
print(np.shape(y_pred))

print("y_pred2 shape:")
print(np.shape(y_pred2))

y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - RUSBoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  #model = OneVsRestClassifier(AdaBoostClassifier(n_estimators=50,learning_rate=1))   
  
  model = OneVsRestClassifier(AdaBoostClassifier(n_estimators=200,learning_rate=1))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
   
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
print("y_pred shape: ")
print(np.shape(y_pred))

print("y_pred2 shape:")
print(np.shape(y_pred2))

y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - ADABoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

# %%
import os
import pandas as pd

folder = "C:/Users/mdjaw/OneDrive/Documents/Markian Training/Research_USQ/USCenterDiseaseControlPrevention/LLCP2019XPT" 
os.chdir(folder)

BRFSS_Grounded = pd.read_csv("LLCP2019XPT_Grounded_KGFS15.csv")

print(BRFSS_Grounded.shape)

BRFSS_Grounded_X = BRFSS_Grounded.drop(['CNCRTYP1', 'DIABETE4'], axis = 1)

print(BRFSS_Grounded_X.shape)

# %%
from sklearn.datasets import make_multilabel_classification
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.neural_network import MLPRegressor
from imblearn.ensemble import RUSBoostClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import hamming_loss
from sklearn.model_selection import KFold
from sklearn.metrics import classification_report
import numpy as np


X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = LogisticRegression(C=1.0, penalty='l1', dual=False, solver='liblinear')
  model = OneVsRestClassifier(model)    
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
print("y_pred shape: ")
print(np.shape(y_pred))

print("y_pred2 shape:")
print(np.shape(y_pred2))

y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = MultinomialNB()
  model = OneVsRestClassifier(MultinomialNB())   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
   
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
              solver='svd', store_covariance=False, tol=0.0001))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))
    
X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(RandomForestClassifier(max_depth=100, random_state=0))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))
    
X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(KNeighborsClassifier(n_neighbors=5))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

a = []
b = []
X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(SVC())   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded - SVM")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))  
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - SVM AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  #model = MultinomialNB()
  model = OneVsRestClassifier(RUSBoostClassifier(random_state=0))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded - RUSBoost")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
   
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
print("y_pred shape: ")
print(np.shape(y_pred))

print("y_pred2 shape:")
print(np.shape(y_pred2))

y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - RUSBoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  #model = OneVsRestClassifier(AdaBoostClassifier(n_estimators=50,learning_rate=1))   
  
  model = OneVsRestClassifier(AdaBoostClassifier(n_estimators=200,learning_rate=1))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
   
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
print("y_pred shape: ")
print(np.shape(y_pred))

print("y_pred2 shape:")
print(np.shape(y_pred2))

y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - ADABoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-ecbe20b2f62b> in <module>
#      22
#      23
# ---> 24 X = np.array(BRFSS_Grounded_X)
#      25 y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()
#      26
#
# NameError: name 'BRFSS_Grounded_X' is not defined

# %%
import os
import pandas as pd

folder = "C:/Users/mdjaw/OneDrive/Documents/Markian Training/Research_USQ/USCenterDiseaseControlPrevention/LLCP2019XPT" 
os.chdir(folder)

BRFSS_Grounded = pd.read_csv("LLCP2019XPT_Grounded_KGFS5.csv")

print(BRFSS_Grounded.shape)

BRFSS_Grounded_X = BRFSS_Grounded.drop(['CNCRTYP1', 'DIABETE4'], axis = 1)

print(BRFSS_Grounded_X.shape)
# Out:
# (212081, 4)
# (212081, 2)

# %%
from sklearn.datasets import make_multilabel_classification
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.neural_network import MLPRegressor
from imblearn.ensemble import RUSBoostClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import hamming_loss
from sklearn.model_selection import KFold
from sklearn.metrics import classification_report
import numpy as np


X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = LogisticRegression(C=1.0, penalty='l1', dual=False, solver='liblinear')
  model = OneVsRestClassifier(model)    
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
print("y_pred shape: ")
print(np.shape(y_pred))

print("y_pred2 shape:")
print(np.shape(y_pred2))

y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = MultinomialNB()
  model = OneVsRestClassifier(MultinomialNB())   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
   
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
              solver='svd', store_covariance=False, tol=0.0001))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))
    
X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(RandomForestClassifier(max_depth=100, random_state=0))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))
    
X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(KNeighborsClassifier(n_neighbors=5))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

a = []
b = []
X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(SVC())   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded - SVM")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))  
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - SVM AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  #model = MultinomialNB()
  model = OneVsRestClassifier(RUSBoostClassifier(random_state=0))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded - RUSBoost")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
   
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
print("y_pred shape: ")
print(np.shape(y_pred))

print("y_pred2 shape:")
print(np.shape(y_pred2))

y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - RUSBoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  #model = OneVsRestClassifier(AdaBoostClassifier(n_estimators=50,learning_rate=1))   
  
  model = OneVsRestClassifier(AdaBoostClassifier(n_estimators=200,learning_rate=1))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
   
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
print("y_pred shape: ")
print(np.shape(y_pred))

print("y_pred2 shape:")
print(np.shape(y_pred2))

y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - ADABoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))
# Out:
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\svm\_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92     35929
#            1       0.00      0.00      0.00      6488
#
#     accuracy                           0.85     42417
#    macro avg       0.42      0.50      0.46     42417
# weighted avg       0.72      0.85      0.78     42417
#
# Hamming Loss: 0.1529575406087182
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\svm\_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92     36367
#            1       0.00      0.00      0.00      6049
#
#     accuracy                           0.86     42416
#    macro avg       0.43      0.50      0.46     42416
# weighted avg       0.74      0.86      0.79     42416
#
# Hamming Loss: 0.14261127876273105
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\svm\_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92     36278
#            1       0.00      0.00      0.00      6138
#
#     accuracy                           0.86     42416
#    macro avg       0.43      0.50      0.46     42416
# weighted avg       0.73      0.86      0.79     42416
#
# Hamming Loss: 0.14470954356846474
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\svm\_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.84      1.00      0.91     35714
#            1       0.00      0.00      0.00      6702
#
#     accuracy                           0.84     42416
#    macro avg       0.42      0.50      0.46     42416
# weighted avg       0.71      0.84      0.77     42416
#
# Hamming Loss: 0.15800641267446247
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93     37082
#            1       0.00      0.00      0.00      5334
#
#     accuracy                           0.87     42416
#    macro avg       0.44      0.50      0.47     42416
# weighted avg       0.76      0.87      0.82     42416
#
# Hamming Loss: 0.125754432289702
# y_pred shape:
# (42416, 2)
# y_pred2 shape:
# (5,)
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression AGGREGATE
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92    181370
#            1       0.00      0.00      0.00     30711
#
#     accuracy                           0.86    212081
#    macro avg       0.43      0.50      0.46    212081
# weighted avg       0.73      0.86      0.79    212081
#
# Hamming Loss: 0.1448078415808157
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92     35929
#            1       0.00      0.00      0.00      6488
#
#     accuracy                           0.85     42417
#    macro avg       0.42      0.50      0.46     42417
# weighted avg       0.72      0.85      0.78     42417
#
# Hamming Loss: 0.1529575406087182
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92     36367
#            1       0.00      0.00      0.00      6049
#
#     accuracy                           0.86     42416
#    macro avg       0.43      0.50      0.46     42416
# weighted avg       0.74      0.86      0.79     42416
#
# Hamming Loss: 0.14261127876273105
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92     36278
#            1       0.00      0.00      0.00      6138
#
#     accuracy                           0.86     42416
#    macro avg       0.43      0.50      0.46     42416
# weighted avg       0.73      0.86      0.79     42416
#
# Hamming Loss: 0.14470954356846474
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.84      1.00      0.91     35714
#            1       0.00      0.00      0.00      6702
#
#     accuracy                           0.84     42416
#    macro avg       0.42      0.50      0.46     42416
# weighted avg       0.71      0.84      0.77     42416
#
# Hamming Loss: 0.15800641267446247
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93     37082
#            1       0.00      0.00      0.00      5334
#
#     accuracy                           0.87     42416
#    macro avg       0.44      0.50      0.47     42416
# weighted avg       0.76      0.87      0.82     42416
#
# Hamming Loss: 0.125754432289702
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB AGGREGATE
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92    181370
#            1       0.00      0.00      0.00     30711
#
#     accuracy                           0.86    212081
#    macro avg       0.43      0.50      0.46    212081
# weighted avg       0.73      0.86      0.79    212081
#
# Hamming Loss: 0.1448078415808157
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92     35929
#            1       0.00      0.00      0.00      6488
#
#     accuracy                           0.85     42417
#    macro avg       0.42      0.50      0.46     42417
# weighted avg       0.72      0.85      0.78     42417
#
# Hamming Loss: 0.1529575406087182
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92     36367
#            1       0.00      0.00      0.00      6049
#
#     accuracy                           0.86     42416
#    macro avg       0.43      0.50      0.46     42416
# weighted avg       0.74      0.86      0.79     42416
#
# Hamming Loss: 0.14261127876273105
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92     36278
#            1       0.00      0.00      0.00      6138
#
#     accuracy                           0.86     42416
#    macro avg       0.43      0.50      0.46     42416
# weighted avg       0.73      0.86      0.79     42416
#
# Hamming Loss: 0.14470954356846474
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA
#               precision    recall  f1-score   support
#
#            0       0.84      1.00      0.91     35714
#            1       0.00      0.00      0.00      6702
#
#     accuracy                           0.84     42416
#    macro avg       0.42      0.50      0.46     42416
# weighted avg       0.71      0.84      0.77     42416
#
# Hamming Loss: 0.15800641267446247
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93     37082
#            1       0.00      0.00      0.00      5334
#
#     accuracy                           0.87     42416
#    macro avg       0.44      0.50      0.47     42416
# weighted avg       0.76      0.87      0.82     42416
#
# Hamming Loss: 0.125754432289702
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA AGGREGATE
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92    181370
#            1       0.00      0.00      0.00     30711
#
#     accuracy                           0.86    212081
#    macro avg       0.43      0.50      0.46    212081
# weighted avg       0.73      0.86      0.79    212081
#
# Hamming Loss: 0.1448078415808157
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92     35929
#            1       0.00      0.00      0.00      6488
#
#     accuracy                           0.85     42417
#    macro avg       0.42      0.50      0.46     42417
# weighted avg       0.72      0.85      0.78     42417
#
# Hamming Loss: 0.1529575406087182
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92     36367
#            1       0.00      0.00      0.00      6049
#
#     accuracy                           0.86     42416
#    macro avg       0.43      0.50      0.46     42416
# weighted avg       0.74      0.86      0.79     42416
#
# Hamming Loss: 0.14261127876273105
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92     36278
#            1       0.00      0.00      0.00      6138
#
#     accuracy                           0.86     42416
#    macro avg       0.43      0.50      0.46     42416
# weighted avg       0.73      0.86      0.79     42416
#
# Hamming Loss: 0.14470954356846474
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest
#               precision    recall  f1-score   support
#
#            0       0.84      1.00      0.91     35714
#            1       0.00      0.00      0.00      6702
#
#     accuracy                           0.84     42416
#    macro avg       0.42      0.50      0.46     42416
# weighted avg       0.71      0.84      0.77     42416
#
# Hamming Loss: 0.15800641267446247
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93     37082
#            1       0.00      0.00      0.00      5334
#
#     accuracy                           0.87     42416
#    macro avg       0.44      0.50      0.47     42416
# weighted avg       0.76      0.87      0.82     42416
#
# Hamming Loss: 0.125754432289702
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest AGGREGATE
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92    181370
#            1       0.00      0.00      0.00     30711
#
#     accuracy                           0.86    212081
#    macro avg       0.43      0.50      0.46    212081
# weighted avg       0.73      0.86      0.79    212081
#
# Hamming Loss: 0.1448078415808157
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92     35929
#            1       0.00      0.00      0.00      6488
#
#     accuracy                           0.85     42417
#    macro avg       0.42      0.50      0.46     42417
# weighted avg       0.72      0.85      0.78     42417
#
# Hamming Loss: 0.1529575406087182
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92     36367
#            1       0.00      0.00      0.00      6049
#
#     accuracy                           0.86     42416
#    macro avg       0.43      0.50      0.46     42416
# weighted avg       0.74      0.86      0.79     42416
#
# Hamming Loss: 0.14261127876273105
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92     36278
#            1       0.00      0.00      0.00      6138
#
#     accuracy                           0.86     42416
#    macro avg       0.43      0.50      0.46     42416
# weighted avg       0.73      0.86      0.79     42416
#
# Hamming Loss: 0.14470954356846474
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN
#               precision    recall  f1-score   support
#
#            0       0.84      1.00      0.91     35714
#            1       0.00      0.00      0.00      6702
#
#     accuracy                           0.84     42416
#    macro avg       0.42      0.50      0.46     42416
# weighted avg       0.71      0.84      0.77     42416
#
# Hamming Loss: 0.15800641267446247
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93     37082
#            1       0.00      0.00      0.00      5334
#
#     accuracy                           0.87     42416
#    macro avg       0.44      0.50      0.47     42416
# weighted avg       0.76      0.87      0.82     42416
#
# Hamming Loss: 0.125754432289702
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN AGGREGATE
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92    181370
#            1       0.00      0.00      0.00     30711
#
#     accuracy                           0.86    212081
#    macro avg       0.43      0.50      0.46    212081
# weighted avg       0.73      0.86      0.79    212081
#
# Hamming Loss: 0.1448078415808157
# BRFSS MultiLabel Cancer + Diabetes - Grounded - SVM
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92     35929
#            1       0.00      0.00      0.00      6488
#
#     accuracy                           0.85     42417
#    macro avg       0.42      0.50      0.46     42417
# weighted avg       0.72      0.85      0.78     42417
#
# Hamming Loss: 0.1529575406087182
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - SVM
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92     36367
#            1       0.00      0.00      0.00      6049
#
#     accuracy                           0.86     42416
#    macro avg       0.43      0.50      0.46     42416
# weighted avg       0.74      0.86      0.79     42416
#
# Hamming Loss: 0.14261127876273105
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - SVM
# ...
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - RUSBoost
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92     36367
#            1       0.00      0.00      0.00      6049
#
#     accuracy                           0.86     42416
#    macro avg       0.43      0.50      0.46     42416
# weighted avg       0.74      0.86      0.79     42416
#
# Hamming Loss: 0.14261127876273105
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - RUSBoost
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92     36278
#            1       0.00      0.00      0.00      6138
#
#     accuracy                           0.86     42416
#    macro avg       0.43      0.50      0.46     42416
# weighted avg       0.73      0.86      0.79     42416
#
# Hamming Loss: 0.14470954356846474
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - RUSBoost
#               precision    recall  f1-score   support
#
#            0       0.84      1.00      0.91     35714
#            1       0.00      0.00      0.00      6702
#
#     accuracy                           0.84     42416
#    macro avg       0.42      0.50      0.46     42416
# weighted avg       0.71      0.84      0.77     42416
#
# Hamming Loss: 0.15800641267446247
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - RUSBoost
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93     37082
#            1       0.00      0.00      0.00      5334
#
#     accuracy                           0.87     42416
#    macro avg       0.44      0.50      0.47     42416
# weighted avg       0.76      0.87      0.82     42416
#
# Hamming Loss: 0.125754432289702
# y_pred shape:
# (42416, 2)
# y_pred2 shape:
# (5,)
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - RUSBoost AGGREGATE
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92    181370
#            1       0.00      0.00      0.00     30711
#
#     accuracy                           0.86    212081
#    macro avg       0.43      0.50      0.46    212081
# weighted avg       0.73      0.86      0.79    212081
#
# Hamming Loss: 0.1448078415808157
# BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92     35929
#            1       0.00      0.00      0.00      6488
#
#     accuracy                           0.85     42417
#    macro avg       0.42      0.50      0.46     42417
# weighted avg       0.72      0.85      0.78     42417
#
# Hamming Loss: 0.1529575406087182
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92     36367
#            1       0.00      0.00      0.00      6049
#
#     accuracy                           0.86     42416
#    macro avg       0.43      0.50      0.46     42416
# weighted avg       0.74      0.86      0.79     42416
#
# Hamming Loss: 0.14261127876273105
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92     36278
#            1       0.00      0.00      0.00      6138
#
#     accuracy                           0.86     42416
#    macro avg       0.43      0.50      0.46     42416
# weighted avg       0.73      0.86      0.79     42416
#
# Hamming Loss: 0.14470954356846474
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost
#               precision    recall  f1-score   support
#
#            0       0.84      1.00      0.91     35714
#            1       0.00      0.00      0.00      6702
#
#     accuracy                           0.84     42416
#    macro avg       0.42      0.50      0.46     42416
# weighted avg       0.71      0.84      0.77     42416
#
# Hamming Loss: 0.15800641267446247
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93     37082
#            1       0.00      0.00      0.00      5334
#
#     accuracy                           0.87     42416
#    macro avg       0.44      0.50      0.47     42416
# weighted avg       0.76      0.87      0.82     42416
#
# Hamming Loss: 0.125754432289702
# y_pred shape:
# (42416, 2)
# y_pred2 shape:
# (5,)
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - ADABoost AGGREGATE
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92    181370
#            1       0.00      0.00      0.00     30711
#
#     accuracy                           0.86    212081
#    macro avg       0.43      0.50      0.46    212081
# weighted avg       0.73      0.86      0.79    212081
#
# Hamming Loss: 0.1448078415808157
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
import os
import pandas as pd

folder = "C:/Users/mdjaw/OneDrive/Documents/Markian Training/Research_USQ/USCenterDiseaseControlPrevention/LLCP2019XPT" 
os.chdir(folder)

BRFSS_Grounded = pd.read_csv("LLCP2019XPT_Grounded_KGFS50.csv")

print(BRFSS_Grounded.shape)

BRFSS_Grounded_X = BRFSS_Grounded.drop(['CNCRTYP1', 'DIABETE4'], axis = 1)

print(BRFSS_Grounded_X.shape)
# Out:
# (54619, 32)
# (54619, 30)

# %%
from sklearn.datasets import make_multilabel_classification
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.neural_network import MLPRegressor
from imblearn.ensemble import RUSBoostClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import hamming_loss
from sklearn.model_selection import KFold
from sklearn.metrics import classification_report
import numpy as np


X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = LogisticRegression(C=1.0, penalty='l1', dual=False, solver='liblinear')
  model = OneVsRestClassifier(model)    
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
print("y_pred shape: ")
print(np.shape(y_pred))

print("y_pred2 shape:")
print(np.shape(y_pred2))

y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = MultinomialNB()
  model = OneVsRestClassifier(MultinomialNB())   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
   
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
              solver='svd', store_covariance=False, tol=0.0001))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))
    
X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(RandomForestClassifier(max_depth=100, random_state=0))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))
    
X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(KNeighborsClassifier(n_neighbors=5))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

a = []
b = []
X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(SVC())   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded - SVM")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))  
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - SVM AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  #model = MultinomialNB()
  model = OneVsRestClassifier(RUSBoostClassifier(random_state=0))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded - RUSBoost")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
   
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
print("y_pred shape: ")
print(np.shape(y_pred))

print("y_pred2 shape:")
print(np.shape(y_pred2))

y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - RUSBoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  #model = OneVsRestClassifier(AdaBoostClassifier(n_estimators=50,learning_rate=1))   
  
  model = OneVsRestClassifier(AdaBoostClassifier(n_estimators=200,learning_rate=1))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
   
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
print("y_pred shape: ")
print(np.shape(y_pred))

print("y_pred2 shape:")
print(np.shape(y_pred2))

y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - ADABoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))
# Out:
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94      9671
#            1       0.00      0.00      0.00      1253
#
#     accuracy                           0.89     10924
#    macro avg       0.44      0.50      0.47     10924
# weighted avg       0.78      0.89      0.83     10924
#
# Hamming Loss: 0.11470157451482973
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94      9709
#            1       0.00      0.00      0.00      1215
#
#     accuracy                           0.89     10924
#    macro avg       0.44      0.50      0.47     10924
# weighted avg       0.79      0.89      0.84     10924
#
# Hamming Loss: 0.11122299523983889
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94      9645
#            1       0.00      0.00      0.00      1279
#
#     accuracy                           0.88     10924
#    macro avg       0.44      0.50      0.47     10924
# weighted avg       0.78      0.88      0.83     10924
#
# Hamming Loss: 0.11708165507140242
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95      9789
#            1       0.00      0.00      0.00      1135
#
#     accuracy                           0.90     10924
#    macro avg       0.45      0.50      0.47     10924
# weighted avg       0.80      0.90      0.85     10924
#
# Hamming Loss: 0.10389967045038448
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95      9824
#            1       0.00      0.00      0.00      1099
#
#     accuracy                           0.90     10923
#    macro avg       0.45      0.50      0.47     10923
# weighted avg       0.81      0.90      0.85     10923
#
# Hamming Loss: 0.10061338460130001
# y_pred shape:
# (10923, 2)
# y_pred2 shape:
# (5,)
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression AGGREGATE
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94     48638
#            1       0.00      0.00      0.00      5981
#
#     accuracy                           0.89     54619
#    macro avg       0.45      0.50      0.47     54619
# weighted avg       0.79      0.89      0.84     54619
#
# Hamming Loss: 0.1095038559755511
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94      9671
#            1       0.00      0.00      0.00      1253
#
#     accuracy                           0.89     10924
#    macro avg       0.44      0.50      0.47     10924
# weighted avg       0.78      0.89      0.83     10924
#
# Hamming Loss: 0.11470157451482973
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94      9709
#            1       0.00      0.00      0.00      1215
#
#     accuracy                           0.89     10924
#    macro avg       0.44      0.50      0.47     10924
# weighted avg       0.79      0.89      0.84     10924
#
# Hamming Loss: 0.11122299523983889
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94      9645
#            1       0.00      0.00      0.00      1279
#
#     accuracy                           0.88     10924
#    macro avg       0.44      0.50      0.47     10924
# weighted avg       0.78      0.88      0.83     10924
#
# Hamming Loss: 0.11708165507140242
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95      9789
#            1       0.00      0.00      0.00      1135
#
#     accuracy                           0.90     10924
#    macro avg       0.45      0.50      0.47     10924
# weighted avg       0.80      0.90      0.85     10924
#
# Hamming Loss: 0.10389967045038448
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95      9824
#            1       0.00      0.00      0.00      1099
#
#     accuracy                           0.90     10923
#    macro avg       0.45      0.50      0.47     10923
# weighted avg       0.81      0.90      0.85     10923
#
# Hamming Loss: 0.10061338460130001
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB AGGREGATE
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94     48638
#            1       0.00      0.00      0.00      5981
#
#     accuracy                           0.89     54619
#    macro avg       0.45      0.50      0.47     54619
# weighted avg       0.79      0.89      0.84     54619
#
# Hamming Loss: 0.1095038559755511
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94      9671
#            1       0.00      0.00      0.00      1253
#
#     accuracy                           0.89     10924
#    macro avg       0.44      0.50      0.47     10924
# weighted avg       0.78      0.89      0.83     10924
#
# Hamming Loss: 0.11470157451482973
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94      9709
#            1       0.00      0.00      0.00      1215
#
#     accuracy                           0.89     10924
#    macro avg       0.44      0.50      0.47     10924
# weighted avg       0.79      0.89      0.84     10924
#
# Hamming Loss: 0.11122299523983889
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94      9645
#            1       0.00      0.00      0.00      1279
#
#     accuracy                           0.88     10924
#    macro avg       0.44      0.50      0.47     10924
# weighted avg       0.78      0.88      0.83     10924
#
# Hamming Loss: 0.11708165507140242
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95      9789
#            1       0.00      0.00      0.00      1135
#
#     accuracy                           0.90     10924
#    macro avg       0.45      0.50      0.47     10924
# weighted avg       0.80      0.90      0.85     10924
#
# Hamming Loss: 0.10389967045038448
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95      9824
#            1       0.00      0.00      0.00      1099
#
#     accuracy                           0.90     10923
#    macro avg       0.45      0.50      0.47     10923
# weighted avg       0.81      0.90      0.85     10923
#
# Hamming Loss: 0.10061338460130001
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA AGGREGATE
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94     48638
#            1       0.00      0.00      0.00      5981
#
#     accuracy                           0.89     54619
#    macro avg       0.45      0.50      0.47     54619
# weighted avg       0.79      0.89      0.84     54619
#
# Hamming Loss: 0.1095038559755511
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94      9671
#            1       0.00      0.00      0.00      1253
#
#     accuracy                           0.89     10924
#    macro avg       0.44      0.50      0.47     10924
# weighted avg       0.78      0.89      0.83     10924
#
# Hamming Loss: 0.11470157451482973
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94      9709
#            1       0.00      0.00      0.00      1215
#
#     accuracy                           0.89     10924
#    macro avg       0.44      0.50      0.47     10924
# weighted avg       0.79      0.89      0.84     10924
#
# Hamming Loss: 0.11122299523983889
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94      9645
#            1       0.00      0.00      0.00      1279
#
#     accuracy                           0.88     10924
#    macro avg       0.44      0.50      0.47     10924
# weighted avg       0.78      0.88      0.83     10924
#
# Hamming Loss: 0.11708165507140242
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95      9789
#            1       0.00      0.00      0.00      1135
#
#     accuracy                           0.90     10924
#    macro avg       0.45      0.50      0.47     10924
# weighted avg       0.80      0.90      0.85     10924
#
# Hamming Loss: 0.10389967045038448
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95      9824
#            1       0.00      0.00      0.00      1099
#
#     accuracy                           0.90     10923
#    macro avg       0.45      0.50      0.47     10923
# weighted avg       0.81      0.90      0.85     10923
#
# Hamming Loss: 0.10061338460130001
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest AGGREGATE
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94     48638
#            1       0.00      0.00      0.00      5981
#
#     accuracy                           0.89     54619
#    macro avg       0.45      0.50      0.47     54619
# weighted avg       0.79      0.89      0.84     54619
#
# Hamming Loss: 0.1095038559755511
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94      9671
#            1       0.00      0.00      0.00      1253
#
#     accuracy                           0.89     10924
#    macro avg       0.44      0.50      0.47     10924
# weighted avg       0.78      0.89      0.83     10924
#
# Hamming Loss: 0.11470157451482973
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94      9709
#            1       0.00      0.00      0.00      1215
#
#     accuracy                           0.89     10924
#    macro avg       0.44      0.50      0.47     10924
# weighted avg       0.79      0.89      0.84     10924
#
# Hamming Loss: 0.11122299523983889
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94      9645
#            1       0.00      0.00      0.00      1279
#
#     accuracy                           0.88     10924
#    macro avg       0.44      0.50      0.47     10924
# weighted avg       0.78      0.88      0.83     10924
#
# Hamming Loss: 0.11708165507140242
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95      9789
#            1       0.00      0.00      0.00      1135
#
#     accuracy                           0.90     10924
#    macro avg       0.45      0.50      0.47     10924
# weighted avg       0.80      0.90      0.85     10924
#
# Hamming Loss: 0.10389967045038448
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95      9824
#            1       0.00      0.00      0.00      1099
#
#     accuracy                           0.90     10923
#    macro avg       0.45      0.50      0.47     10923
# weighted avg       0.81      0.90      0.85     10923
#
# Hamming Loss: 0.10061338460130001
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN AGGREGATE
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94     48638
#            1       0.00      0.00      0.00      5981
#
#     accuracy                           0.89     54619
#    macro avg       0.45      0.50      0.47     54619
# weighted avg       0.79      0.89      0.84     54619
#
# Hamming Loss: 0.1095038559755511
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - SVM
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94      9671
#            1       0.00      0.00      0.00      1253
#
#     accuracy                           0.89     10924
#    macro avg       0.44      0.50      0.47     10924
# weighted avg       0.78      0.89      0.83     10924
#
# ...
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - RUSBoost
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94      9645
#            1       0.00      0.00      0.00      1279
#
#     accuracy                           0.88     10924
#    macro avg       0.44      0.50      0.47     10924
# weighted avg       0.78      0.88      0.83     10924
#
# Hamming Loss: 0.11708165507140242
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - RUSBoost
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95      9789
#            1       0.00      0.00      0.00      1135
#
#     accuracy                           0.90     10924
#    macro avg       0.45      0.50      0.47     10924
# weighted avg       0.80      0.90      0.85     10924
#
# Hamming Loss: 0.10389967045038448
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - RUSBoost
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95      9824
#            1       0.00      0.00      0.00      1099
#
#     accuracy                           0.90     10923
#    macro avg       0.45      0.50      0.47     10923
# weighted avg       0.81      0.90      0.85     10923
#
# Hamming Loss: 0.10061338460130001
# y_pred shape:
# (10923, 2)
# y_pred2 shape:
# (5,)
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - RUSBoost AGGREGATE
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94     48638
#            1       0.00      0.00      0.00      5981
#
#     accuracy                           0.89     54619
#    macro avg       0.45      0.50      0.47     54619
# weighted avg       0.79      0.89      0.84     54619
#
# Hamming Loss: 0.1095038559755511
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94      9671
#            1       0.00      0.00      0.00      1253
#
#     accuracy                           0.89     10924
#    macro avg       0.44      0.50      0.47     10924
# weighted avg       0.78      0.89      0.83     10924
#
# Hamming Loss: 0.11470157451482973
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94      9709
#            1       0.00      0.00      0.00      1215
#
#     accuracy                           0.89     10924
#    macro avg       0.44      0.50      0.47     10924
# weighted avg       0.79      0.89      0.84     10924
#
# Hamming Loss: 0.11122299523983889
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94      9645
#            1       0.00      0.00      0.00      1279
#
#     accuracy                           0.88     10924
#    macro avg       0.44      0.50      0.47     10924
# weighted avg       0.78      0.88      0.83     10924
#
# Hamming Loss: 0.11708165507140242
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95      9789
#            1       0.00      0.00      0.00      1135
#
#     accuracy                           0.90     10924
#    macro avg       0.45      0.50      0.47     10924
# weighted avg       0.80      0.90      0.85     10924
#
# Hamming Loss: 0.10389967045038448
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95      9824
#            1       0.00      0.00      0.00      1099
#
#     accuracy                           0.90     10923
#    macro avg       0.45      0.50      0.47     10923
# weighted avg       0.81      0.90      0.85     10923
#
# Hamming Loss: 0.10061338460130001
# y_pred shape:
# (10923, 2)
# y_pred2 shape:
# (5,)
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - ADABoost AGGREGATE
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94     48638
#            1       0.00      0.00      0.00      5981
#
#     accuracy                           0.89     54619
#    macro avg       0.45      0.50      0.47     54619
# weighted avg       0.79      0.89      0.84     54619
#
# Hamming Loss: 0.1095038559755511
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
import os
import pandas as pd

folder = "C:/Users/mdjaw/OneDrive/Documents/Markian Training/Research_USQ/USCenterDiseaseControlPrevention/LLCP2019XPT" 
os.chdir(folder)

BRFSS_Grounded = pd.read_csv("LLCP2019XPT_Grounded_KGFS4.csv")

print(BRFSS_Grounded.shape)

BRFSS_Grounded_X = BRFSS_Grounded.drop(['CNCRTYP1', 'DIABETE4'], axis = 1)

print(BRFSS_Grounded_X.shape)

# %%
from sklearn.datasets import make_multilabel_classification
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.neural_network import MLPRegressor
from imblearn.ensemble import RUSBoostClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import hamming_loss
from sklearn.model_selection import KFold
from sklearn.metrics import classification_report
import numpy as np


X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = LogisticRegression(C=1.0, penalty='l1', dual=False, solver='liblinear')
  model = OneVsRestClassifier(model)    
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
print("y_pred shape: ")
print(np.shape(y_pred))

print("y_pred2 shape:")
print(np.shape(y_pred2))

y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = MultinomialNB()
  model = OneVsRestClassifier(MultinomialNB())   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
   
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
              solver='svd', store_covariance=False, tol=0.0001))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))
    
X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(RandomForestClassifier(max_depth=100, random_state=0))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))
    
X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(KNeighborsClassifier(n_neighbors=5))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

a = []
b = []
X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(SVC())   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded - SVM")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))  
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - SVM AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  #model = MultinomialNB()
  model = OneVsRestClassifier(RUSBoostClassifier(random_state=0))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded - RUSBoost")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
   
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
print("y_pred shape: ")
print(np.shape(y_pred))

print("y_pred2 shape:")
print(np.shape(y_pred2))

y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - RUSBoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  #model = OneVsRestClassifier(AdaBoostClassifier(n_estimators=50,learning_rate=1))   
  
  model = OneVsRestClassifier(AdaBoostClassifier(n_estimators=200,learning_rate=1))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
   
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
print("y_pred shape: ")
print(np.shape(y_pred))

print("y_pred2 shape:")
print(np.shape(y_pred2))

y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - ADABoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

# %%
import os
import pandas as pd

folder = "C:/Users/mdjaw/OneDrive/Documents/Markian Training/Research_USQ/USCenterDiseaseControlPrevention/LLCP2019XPT" 
os.chdir(folder)

BRFSS_Grounded = pd.read_csv("LLCP2019XPT_Grounded_KGFS10.csv")

print(BRFSS_Grounded.shape)

BRFSS_Grounded_X = BRFSS_Grounded.drop(['CNCRTYP1', 'DIABETE4'], axis = 1)

print(BRFSS_Grounded_X.shape)
# Out:
# (134086, 7)
# (134086, 5)

# %%
from sklearn.datasets import make_multilabel_classification
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.neural_network import MLPRegressor
from imblearn.ensemble import RUSBoostClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import hamming_loss
from sklearn.model_selection import KFold
from sklearn.metrics import classification_report
import numpy as np


X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = LogisticRegression(C=1.0, penalty='l1', dual=False, solver='liblinear')
  model = OneVsRestClassifier(model)    
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
print("y_pred shape: ")
print(np.shape(y_pred))

print("y_pred2 shape:")
print(np.shape(y_pred2))

y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = MultinomialNB()
  model = OneVsRestClassifier(MultinomialNB())   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
   
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
              solver='svd', store_covariance=False, tol=0.0001))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))
    
X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(RandomForestClassifier(max_depth=100, random_state=0))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))
    
X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(KNeighborsClassifier(n_neighbors=5))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

a = []
b = []
X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(SVC())   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded - SVM")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))  
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - SVM AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  #model = MultinomialNB()
  model = OneVsRestClassifier(RUSBoostClassifier(random_state=0))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded - RUSBoost")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
   
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
print("y_pred shape: ")
print(np.shape(y_pred))

print("y_pred2 shape:")
print(np.shape(y_pred2))

y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - RUSBoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  #model = OneVsRestClassifier(AdaBoostClassifier(n_estimators=50,learning_rate=1))   
  
  model = OneVsRestClassifier(AdaBoostClassifier(n_estimators=200,learning_rate=1))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
   
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
print("y_pred shape: ")
print(np.shape(y_pred))

print("y_pred2 shape:")
print(np.shape(y_pred2))

y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - ADABoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))
# Out:
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.93     23123
#            1       0.00      0.00      0.00      3695
#
#     accuracy                           0.86     26818
#    macro avg       0.43      0.50      0.46     26818
# weighted avg       0.74      0.86      0.80     26818
#
# Hamming Loss: 0.1377805951226788
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93     23387
#            1       0.00      0.00      0.00      3430
#
#     accuracy                           0.87     26817
#    macro avg       0.44      0.50      0.47     26817
# weighted avg       0.76      0.87      0.81     26817
#
# Hamming Loss: 0.12790394152962672
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94     23590
#            1       0.00      0.00      0.00      3227
#
#     accuracy                           0.88     26817
#    macro avg       0.44      0.50      0.47     26817
# weighted avg       0.77      0.88      0.82     26817
#
# Hamming Loss: 0.12033411641868964
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.93     23176
#            1       0.00      0.00      0.00      3641
#
#     accuracy                           0.86     26817
#    macro avg       0.43      0.50      0.46     26817
# weighted avg       0.75      0.86      0.80     26817
#
# Hamming Loss: 0.13577208487153672
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94     23908
#            1       0.00      0.00      0.00      2909
#
#     accuracy                           0.89     26817
#    macro avg       0.45      0.50      0.47     26817
# weighted avg       0.79      0.89      0.84     26817
#
# Hamming Loss: 0.10847596673751725
# y_pred shape:
# (26817, 2)
# y_pred2 shape:
# (5,)
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression AGGREGATE
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93    117184
#            1       0.00      0.00      0.00     16902
#
#     accuracy                           0.87    134086
#    macro avg       0.44      0.50      0.47    134086
# weighted avg       0.76      0.87      0.82    134086
#
# Hamming Loss: 0.1260533409360098
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.93     23123
#            1       0.00      0.00      0.00      3695
#
#     accuracy                           0.86     26818
#    macro avg       0.43      0.50      0.46     26818
# weighted avg       0.74      0.86      0.80     26818
#
# Hamming Loss: 0.1377805951226788
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93     23387
#            1       0.00      0.00      0.00      3430
#
#     accuracy                           0.87     26817
#    macro avg       0.44      0.50      0.47     26817
# weighted avg       0.76      0.87      0.81     26817
#
# Hamming Loss: 0.12790394152962672
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94     23590
#            1       0.00      0.00      0.00      3227
#
#     accuracy                           0.88     26817
#    macro avg       0.44      0.50      0.47     26817
# weighted avg       0.77      0.88      0.82     26817
#
# Hamming Loss: 0.12033411641868964
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.93     23176
#            1       0.00      0.00      0.00      3641
#
#     accuracy                           0.86     26817
#    macro avg       0.43      0.50      0.46     26817
# weighted avg       0.75      0.86      0.80     26817
#
# Hamming Loss: 0.13577208487153672
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94     23908
#            1       0.00      0.00      0.00      2909
#
#     accuracy                           0.89     26817
#    macro avg       0.45      0.50      0.47     26817
# weighted avg       0.79      0.89      0.84     26817
#
# Hamming Loss: 0.10847596673751725
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB AGGREGATE
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93    117184
#            1       0.00      0.00      0.00     16902
#
#     accuracy                           0.87    134086
#    macro avg       0.44      0.50      0.47    134086
# weighted avg       0.76      0.87      0.82    134086
#
# Hamming Loss: 0.1260533409360098
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.93     23123
#            1       0.00      0.00      0.00      3695
#
#     accuracy                           0.86     26818
#    macro avg       0.43      0.50      0.46     26818
# weighted avg       0.74      0.86      0.80     26818
#
# Hamming Loss: 0.1377805951226788
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93     23387
#            1       0.00      0.00      0.00      3430
#
#     accuracy                           0.87     26817
#    macro avg       0.44      0.50      0.47     26817
# weighted avg       0.76      0.87      0.81     26817
#
# Hamming Loss: 0.12790394152962672
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94     23590
#            1       0.00      0.00      0.00      3227
#
#     accuracy                           0.88     26817
#    macro avg       0.44      0.50      0.47     26817
# weighted avg       0.77      0.88      0.82     26817
#
# Hamming Loss: 0.12033411641868964
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.93     23176
#            1       0.00      0.00      0.00      3641
#
#     accuracy                           0.86     26817
#    macro avg       0.43      0.50      0.46     26817
# weighted avg       0.75      0.86      0.80     26817
#
# Hamming Loss: 0.13577208487153672
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94     23908
#            1       0.00      0.00      0.00      2909
#
#     accuracy                           0.89     26817
#    macro avg       0.45      0.50      0.47     26817
# weighted avg       0.79      0.89      0.84     26817
#
# Hamming Loss: 0.10847596673751725
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA AGGREGATE
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93    117184
#            1       0.00      0.00      0.00     16902
#
#     accuracy                           0.87    134086
#    macro avg       0.44      0.50      0.47    134086
# weighted avg       0.76      0.87      0.82    134086
#
# Hamming Loss: 0.1260533409360098
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.93     23123
#            1       0.00      0.00      0.00      3695
#
#     accuracy                           0.86     26818
#    macro avg       0.43      0.50      0.46     26818
# weighted avg       0.74      0.86      0.80     26818
#
# Hamming Loss: 0.1377805951226788
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93     23387
#            1       0.00      0.00      0.00      3430
#
#     accuracy                           0.87     26817
#    macro avg       0.44      0.50      0.47     26817
# weighted avg       0.76      0.87      0.81     26817
#
# Hamming Loss: 0.12790394152962672
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94     23590
#            1       0.00      0.00      0.00      3227
#
#     accuracy                           0.88     26817
#    macro avg       0.44      0.50      0.47     26817
# weighted avg       0.77      0.88      0.82     26817
#
# Hamming Loss: 0.12033411641868964
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.93     23176
#            1       0.00      0.00      0.00      3641
#
#     accuracy                           0.86     26817
#    macro avg       0.43      0.50      0.46     26817
# weighted avg       0.75      0.86      0.80     26817
#
# Hamming Loss: 0.13577208487153672
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94     23908
#            1       0.00      0.00      0.00      2909
#
#     accuracy                           0.89     26817
#    macro avg       0.45      0.50      0.47     26817
# weighted avg       0.79      0.89      0.84     26817
#
# Hamming Loss: 0.10847596673751725
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest AGGREGATE
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93    117184
#            1       0.00      0.00      0.00     16902
#
#     accuracy                           0.87    134086
#    macro avg       0.44      0.50      0.47    134086
# weighted avg       0.76      0.87      0.82    134086
#
# Hamming Loss: 0.1260533409360098
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.93     23123
#            1       0.00      0.00      0.00      3695
#
#     accuracy                           0.86     26818
#    macro avg       0.43      0.50      0.46     26818
# weighted avg       0.74      0.86      0.80     26818
#
# Hamming Loss: 0.1377805951226788
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93     23387
#            1       0.00      0.00      0.00      3430
#
#     accuracy                           0.87     26817
#    macro avg       0.44      0.50      0.47     26817
# weighted avg       0.76      0.87      0.81     26817
#
# Hamming Loss: 0.12790394152962672
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94     23590
#            1       0.00      0.00      0.00      3227
#
#     accuracy                           0.88     26817
#    macro avg       0.44      0.50      0.47     26817
# weighted avg       0.77      0.88      0.82     26817
#
# Hamming Loss: 0.12033411641868964
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.93     23176
#            1       0.00      0.00      0.00      3641
#
#     accuracy                           0.86     26817
#    macro avg       0.43      0.50      0.46     26817
# weighted avg       0.75      0.86      0.80     26817
#
# Hamming Loss: 0.13577208487153672
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94     23908
#            1       0.00      0.00      0.00      2909
#
#     accuracy                           0.89     26817
#    macro avg       0.45      0.50      0.47     26817
# weighted avg       0.79      0.89      0.84     26817
#
# Hamming Loss: 0.10847596673751725
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN AGGREGATE
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93    117184
#            1       0.00      0.00      0.00     16902
#
#     accuracy                           0.87    134086
#    macro avg       0.44      0.50      0.47    134086
# weighted avg       0.76      0.87      0.82    134086
#
# Hamming Loss: 0.1260533409360098
# BRFSS MultiLabel Cancer + Diabetes - Grounded - SVM
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.93     23123
#            1       0.00      0.00      0.00      3695
#
#     accuracy                           0.86     26818
#    macro avg       0.43      0.50      0.46     26818
# weighted avg       0.74      0.86      0.80     26818
#
# Hamming Loss: 0.1377805951226788
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - SVM
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93     23387
#            1       0.00      0.00      0.00      3430
#
#     accuracy                           0.87     26817
#    macro avg       0.44      0.50      0.47     26817
# weighted avg       0.76      0.87      0.81     26817
#
# Hamming Loss: 0.12790394152962672
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - SVM
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94     23590
#            1       0.00      0.00      0.00      3227
#
#     accuracy                           0.88     26817
#    macro avg       0.44      0.50      0.47     26817
# weighted avg       0.77      0.88      0.82     26817
#
# Hamming Loss: 0.12033411641868964
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - RUSBoost
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93     23387
#            1       0.00      0.00      0.00      3430
#
#     accuracy                           0.87     26817
#    macro avg       0.44      0.50      0.47     26817
# weighted avg       0.76      0.87      0.81     26817
#
# Hamming Loss: 0.12790394152962672
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - RUSBoost
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94     23590
#            1       0.00      0.00      0.00      3227
#
#     accuracy                           0.88     26817
#    macro avg       0.44      0.50      0.47     26817
# weighted avg       0.77      0.88      0.82     26817
#
# Hamming Loss: 0.12033411641868964
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - RUSBoost
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.93     23176
#            1       0.00      0.00      0.00      3641
#
#     accuracy                           0.86     26817
#    macro avg       0.43      0.50      0.46     26817
# weighted avg       0.75      0.86      0.80     26817
#
# Hamming Loss: 0.13577208487153672
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - RUSBoost
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94     23908
#            1       0.00      0.00      0.00      2909
#
#     accuracy                           0.89     26817
#    macro avg       0.45      0.50      0.47     26817
# weighted avg       0.79      0.89      0.84     26817
#
# Hamming Loss: 0.10847596673751725
# y_pred shape:
# (26817, 2)
# y_pred2 shape:
# (5,)
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - RUSBoost AGGREGATE
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93    117184
#            1       0.00      0.00      0.00     16902
#
#     accuracy                           0.87    134086
#    macro avg       0.44      0.50      0.47    134086
# weighted avg       0.76      0.87      0.82    134086
#
# Hamming Loss: 0.1260533409360098
# BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.93     23123
#            1       0.00      0.00      0.00      3695
#
#     accuracy                           0.86     26818
#    macro avg       0.43      0.50      0.46     26818
# weighted avg       0.74      0.86      0.80     26818
#
# Hamming Loss: 0.1377805951226788
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93     23387
#            1       0.00      0.00      0.00      3430
#
#     accuracy                           0.87     26817
#    macro avg       0.44      0.50      0.47     26817
# weighted avg       0.76      0.87      0.81     26817
#
# Hamming Loss: 0.12790394152962672
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94     23590
#            1       0.00      0.00      0.00      3227
#
#     accuracy                           0.88     26817
#    macro avg       0.44      0.50      0.47     26817
# weighted avg       0.77      0.88      0.82     26817
#
# Hamming Loss: 0.12033411641868964
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.93     23176
#            1       0.00      0.00      0.00      3641
#
#     accuracy                           0.86     26817
#    macro avg       0.43      0.50      0.46     26817
# weighted avg       0.75      0.86      0.80     26817
#
# Hamming Loss: 0.13577208487153672
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94     23908
#            1       0.00      0.00      0.00      2909
#
#     accuracy                           0.89     26817
#    macro avg       0.45      0.50      0.47     26817
# weighted avg       0.79      0.89      0.84     26817
#
# Hamming Loss: 0.10847596673751725
# y_pred shape:
# (26817, 2)
# y_pred2 shape:
# (5,)
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - ADABoost AGGREGATE
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93    117184
#            1       0.00      0.00      0.00     16902
#
#     accuracy                           0.87    134086
#    macro avg       0.44      0.50      0.47    134086
# weighted avg       0.76      0.87      0.82    134086
#
# Hamming Loss: 0.1260533409360098
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
import os
import pandas as pd

folder = "C:/Users/mdjaw/OneDrive/Documents/Markian Training/Research_USQ/USCenterDiseaseControlPrevention/LLCP2019XPT" 
os.chdir(folder)

BRFSS_Grounded = pd.read_csv("LLCP2019XPT_Grounded_KGFS2.csv")

print(BRFSS_Grounded.shape)

BRFSS_Grounded_X = BRFSS_Grounded.drop(['CNCRTYP1', 'DIABETE4'], axis = 1)

print(BRFSS_Grounded_X.shape)

# %%
from sklearn.datasets import make_multilabel_classification
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.neural_network import MLPRegressor
from imblearn.ensemble import RUSBoostClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import hamming_loss
from sklearn.model_selection import KFold
from sklearn.metrics import classification_report
import numpy as np


X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = LogisticRegression(C=1.0, penalty='l1', dual=False, solver='liblinear')
  model = OneVsRestClassifier(model)    
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
print("y_pred shape: ")
print(np.shape(y_pred))

print("y_pred2 shape:")
print(np.shape(y_pred2))

y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = MultinomialNB()
  model = OneVsRestClassifier(MultinomialNB())   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
   
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
              solver='svd', store_covariance=False, tol=0.0001))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))
    
X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(RandomForestClassifier(max_depth=100, random_state=0))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))
    
X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(KNeighborsClassifier(n_neighbors=5))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

a = []
b = []
X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(SVC())   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded - SVM")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))  
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - SVM AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  #model = MultinomialNB()
  model = OneVsRestClassifier(RUSBoostClassifier(random_state=0))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded - RUSBoost")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
   
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
print("y_pred shape: ")
print(np.shape(y_pred))

print("y_pred2 shape:")
print(np.shape(y_pred2))

y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - RUSBoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  #model = OneVsRestClassifier(AdaBoostClassifier(n_estimators=50,learning_rate=1))   
  
  model = OneVsRestClassifier(AdaBoostClassifier(n_estimators=200,learning_rate=1))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
   
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
print("y_pred shape: ")
print(np.shape(y_pred))

print("y_pred2 shape:")
print(np.shape(y_pred2))

y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - ADABoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

# %%
import os
import pandas as pd

folder = "C:/Users/mdjaw/OneDrive/Documents/Markian Training/Research_USQ/USCenterDiseaseControlPrevention/LLCP2019XPT" 
os.chdir(folder)

BRFSS_Grounded = pd.read_csv("LLCP2019XPT_Grounded_KGFS75.csv")

print(BRFSS_Grounded.shape)

BRFSS_Grounded_X = BRFSS_Grounded.drop(['CNCRTYP1', 'DIABETE4'], axis = 1)

print(BRFSS_Grounded_X.shape)
# Out:
# (212081, 4)
# (212081, 2)

# %%
from sklearn.datasets import make_multilabel_classification
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.neural_network import MLPRegressor
from imblearn.ensemble import RUSBoostClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import hamming_loss
from sklearn.model_selection import KFold
from sklearn.metrics import classification_report
import numpy as np


X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = LogisticRegression(C=1.0, penalty='l1', dual=False, solver='liblinear')
  model = OneVsRestClassifier(model)    
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
print("y_pred shape: ")
print(np.shape(y_pred))

print("y_pred2 shape:")
print(np.shape(y_pred2))

y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = MultinomialNB()
  model = OneVsRestClassifier(MultinomialNB())   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
   
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
              solver='svd', store_covariance=False, tol=0.0001))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))
    
X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(RandomForestClassifier(max_depth=100, random_state=0))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))
    
X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(KNeighborsClassifier(n_neighbors=5))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

a = []
b = []
X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(SVC())   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded - SVM")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))  
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - SVM AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  #model = MultinomialNB()
  model = OneVsRestClassifier(RUSBoostClassifier(random_state=0))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded - RUSBoost")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
   
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
print("y_pred shape: ")
print(np.shape(y_pred))

print("y_pred2 shape:")
print(np.shape(y_pred2))

y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - RUSBoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  #model = OneVsRestClassifier(AdaBoostClassifier(n_estimators=50,learning_rate=1))   
  
  model = OneVsRestClassifier(AdaBoostClassifier(n_estimators=200,learning_rate=1))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
   
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
print("y_pred shape: ")
print(np.shape(y_pred))

print("y_pred2 shape:")
print(np.shape(y_pred2))

y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - ADABoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))
# Out:
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\svm\_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92     35929
#            1       0.00      0.00      0.00      6488
#
#     accuracy                           0.85     42417
#    macro avg       0.42      0.50      0.46     42417
# weighted avg       0.72      0.85      0.78     42417
#
# Hamming Loss: 0.1529575406087182
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\svm\_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92     36367
#            1       0.00      0.00      0.00      6049
#
#     accuracy                           0.86     42416
#    macro avg       0.43      0.50      0.46     42416
# weighted avg       0.74      0.86      0.79     42416
#
# Hamming Loss: 0.14261127876273105
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\svm\_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92     36278
#            1       0.00      0.00      0.00      6138
#
#     accuracy                           0.86     42416
#    macro avg       0.43      0.50      0.46     42416
# weighted avg       0.73      0.86      0.79     42416
#
# Hamming Loss: 0.14470954356846474
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\svm\_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.84      1.00      0.91     35714
#            1       0.00      0.00      0.00      6702
#
#     accuracy                           0.84     42416
#    macro avg       0.42      0.50      0.46     42416
# weighted avg       0.71      0.84      0.77     42416
#
# Hamming Loss: 0.15800641267446247
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93     37082
#            1       0.00      0.00      0.00      5334
#
#     accuracy                           0.87     42416
#    macro avg       0.44      0.50      0.47     42416
# weighted avg       0.76      0.87      0.82     42416
#
# Hamming Loss: 0.125754432289702
# y_pred shape:
# (42416, 2)
# y_pred2 shape:
# (5,)
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression AGGREGATE
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92    181370
#            1       0.00      0.00      0.00     30711
#
#     accuracy                           0.86    212081
#    macro avg       0.43      0.50      0.46    212081
# weighted avg       0.73      0.86      0.79    212081
#
# Hamming Loss: 0.1448078415808157
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92     35929
#            1       0.00      0.00      0.00      6488
#
#     accuracy                           0.85     42417
#    macro avg       0.42      0.50      0.46     42417
# weighted avg       0.72      0.85      0.78     42417
#
# Hamming Loss: 0.1529575406087182
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92     36367
#            1       0.00      0.00      0.00      6049
#
#     accuracy                           0.86     42416
#    macro avg       0.43      0.50      0.46     42416
# weighted avg       0.74      0.86      0.79     42416
#
# Hamming Loss: 0.14261127876273105
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92     36278
#            1       0.00      0.00      0.00      6138
#
#     accuracy                           0.86     42416
#    macro avg       0.43      0.50      0.46     42416
# weighted avg       0.73      0.86      0.79     42416
#
# Hamming Loss: 0.14470954356846474
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.84      1.00      0.91     35714
#            1       0.00      0.00      0.00      6702
#
#     accuracy                           0.84     42416
#    macro avg       0.42      0.50      0.46     42416
# weighted avg       0.71      0.84      0.77     42416
#
# Hamming Loss: 0.15800641267446247
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93     37082
#            1       0.00      0.00      0.00      5334
#
#     accuracy                           0.87     42416
#    macro avg       0.44      0.50      0.47     42416
# weighted avg       0.76      0.87      0.82     42416
#
# Hamming Loss: 0.125754432289702
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB AGGREGATE
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92    181370
#            1       0.00      0.00      0.00     30711
#
#     accuracy                           0.86    212081
#    macro avg       0.43      0.50      0.46    212081
# weighted avg       0.73      0.86      0.79    212081
#
# Hamming Loss: 0.1448078415808157
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92     35929
#            1       0.00      0.00      0.00      6488
#
#     accuracy                           0.85     42417
#    macro avg       0.42      0.50      0.46     42417
# weighted avg       0.72      0.85      0.78     42417
#
# Hamming Loss: 0.1529575406087182
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92     36367
#            1       0.00      0.00      0.00      6049
#
#     accuracy                           0.86     42416
#    macro avg       0.43      0.50      0.46     42416
# weighted avg       0.74      0.86      0.79     42416
#
# Hamming Loss: 0.14261127876273105
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92     36278
#            1       0.00      0.00      0.00      6138
#
#     accuracy                           0.86     42416
#    macro avg       0.43      0.50      0.46     42416
# weighted avg       0.73      0.86      0.79     42416
#
# Hamming Loss: 0.14470954356846474
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA
#               precision    recall  f1-score   support
#
#            0       0.84      1.00      0.91     35714
#            1       0.00      0.00      0.00      6702
#
#     accuracy                           0.84     42416
#    macro avg       0.42      0.50      0.46     42416
# weighted avg       0.71      0.84      0.77     42416
#
# Hamming Loss: 0.15800641267446247
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93     37082
#            1       0.00      0.00      0.00      5334
#
#     accuracy                           0.87     42416
#    macro avg       0.44      0.50      0.47     42416
# weighted avg       0.76      0.87      0.82     42416
#
# Hamming Loss: 0.125754432289702
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA AGGREGATE
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92    181370
#            1       0.00      0.00      0.00     30711
#
#     accuracy                           0.86    212081
#    macro avg       0.43      0.50      0.46    212081
# weighted avg       0.73      0.86      0.79    212081
#
# Hamming Loss: 0.1448078415808157
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92     35929
#            1       0.00      0.00      0.00      6488
#
#     accuracy                           0.85     42417
#    macro avg       0.42      0.50      0.46     42417
# weighted avg       0.72      0.85      0.78     42417
#
# Hamming Loss: 0.1529575406087182
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92     36367
#            1       0.00      0.00      0.00      6049
#
#     accuracy                           0.86     42416
#    macro avg       0.43      0.50      0.46     42416
# weighted avg       0.74      0.86      0.79     42416
#
# Hamming Loss: 0.14261127876273105
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92     36278
#            1       0.00      0.00      0.00      6138
#
#     accuracy                           0.86     42416
#    macro avg       0.43      0.50      0.46     42416
# weighted avg       0.73      0.86      0.79     42416
#
# Hamming Loss: 0.14470954356846474
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest
#               precision    recall  f1-score   support
#
#            0       0.84      1.00      0.91     35714
#            1       0.00      0.00      0.00      6702
#
#     accuracy                           0.84     42416
#    macro avg       0.42      0.50      0.46     42416
# weighted avg       0.71      0.84      0.77     42416
#
# Hamming Loss: 0.15800641267446247
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93     37082
#            1       0.00      0.00      0.00      5334
#
#     accuracy                           0.87     42416
#    macro avg       0.44      0.50      0.47     42416
# weighted avg       0.76      0.87      0.82     42416
#
# Hamming Loss: 0.125754432289702
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest AGGREGATE
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92    181370
#            1       0.00      0.00      0.00     30711
#
#     accuracy                           0.86    212081
#    macro avg       0.43      0.50      0.46    212081
# weighted avg       0.73      0.86      0.79    212081
#
# Hamming Loss: 0.1448078415808157
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92     35929
#            1       0.00      0.00      0.00      6488
#
#     accuracy                           0.85     42417
#    macro avg       0.42      0.50      0.46     42417
# weighted avg       0.72      0.85      0.78     42417
#
# Hamming Loss: 0.1529575406087182
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92     36367
#            1       0.00      0.00      0.00      6049
#
#     accuracy                           0.86     42416
#    macro avg       0.43      0.50      0.46     42416
# weighted avg       0.74      0.86      0.79     42416
#
# Hamming Loss: 0.14261127876273105
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92     36278
#            1       0.00      0.00      0.00      6138
#
#     accuracy                           0.86     42416
#    macro avg       0.43      0.50      0.46     42416
# weighted avg       0.73      0.86      0.79     42416
#
# Hamming Loss: 0.14470954356846474
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN
#               precision    recall  f1-score   support
#
#            0       0.84      1.00      0.91     35714
#            1       0.00      0.00      0.00      6702
#
#     accuracy                           0.84     42416
#    macro avg       0.42      0.50      0.46     42416
# weighted avg       0.71      0.84      0.77     42416
#
# Hamming Loss: 0.15800641267446247
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93     37082
#            1       0.00      0.00      0.00      5334
#
#     accuracy                           0.87     42416
#    macro avg       0.44      0.50      0.47     42416
# weighted avg       0.76      0.87      0.82     42416
#
# Hamming Loss: 0.125754432289702
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN AGGREGATE
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92    181370
#            1       0.00      0.00      0.00     30711
#
#     accuracy                           0.86    212081
#    macro avg       0.43      0.50      0.46    212081
# weighted avg       0.73      0.86      0.79    212081
#
# Hamming Loss: 0.1448078415808157
# BRFSS MultiLabel Cancer + Diabetes - Grounded - SVM
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92     35929
#            1       0.00      0.00      0.00      6488
#
#     accuracy                           0.85     42417
#    macro avg       0.42      0.50      0.46     42417
# weighted avg       0.72      0.85      0.78     42417
#
# Hamming Loss: 0.1529575406087182
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - SVM
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92     36367
#            1       0.00      0.00      0.00      6049
#
#     accuracy                           0.86     42416
#    macro avg       0.43      0.50      0.46     42416
# weighted avg       0.74      0.86      0.79     42416
#
# Hamming Loss: 0.14261127876273105
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - SVM
# ...
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - RUSBoost
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92     36367
#            1       0.00      0.00      0.00      6049
#
#     accuracy                           0.86     42416
#    macro avg       0.43      0.50      0.46     42416
# weighted avg       0.74      0.86      0.79     42416
#
# Hamming Loss: 0.14261127876273105
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - RUSBoost
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92     36278
#            1       0.00      0.00      0.00      6138
#
#     accuracy                           0.86     42416
#    macro avg       0.43      0.50      0.46     42416
# weighted avg       0.73      0.86      0.79     42416
#
# Hamming Loss: 0.14470954356846474
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - RUSBoost
#               precision    recall  f1-score   support
#
#            0       0.84      1.00      0.91     35714
#            1       0.00      0.00      0.00      6702
#
#     accuracy                           0.84     42416
#    macro avg       0.42      0.50      0.46     42416
# weighted avg       0.71      0.84      0.77     42416
#
# Hamming Loss: 0.15800641267446247
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - RUSBoost
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93     37082
#            1       0.00      0.00      0.00      5334
#
#     accuracy                           0.87     42416
#    macro avg       0.44      0.50      0.47     42416
# weighted avg       0.76      0.87      0.82     42416
#
# Hamming Loss: 0.125754432289702
# y_pred shape:
# (42416, 2)
# y_pred2 shape:
# (5,)
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - RUSBoost AGGREGATE
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92    181370
#            1       0.00      0.00      0.00     30711
#
#     accuracy                           0.86    212081
#    macro avg       0.43      0.50      0.46    212081
# weighted avg       0.73      0.86      0.79    212081
#
# Hamming Loss: 0.1448078415808157
# BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92     35929
#            1       0.00      0.00      0.00      6488
#
#     accuracy                           0.85     42417
#    macro avg       0.42      0.50      0.46     42417
# weighted avg       0.72      0.85      0.78     42417
#
# Hamming Loss: 0.1529575406087182
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92     36367
#            1       0.00      0.00      0.00      6049
#
#     accuracy                           0.86     42416
#    macro avg       0.43      0.50      0.46     42416
# weighted avg       0.74      0.86      0.79     42416
#
# Hamming Loss: 0.14261127876273105
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92     36278
#            1       0.00      0.00      0.00      6138
#
#     accuracy                           0.86     42416
#    macro avg       0.43      0.50      0.46     42416
# weighted avg       0.73      0.86      0.79     42416
#
# Hamming Loss: 0.14470954356846474
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost
#               precision    recall  f1-score   support
#
#            0       0.84      1.00      0.91     35714
#            1       0.00      0.00      0.00      6702
#
#     accuracy                           0.84     42416
#    macro avg       0.42      0.50      0.46     42416
# weighted avg       0.71      0.84      0.77     42416
#
# Hamming Loss: 0.15800641267446247
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93     37082
#            1       0.00      0.00      0.00      5334
#
#     accuracy                           0.87     42416
#    macro avg       0.44      0.50      0.47     42416
# weighted avg       0.76      0.87      0.82     42416
#
# Hamming Loss: 0.125754432289702
# y_pred shape:
# (42416, 2)
# y_pred2 shape:
# (5,)
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - ADABoost AGGREGATE
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92    181370
#            1       0.00      0.00      0.00     30711
#
#     accuracy                           0.86    212081
#    macro avg       0.43      0.50      0.46    212081
# weighted avg       0.73      0.86      0.79    212081
#
# Hamming Loss: 0.1448078415808157
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
import os
import pandas as pd

folder = "C:/Users/mdjaw/OneDrive/Documents/Markian Training/Research_USQ/USCenterDiseaseControlPrevention/LLCP2019XPT" 
os.chdir(folder)

BRFSS_Grounded = pd.read_csv("LLCP2019XPT_Grounded_KGFS95.csv")

print(BRFSS_Grounded.shape)

BRFSS_Grounded_X = BRFSS_Grounded.drop(['CNCRTYP1', 'DIABETE4'], axis = 1)

print(BRFSS_Grounded_X.shape)

# %%
from sklearn.datasets import make_multilabel_classification
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.neural_network import MLPRegressor
from imblearn.ensemble import RUSBoostClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import hamming_loss
from sklearn.model_selection import KFold
from sklearn.metrics import classification_report
import numpy as np


X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = LogisticRegression(C=1.0, penalty='l1', dual=False, solver='liblinear')
  model = OneVsRestClassifier(model)    
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
print("y_pred shape: ")
print(np.shape(y_pred))

print("y_pred2 shape:")
print(np.shape(y_pred2))

y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = MultinomialNB()
  model = OneVsRestClassifier(MultinomialNB())   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
   
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
              solver='svd', store_covariance=False, tol=0.0001))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))
    
X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(RandomForestClassifier(max_depth=100, random_state=0))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))
    
X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(KNeighborsClassifier(n_neighbors=5))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

a = []
b = []
X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(SVC())   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded - SVM")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))  
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - SVM AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  #model = MultinomialNB()
  model = OneVsRestClassifier(RUSBoostClassifier(random_state=0))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded - RUSBoost")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
   
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
print("y_pred shape: ")
print(np.shape(y_pred))

print("y_pred2 shape:")
print(np.shape(y_pred2))

y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - RUSBoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  #model = OneVsRestClassifier(AdaBoostClassifier(n_estimators=50,learning_rate=1))   
  
  model = OneVsRestClassifier(AdaBoostClassifier(n_estimators=200,learning_rate=1))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
   
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
print("y_pred shape: ")
print(np.shape(y_pred))

print("y_pred2 shape:")
print(np.shape(y_pred2))

y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - ADABoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

# %%
import os
import pandas as pd

folder = "C:/Users/mdjaw/OneDrive/Documents/Markian Training/Research_USQ/USCenterDiseaseControlPrevention/LLCP2019XPT" 
os.chdir(folder)

BRFSS_Grounded = pd.read_csv("LLCP2019XPT_Grounded_KGFS90.csv")

print(BRFSS_Grounded.shape)

BRFSS_Grounded_X = BRFSS_Grounded.drop(['CNCRTYP1', 'DIABETE4'], axis = 1)

print(BRFSS_Grounded_X.shape)
# Out:
# (27254, 78)
# (27254, 76)

# %%
from sklearn.datasets import make_multilabel_classification
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.neural_network import MLPRegressor
from imblearn.ensemble import RUSBoostClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import hamming_loss
from sklearn.model_selection import KFold
from sklearn.metrics import classification_report
import numpy as np


X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = LogisticRegression(C=1.0, penalty='l1', dual=False, solver='liblinear')
  model = OneVsRestClassifier(model)    
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
print("y_pred shape: ")
print(np.shape(y_pred))

print("y_pred2 shape:")
print(np.shape(y_pred2))

y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = MultinomialNB()
  model = OneVsRestClassifier(MultinomialNB())   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
   
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
              solver='svd', store_covariance=False, tol=0.0001))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))
    
X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(RandomForestClassifier(max_depth=100, random_state=0))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))
    
X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(KNeighborsClassifier(n_neighbors=5))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

a = []
b = []
X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(SVC())   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded - SVM")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))  
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - SVM AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  #model = MultinomialNB()
  model = OneVsRestClassifier(RUSBoostClassifier(random_state=0))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded - RUSBoost")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
   
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
print("y_pred shape: ")
print(np.shape(y_pred))

print("y_pred2 shape:")
print(np.shape(y_pred2))

y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - RUSBoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  #model = OneVsRestClassifier(AdaBoostClassifier(n_estimators=50,learning_rate=1))   
  
  model = OneVsRestClassifier(AdaBoostClassifier(n_estimators=200,learning_rate=1))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
   
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
print("y_pred shape: ")
print(np.shape(y_pred))

print("y_pred2 shape:")
print(np.shape(y_pred2))

y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - ADABoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))
# Out:
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92      4671
#            1       0.00      0.00      0.00       780
#
#     accuracy                           0.86      5451
#    macro avg       0.43      0.50      0.46      5451
# weighted avg       0.73      0.86      0.79      5451
#
# Hamming Loss: 0.14309301045679693
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.93      4704
#            1       0.00      0.00      0.00       747
#
#     accuracy                           0.86      5451
#    macro avg       0.43      0.50      0.46      5451
# weighted avg       0.74      0.86      0.80      5451
#
# Hamming Loss: 0.13703907539900936
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92      4665
#            1       0.00      0.00      0.00       786
#
#     accuracy                           0.86      5451
#    macro avg       0.43      0.50      0.46      5451
# weighted avg       0.73      0.86      0.79      5451
#
# Hamming Loss: 0.1441937259218492
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94      4789
#            1       0.00      0.00      0.00       662
#
#     accuracy                           0.88      5451
#    macro avg       0.44      0.50      0.47      5451
# weighted avg       0.77      0.88      0.82      5451
#
# Hamming Loss: 0.12144560631076867
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94      4840
#            1       0.00      0.00      0.00       610
#
#     accuracy                           0.89      5450
#    macro avg       0.44      0.50      0.47      5450
# weighted avg       0.79      0.89      0.84      5450
#
# Hamming Loss: 0.11192660550458716
# y_pred shape:
# (5450, 2)
# y_pred2 shape:
# (5,)
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression AGGREGATE
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93     23669
#            1       0.00      0.00      0.00      3585
#
#     accuracy                           0.87     27254
#    macro avg       0.43      0.50      0.46     27254
# weighted avg       0.75      0.87      0.81     27254
#
# Hamming Loss: 0.13153960471860224
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92      4671
#            1       0.00      0.00      0.00       780
#
#     accuracy                           0.86      5451
#    macro avg       0.43      0.50      0.46      5451
# weighted avg       0.73      0.86      0.79      5451
#
# Hamming Loss: 0.14309301045679693
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.93      4704
#            1       0.00      0.00      0.00       747
#
#     accuracy                           0.86      5451
#    macro avg       0.43      0.50      0.46      5451
# weighted avg       0.74      0.86      0.80      5451
#
# Hamming Loss: 0.13703907539900936
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92      4665
#            1       0.00      0.00      0.00       786
#
#     accuracy                           0.86      5451
#    macro avg       0.43      0.50      0.46      5451
# weighted avg       0.73      0.86      0.79      5451
#
# Hamming Loss: 0.1441937259218492
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94      4789
#            1       0.00      0.00      0.00       662
#
#     accuracy                           0.88      5451
#    macro avg       0.44      0.50      0.47      5451
# weighted avg       0.77      0.88      0.82      5451
#
# Hamming Loss: 0.12144560631076867
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94      4840
#            1       0.00      0.00      0.00       610
#
#     accuracy                           0.89      5450
#    macro avg       0.44      0.50      0.47      5450
# weighted avg       0.79      0.89      0.84      5450
#
# Hamming Loss: 0.11192660550458716
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB AGGREGATE
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93     23669
#            1       0.00      0.00      0.00      3585
#
#     accuracy                           0.87     27254
#    macro avg       0.43      0.50      0.46     27254
# weighted avg       0.75      0.87      0.81     27254
#
# Hamming Loss: 0.13153960471860224
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92      4671
#            1       0.00      0.00      0.00       780
#
#     accuracy                           0.86      5451
#    macro avg       0.43      0.50      0.46      5451
# weighted avg       0.73      0.86      0.79      5451
#
# Hamming Loss: 0.14309301045679693
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.93      4704
#            1       0.00      0.00      0.00       747
#
#     accuracy                           0.86      5451
#    macro avg       0.43      0.50      0.46      5451
# weighted avg       0.74      0.86      0.80      5451
#
# Hamming Loss: 0.13703907539900936
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92      4665
#            1       0.00      0.00      0.00       786
#
#     accuracy                           0.86      5451
#    macro avg       0.43      0.50      0.46      5451
# weighted avg       0.73      0.86      0.79      5451
#
# Hamming Loss: 0.1441937259218492
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94      4789
#            1       0.00      0.00      0.00       662
#
#     accuracy                           0.88      5451
#    macro avg       0.44      0.50      0.47      5451
# weighted avg       0.77      0.88      0.82      5451
#
# Hamming Loss: 0.12144560631076867
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94      4840
#            1       0.00      0.00      0.00       610
#
#     accuracy                           0.89      5450
#    macro avg       0.44      0.50      0.47      5450
# weighted avg       0.79      0.89      0.84      5450
#
# Hamming Loss: 0.11192660550458716
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA AGGREGATE
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93     23669
#            1       0.00      0.00      0.00      3585
#
#     accuracy                           0.87     27254
#    macro avg       0.43      0.50      0.46     27254
# weighted avg       0.75      0.87      0.81     27254
#
# Hamming Loss: 0.13153960471860224
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92      4671
#            1       0.00      0.00      0.00       780
#
#     accuracy                           0.86      5451
#    macro avg       0.43      0.50      0.46      5451
# weighted avg       0.73      0.86      0.79      5451
#
# Hamming Loss: 0.14309301045679693
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.93      4704
#            1       0.00      0.00      0.00       747
#
#     accuracy                           0.86      5451
#    macro avg       0.43      0.50      0.46      5451
# weighted avg       0.74      0.86      0.80      5451
#
# Hamming Loss: 0.13703907539900936
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92      4665
#            1       0.00      0.00      0.00       786
#
#     accuracy                           0.86      5451
#    macro avg       0.43      0.50      0.46      5451
# weighted avg       0.73      0.86      0.79      5451
#
# Hamming Loss: 0.1441937259218492
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94      4789
#            1       0.00      0.00      0.00       662
#
#     accuracy                           0.88      5451
#    macro avg       0.44      0.50      0.47      5451
# weighted avg       0.77      0.88      0.82      5451
#
# Hamming Loss: 0.12144560631076867
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94      4840
#            1       0.00      0.00      0.00       610
#
#     accuracy                           0.89      5450
#    macro avg       0.44      0.50      0.47      5450
# weighted avg       0.79      0.89      0.84      5450
#
# Hamming Loss: 0.11192660550458716
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest AGGREGATE
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93     23669
#            1       0.00      0.00      0.00      3585
#
#     accuracy                           0.87     27254
#    macro avg       0.43      0.50      0.46     27254
# weighted avg       0.75      0.87      0.81     27254
#
# Hamming Loss: 0.13153960471860224
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92      4671
#            1       0.00      0.00      0.00       780
#
#     accuracy                           0.86      5451
#    macro avg       0.43      0.50      0.46      5451
# weighted avg       0.73      0.86      0.79      5451
#
# Hamming Loss: 0.14309301045679693
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.93      4704
#            1       0.00      0.00      0.00       747
#
#     accuracy                           0.86      5451
#    macro avg       0.43      0.50      0.46      5451
# weighted avg       0.74      0.86      0.80      5451
#
# Hamming Loss: 0.13703907539900936
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92      4665
#            1       0.00      0.00      0.00       786
#
#     accuracy                           0.86      5451
#    macro avg       0.43      0.50      0.46      5451
# weighted avg       0.73      0.86      0.79      5451
#
# Hamming Loss: 0.1441937259218492
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94      4789
#            1       0.00      0.00      0.00       662
#
#     accuracy                           0.88      5451
#    macro avg       0.44      0.50      0.47      5451
# weighted avg       0.77      0.88      0.82      5451
#
# Hamming Loss: 0.12144560631076867
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94      4840
#            1       0.00      0.00      0.00       610
#
#     accuracy                           0.89      5450
#    macro avg       0.44      0.50      0.47      5450
# weighted avg       0.79      0.89      0.84      5450
#
# Hamming Loss: 0.11192660550458716
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN AGGREGATE
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93     23669
#            1       0.00      0.00      0.00      3585
#
#     accuracy                           0.87     27254
#    macro avg       0.43      0.50      0.46     27254
# weighted avg       0.75      0.87      0.81     27254
#
# Hamming Loss: 0.13153960471860224
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - SVM
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92      4671
#            1       0.00      0.00      0.00       780
#
#     accuracy                           0.86      5451
#    macro avg       0.43      0.50      0.46      5451
# weighted avg       0.73      0.86      0.79      5451
#
# ...
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - RUSBoost
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92      4665
#            1       0.00      0.00      0.00       786
#
#     accuracy                           0.86      5451
#    macro avg       0.43      0.50      0.46      5451
# weighted avg       0.73      0.86      0.79      5451
#
# Hamming Loss: 0.1441937259218492
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - RUSBoost
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94      4789
#            1       0.00      0.00      0.00       662
#
#     accuracy                           0.88      5451
#    macro avg       0.44      0.50      0.47      5451
# weighted avg       0.77      0.88      0.82      5451
#
# Hamming Loss: 0.12144560631076867
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - RUSBoost
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94      4840
#            1       0.00      0.00      0.00       610
#
#     accuracy                           0.89      5450
#    macro avg       0.44      0.50      0.47      5450
# weighted avg       0.79      0.89      0.84      5450
#
# Hamming Loss: 0.11192660550458716
# y_pred shape:
# (5450, 2)
# y_pred2 shape:
# (5,)
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - RUSBoost AGGREGATE
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93     23669
#            1       0.00      0.00      0.00      3585
#
#     accuracy                           0.87     27254
#    macro avg       0.43      0.50      0.46     27254
# weighted avg       0.75      0.87      0.81     27254
#
# Hamming Loss: 0.13153960471860224
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92      4671
#            1       0.00      0.00      0.00       780
#
#     accuracy                           0.86      5451
#    macro avg       0.43      0.50      0.46      5451
# weighted avg       0.73      0.86      0.79      5451
#
# Hamming Loss: 0.14309301045679693
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.93      4704
#            1       0.00      0.00      0.00       747
#
#     accuracy                           0.86      5451
#    macro avg       0.43      0.50      0.46      5451
# weighted avg       0.74      0.86      0.80      5451
#
# Hamming Loss: 0.13703907539900936
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92      4665
#            1       0.00      0.00      0.00       786
#
#     accuracy                           0.86      5451
#    macro avg       0.43      0.50      0.46      5451
# weighted avg       0.73      0.86      0.79      5451
#
# Hamming Loss: 0.1441937259218492
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94      4789
#            1       0.00      0.00      0.00       662
#
#     accuracy                           0.88      5451
#    macro avg       0.44      0.50      0.47      5451
# weighted avg       0.77      0.88      0.82      5451
#
# Hamming Loss: 0.12144560631076867
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94      4840
#            1       0.00      0.00      0.00       610
#
#     accuracy                           0.89      5450
#    macro avg       0.44      0.50      0.47      5450
# weighted avg       0.79      0.89      0.84      5450
#
# Hamming Loss: 0.11192660550458716
# y_pred shape:
# (5450, 2)
# y_pred2 shape:
# (5,)
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - ADABoost AGGREGATE
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93     23669
#            1       0.00      0.00      0.00      3585
#
#     accuracy                           0.87     27254
#    macro avg       0.43      0.50      0.46     27254
# weighted avg       0.75      0.87      0.81     27254
#
# Hamming Loss: 0.13153960471860224
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
import os
import pandas as pd

folder = "C:/Users/mdjaw/OneDrive/Documents/Markian Training/Research_USQ/USCenterDiseaseControlPrevention/LLCP2019XPT" 
os.chdir(folder)

BRFSS_Grounded = pd.read_csv("LLCP2019XPT_Grounded_KGFS1.csv")

print(BRFSS_Grounded.shape)

BRFSS_Grounded_X = BRFSS_Grounded.drop(['CNCRTYP1', 'DIABETE4'], axis = 1)

print(BRFSS_Grounded_X.shape)
# Out:
# (204373, 4)
# (204373, 2)

# %%
from sklearn.datasets import make_multilabel_classification
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.neural_network import MLPRegressor
from imblearn.ensemble import RUSBoostClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import hamming_loss
from sklearn.model_selection import KFold
from sklearn.metrics import classification_report
import numpy as np


X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = LogisticRegression(C=1.0, penalty='l1', dual=False, solver='liblinear')
  model = OneVsRestClassifier(model)    
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
print("y_pred shape: ")
print(np.shape(y_pred))

print("y_pred2 shape:")
print(np.shape(y_pred2))

y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = MultinomialNB()
  model = OneVsRestClassifier(MultinomialNB())   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
   
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
              solver='svd', store_covariance=False, tol=0.0001))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))
    
X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(RandomForestClassifier(max_depth=100, random_state=0))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))
    
X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(KNeighborsClassifier(n_neighbors=5))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

a = []
b = []
X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(SVC())   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded - SVM")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))  
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - SVM AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  #model = MultinomialNB()
  model = OneVsRestClassifier(RUSBoostClassifier(random_state=0))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded - RUSBoost")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
   
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
print("y_pred shape: ")
print(np.shape(y_pred))

print("y_pred2 shape:")
print(np.shape(y_pred2))

y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - RUSBoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  #model = OneVsRestClassifier(AdaBoostClassifier(n_estimators=50,learning_rate=1))   
  
  model = OneVsRestClassifier(AdaBoostClassifier(n_estimators=200,learning_rate=1))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
   
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
print("y_pred shape: ")
print(np.shape(y_pred))

print("y_pred2 shape:")
print(np.shape(y_pred2))

y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - ADABoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))
# Out:
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\svm\_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92     34607
#            1       0.00      0.00      0.00      6268
#
#     accuracy                           0.85     40875
#    macro avg       0.42      0.50      0.46     40875
# weighted avg       0.72      0.85      0.78     40875
#
# Hamming Loss: 0.15334556574923547
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\svm\_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92     34974
#            1       0.00      0.00      0.00      5901
#
#     accuracy                           0.86     40875
#    macro avg       0.43      0.50      0.46     40875
# weighted avg       0.73      0.86      0.79     40875
#
# Hamming Loss: 0.14436697247706423
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\svm\_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92     34941
#            1       0.00      0.00      0.00      5934
#
#     accuracy                           0.85     40875
#    macro avg       0.43      0.50      0.46     40875
# weighted avg       0.73      0.85      0.79     40875
#
# Hamming Loss: 0.14517431192660551
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\svm\_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.84      1.00      0.91     34393
#            1       0.00      0.00      0.00      6481
#
#     accuracy                           0.84     40874
#    macro avg       0.42      0.50      0.46     40874
# weighted avg       0.71      0.84      0.77     40874
#
# Hamming Loss: 0.15856045407838723
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93     35715
#            1       0.00      0.00      0.00      5159
#
#     accuracy                           0.87     40874
#    macro avg       0.44      0.50      0.47     40874
# weighted avg       0.76      0.87      0.81     40874
#
# Hamming Loss: 0.12621715515975926
# y_pred shape:
# (40874, 2)
# y_pred2 shape:
# (5,)
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression AGGREGATE
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92    174630
#            1       0.00      0.00      0.00     29743
#
#     accuracy                           0.85    204373
#    macro avg       0.43      0.50      0.46    204373
# weighted avg       0.73      0.85      0.79    204373
#
# Hamming Loss: 0.14553289187821034
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92     34607
#            1       0.00      0.00      0.00      6268
#
#     accuracy                           0.85     40875
#    macro avg       0.42      0.50      0.46     40875
# weighted avg       0.72      0.85      0.78     40875
#
# Hamming Loss: 0.15334556574923547
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92     34974
#            1       0.00      0.00      0.00      5901
#
#     accuracy                           0.86     40875
#    macro avg       0.43      0.50      0.46     40875
# weighted avg       0.73      0.86      0.79     40875
#
# Hamming Loss: 0.14436697247706423
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92     34941
#            1       0.00      0.00      0.00      5934
#
#     accuracy                           0.85     40875
#    macro avg       0.43      0.50      0.46     40875
# weighted avg       0.73      0.85      0.79     40875
#
# Hamming Loss: 0.14517431192660551
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.84      1.00      0.91     34393
#            1       0.00      0.00      0.00      6481
#
#     accuracy                           0.84     40874
#    macro avg       0.42      0.50      0.46     40874
# weighted avg       0.71      0.84      0.77     40874
#
# Hamming Loss: 0.15856045407838723
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93     35715
#            1       0.00      0.00      0.00      5159
#
#     accuracy                           0.87     40874
#    macro avg       0.44      0.50      0.47     40874
# weighted avg       0.76      0.87      0.81     40874
#
# Hamming Loss: 0.12621715515975926
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB AGGREGATE
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92    174630
#            1       0.00      0.00      0.00     29743
#
#     accuracy                           0.85    204373
#    macro avg       0.43      0.50      0.46    204373
# weighted avg       0.73      0.85      0.79    204373
#
# Hamming Loss: 0.14553289187821034
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92     34607
#            1       0.00      0.00      0.00      6268
#
#     accuracy                           0.85     40875
#    macro avg       0.42      0.50      0.46     40875
# weighted avg       0.72      0.85      0.78     40875
#
# Hamming Loss: 0.15334556574923547
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92     34974
#            1       0.00      0.00      0.00      5901
#
#     accuracy                           0.86     40875
#    macro avg       0.43      0.50      0.46     40875
# weighted avg       0.73      0.86      0.79     40875
#
# Hamming Loss: 0.14436697247706423
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92     34941
#            1       0.00      0.00      0.00      5934
#
#     accuracy                           0.85     40875
#    macro avg       0.43      0.50      0.46     40875
# weighted avg       0.73      0.85      0.79     40875
#
# Hamming Loss: 0.14517431192660551
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA
#               precision    recall  f1-score   support
#
#            0       0.84      1.00      0.91     34393
#            1       0.00      0.00      0.00      6481
#
#     accuracy                           0.84     40874
#    macro avg       0.42      0.50      0.46     40874
# weighted avg       0.71      0.84      0.77     40874
#
# Hamming Loss: 0.15856045407838723
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93     35715
#            1       0.00      0.00      0.00      5159
#
#     accuracy                           0.87     40874
#    macro avg       0.44      0.50      0.47     40874
# weighted avg       0.76      0.87      0.81     40874
#
# Hamming Loss: 0.12621715515975926
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA AGGREGATE
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92    174630
#            1       0.00      0.00      0.00     29743
#
#     accuracy                           0.85    204373
#    macro avg       0.43      0.50      0.46    204373
# weighted avg       0.73      0.85      0.79    204373
#
# Hamming Loss: 0.14553289187821034
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92     34607
#            1       0.00      0.00      0.00      6268
#
#     accuracy                           0.85     40875
#    macro avg       0.42      0.50      0.46     40875
# weighted avg       0.72      0.85      0.78     40875
#
# Hamming Loss: 0.15334556574923547
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92     34974
#            1       0.00      0.00      0.00      5901
#
#     accuracy                           0.86     40875
#    macro avg       0.43      0.50      0.46     40875
# weighted avg       0.73      0.86      0.79     40875
#
# Hamming Loss: 0.14436697247706423
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92     34941
#            1       0.00      0.00      0.00      5934
#
#     accuracy                           0.85     40875
#    macro avg       0.43      0.50      0.46     40875
# weighted avg       0.73      0.85      0.79     40875
#
# Hamming Loss: 0.14517431192660551
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest
#               precision    recall  f1-score   support
#
#            0       0.84      1.00      0.91     34393
#            1       0.00      0.00      0.00      6481
#
#     accuracy                           0.84     40874
#    macro avg       0.42      0.50      0.46     40874
# weighted avg       0.71      0.84      0.77     40874
#
# Hamming Loss: 0.15856045407838723
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93     35715
#            1       0.00      0.00      0.00      5159
#
#     accuracy                           0.87     40874
#    macro avg       0.44      0.50      0.47     40874
# weighted avg       0.76      0.87      0.81     40874
#
# Hamming Loss: 0.12621715515975926
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest AGGREGATE
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92    174630
#            1       0.00      0.00      0.00     29743
#
#     accuracy                           0.85    204373
#    macro avg       0.43      0.50      0.46    204373
# weighted avg       0.73      0.85      0.79    204373
#
# Hamming Loss: 0.14553289187821034
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92     34607
#            1       0.00      0.00      0.00      6268
#
#     accuracy                           0.85     40875
#    macro avg       0.42      0.50      0.46     40875
# weighted avg       0.72      0.85      0.78     40875
#
# Hamming Loss: 0.15334556574923547
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92     34974
#            1       0.00      0.00      0.00      5901
#
#     accuracy                           0.86     40875
#    macro avg       0.43      0.50      0.46     40875
# weighted avg       0.73      0.86      0.79     40875
#
# Hamming Loss: 0.14436697247706423
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92     34941
#            1       0.00      0.00      0.00      5934
#
#     accuracy                           0.85     40875
#    macro avg       0.43      0.50      0.46     40875
# weighted avg       0.73      0.85      0.79     40875
#
# Hamming Loss: 0.14517431192660551
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN
#               precision    recall  f1-score   support
#
#            0       0.84      1.00      0.91     34393
#            1       0.00      0.00      0.00      6481
#
#     accuracy                           0.84     40874
#    macro avg       0.42      0.50      0.46     40874
# weighted avg       0.71      0.84      0.77     40874
#
# Hamming Loss: 0.15856045407838723
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93     35715
#            1       0.00      0.00      0.00      5159
#
#     accuracy                           0.87     40874
#    macro avg       0.44      0.50      0.47     40874
# weighted avg       0.76      0.87      0.81     40874
#
# Hamming Loss: 0.12621715515975926
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN AGGREGATE
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92    174630
#            1       0.00      0.00      0.00     29743
#
#     accuracy                           0.85    204373
#    macro avg       0.43      0.50      0.46    204373
# weighted avg       0.73      0.85      0.79    204373
#
# Hamming Loss: 0.14553289187821034
# BRFSS MultiLabel Cancer + Diabetes - Grounded - SVM
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92     34607
#            1       0.00      0.00      0.00      6268
#
#     accuracy                           0.85     40875
#    macro avg       0.42      0.50      0.46     40875
# weighted avg       0.72      0.85      0.78     40875
#
# Hamming Loss: 0.15334556574923547
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - SVM
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92     34974
#            1       0.00      0.00      0.00      5901
#
#     accuracy                           0.86     40875
#    macro avg       0.43      0.50      0.46     40875
# weighted avg       0.73      0.86      0.79     40875
#
# Hamming Loss: 0.14436697247706423
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - RUSBoost
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92     34974
#            1       0.00      0.00      0.00      5901
#
#     accuracy                           0.86     40875
#    macro avg       0.43      0.50      0.46     40875
# weighted avg       0.73      0.86      0.79     40875
#
# Hamming Loss: 0.14436697247706423
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - RUSBoost
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92     34941
#            1       0.00      0.00      0.00      5934
#
#     accuracy                           0.85     40875
#    macro avg       0.43      0.50      0.46     40875
# weighted avg       0.73      0.85      0.79     40875
#
# Hamming Loss: 0.14517431192660551
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - RUSBoost
#               precision    recall  f1-score   support
#
#            0       0.84      1.00      0.91     34393
#            1       0.00      0.00      0.00      6481
#
#     accuracy                           0.84     40874
#    macro avg       0.42      0.50      0.46     40874
# weighted avg       0.71      0.84      0.77     40874
#
# Hamming Loss: 0.15856045407838723
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - RUSBoost
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93     35715
#            1       0.00      0.00      0.00      5159
#
#     accuracy                           0.87     40874
#    macro avg       0.44      0.50      0.47     40874
# weighted avg       0.76      0.87      0.81     40874
#
# Hamming Loss: 0.12621715515975926
# y_pred shape:
# (40874, 2)
# y_pred2 shape:
# (5,)
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - RUSBoost AGGREGATE
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92    174630
#            1       0.00      0.00      0.00     29743
#
#     accuracy                           0.85    204373
#    macro avg       0.43      0.50      0.46    204373
# weighted avg       0.73      0.85      0.79    204373
#
# Hamming Loss: 0.14553289187821034
# BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92     34607
#            1       0.00      0.00      0.00      6268
#
#     accuracy                           0.85     40875
#    macro avg       0.42      0.50      0.46     40875
# weighted avg       0.72      0.85      0.78     40875
#
# Hamming Loss: 0.15334556574923547
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92     34974
#            1       0.00      0.00      0.00      5901
#
#     accuracy                           0.86     40875
#    macro avg       0.43      0.50      0.46     40875
# weighted avg       0.73      0.86      0.79     40875
#
# Hamming Loss: 0.14436697247706423
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92     34941
#            1       0.00      0.00      0.00      5934
#
#     accuracy                           0.85     40875
#    macro avg       0.43      0.50      0.46     40875
# weighted avg       0.73      0.85      0.79     40875
#
# Hamming Loss: 0.14517431192660551
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost
#               precision    recall  f1-score   support
#
#            0       0.84      1.00      0.91     34393
#            1       0.00      0.00      0.00      6481
#
#     accuracy                           0.84     40874
#    macro avg       0.42      0.50      0.46     40874
# weighted avg       0.71      0.84      0.77     40874
#
# Hamming Loss: 0.15856045407838723
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93     35715
#            1       0.00      0.00      0.00      5159
#
#     accuracy                           0.87     40874
#    macro avg       0.44      0.50      0.47     40874
# weighted avg       0.76      0.87      0.81     40874
#
# Hamming Loss: 0.12621715515975926
# y_pred shape:
# (40874, 2)
# y_pred2 shape:
# (5,)
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - ADABoost AGGREGATE
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92    174630
#            1       0.00      0.00      0.00     29743
#
#     accuracy                           0.85    204373
#    macro avg       0.43      0.50      0.46    204373
# weighted avg       0.73      0.85      0.79    204373
#
# Hamming Loss: 0.14553289187821034
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
import os
import pandas as pd

folder = "C:/Users/mdjaw/OneDrive/Documents/Markian Training/Research_USQ/USCenterDiseaseControlPrevention/LLCP2019XPT" 
os.chdir(folder)
BRFSS_Grounded = pd.read_csv("LLCP2019XPT_LINEAR_WHOICD_V2B.csv")
print(BRFSS_Grounded.shape)
BRFSS_Grounded_X = BRFSS_Grounded.drop(['CNCRTYP1', 'DIABETE4'], axis = 1)
print(BRFSS_Grounded_X.shape)
# Out:
# (212081, 137)
# (212081, 135)

# %%
from sklearn.datasets import make_multilabel_classification
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.neural_network import MLPRegressor
from imblearn.ensemble import RUSBoostClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import hamming_loss
from sklearn.model_selection import KFold
from sklearn.metrics import classification_report
import numpy as np


X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = LogisticRegression(C=1.0, penalty='l1', dual=False, solver='liblinear')
  model = OneVsRestClassifier(model)    
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
print("y_pred shape: ")
print(np.shape(y_pred))

print("y_pred2 shape:")
print(np.shape(y_pred2))

y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = MultinomialNB()
  model = OneVsRestClassifier(MultinomialNB())   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
   
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
              solver='svd', store_covariance=False, tol=0.0001))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))
    
X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(RandomForestClassifier(max_depth=100, random_state=0))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))
    
X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(KNeighborsClassifier(n_neighbors=5))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

a = []
b = []
X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  model = OneVsRestClassifier(SVC())   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded - SVM")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))  
    
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - SVM AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  #model = MultinomialNB()
  model = OneVsRestClassifier(RUSBoostClassifier(random_state=0))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded - RUSBoost")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
   
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
print("y_pred shape: ")
print(np.shape(y_pred))

print("y_pred2 shape:")
print(np.shape(y_pred2))

y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - RUSBoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))

X = np.array(BRFSS_Grounded_X)
y = BRFSS_Grounded[['CNCRTYP1', 'DIABETE4']].to_numpy()

n_split=5

y_pred2, pred2, y_test2, hl2 = list(),list(),list(),list()

for train_index, test_index in KFold(n_split).split(X):
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]

  mlb = MultiLabelBinarizer()
  labels = mlb.fit_transform(y_train)

  mlb = MultiLabelBinarizer()
  mlb.fit(labels)

  #model = OneVsRestClassifier(AdaBoostClassifier(n_estimators=50,learning_rate=1))   
  
  model = OneVsRestClassifier(AdaBoostClassifier(n_estimators=200,learning_rate=1))   
  clf = model.fit(X_train, mlb.transform(y_train))

  y_pred = clf.predict(X_test)  
  pred = np.argmax(y_pred, axis=1)
  y_test = np.argmax(y_test, axis=1)

  print("BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost")
  #print(classification_report(y_test, pred, labels=[1, 2, 3]))
  print(classification_report(y_test, pred))

  hl=hamming_loss(y_test,pred)
  print("Hamming Loss: " + str(hl))
   
  y_pred2.append(y_pred)
  pred2.append(pred)
  y_test2.append(y_test)
  hl2.append(hl)
    
print("y_pred shape: ")
print(np.shape(y_pred))

print("y_pred2 shape:")
print(np.shape(y_pred2))

y_pred3 = np.concatenate((y_pred2[0], y_pred2[1], y_pred2[2], y_pred2[3], y_pred2[4]), axis=None)
pred3 = np.concatenate((pred2[0], pred2[1], pred2[2], pred2[3], pred2[4]), axis=None)
y_test3 = np.concatenate((y_test2[0], y_test2[1], y_test2[2], y_test2[3], y_test2[4]), axis=None)
hl3 = np.concatenate((hl2[0], hl2[1], hl2[2], hl2[3], hl2[4]), axis=None)

print("BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - ADABoost AGGREGATE")
#print(classification_report(y_test, pred, labels=[1, 2, 3]))
print(classification_report(y_test3, pred3))
hl3_avg = sum(hl3) / len(hl3)
print("Hamming Loss: " + str(hl3_avg))
# Out:
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92     35929
#            1       0.00      0.00      0.00      6488
#
#     accuracy                           0.85     42417
#    macro avg       0.42      0.50      0.46     42417
# weighted avg       0.72      0.85      0.78     42417
#
# Hamming Loss: 0.1529575406087182
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92     36367
#            1       0.00      0.00      0.00      6049
#
#     accuracy                           0.86     42416
#    macro avg       0.43      0.50      0.46     42416
# weighted avg       0.74      0.86      0.79     42416
#
# Hamming Loss: 0.14261127876273105
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92     36278
#            1       0.00      0.00      0.00      6138
#
#     accuracy                           0.86     42416
#    macro avg       0.43      0.50      0.46     42416
# weighted avg       0.73      0.86      0.79     42416
#
# Hamming Loss: 0.14470954356846474
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.84      1.00      0.91     35714
#            1       0.00      0.00      0.00      6702
#
#     accuracy                           0.84     42416
#    macro avg       0.42      0.50      0.46     42416
# weighted avg       0.71      0.84      0.77     42416
#
# Hamming Loss: 0.15800641267446247
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93     37082
#            1       0.00      0.00      0.00      5334
#
#     accuracy                           0.87     42416
#    macro avg       0.44      0.50      0.47     42416
# weighted avg       0.76      0.87      0.82     42416
#
# Hamming Loss: 0.125754432289702
# y_pred shape:
# (42416, 2)
# y_pred2 shape:
# (5,)
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Logistic Regression AGGREGATE
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92    181370
#            1       0.00      0.00      0.00     30711
#
#     accuracy                           0.86    212081
#    macro avg       0.43      0.50      0.46    212081
# weighted avg       0.73      0.86      0.79    212081
#
# Hamming Loss: 0.1448078415808157
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92     35929
#            1       0.00      0.00      0.00      6488
#
#     accuracy                           0.85     42417
#    macro avg       0.42      0.50      0.46     42417
# weighted avg       0.72      0.85      0.78     42417
#
# Hamming Loss: 0.1529575406087182
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92     36367
#            1       0.00      0.00      0.00      6049
#
#     accuracy                           0.86     42416
#    macro avg       0.43      0.50      0.46     42416
# weighted avg       0.74      0.86      0.79     42416
#
# Hamming Loss: 0.14261127876273105
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92     36278
#            1       0.00      0.00      0.00      6138
#
#     accuracy                           0.86     42416
#    macro avg       0.43      0.50      0.46     42416
# weighted avg       0.73      0.86      0.79     42416
#
# Hamming Loss: 0.14470954356846474
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94     35714
#            1       1.00      0.36      0.53      6702
#
#     accuracy                           0.90     42416
#    macro avg       0.95      0.68      0.73     42416
# weighted avg       0.91      0.90      0.88     42416
#
# Hamming Loss: 0.10158902301018484
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93     37082
#            1       0.00      0.00      0.00      5334
#
#     accuracy                           0.87     42416
#    macro avg       0.44      0.50      0.47     42416
# weighted avg       0.76      0.87      0.82     42416
#
# Hamming Loss: 0.125754432289702
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - MultinomialNB AGGREGATE
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.93    181370
#            1       1.00      0.08      0.14     30711
#
#     accuracy                           0.87    212081
#    macro avg       0.93      0.54      0.54    212081
# weighted avg       0.88      0.87      0.81    212081
#
# Hamming Loss: 0.13352436364796016
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92     35929
#            1       0.00      0.00      0.00      6488
#
#     accuracy                           0.85     42417
#    macro avg       0.42      0.50      0.46     42417
# weighted avg       0.72      0.85      0.78     42417
#
# Hamming Loss: 0.1529575406087182
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92     36367
#            1       0.00      0.00      0.00      6049
#
#     accuracy                           0.86     42416
#    macro avg       0.43      0.50      0.46     42416
# weighted avg       0.74      0.86      0.79     42416
#
# Hamming Loss: 0.14261127876273105
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92     36278
#            1       0.00      0.00      0.00      6138
#
#     accuracy                           0.86     42416
#    macro avg       0.43      0.50      0.46     42416
# weighted avg       0.73      0.86      0.79     42416
#
# Hamming Loss: 0.14470954356846474
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA
#               precision    recall  f1-score   support
#
#            0       0.84      1.00      0.91     35714
#            1       0.00      0.00      0.00      6702
#
#     accuracy                           0.84     42416
#    macro avg       0.42      0.50      0.46     42416
# weighted avg       0.71      0.84      0.77     42416
#
# Hamming Loss: 0.15800641267446247
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93     37082
#            1       0.00      0.00      0.00      5334
#
#     accuracy                           0.87     42416
#    macro avg       0.44      0.50      0.47     42416
# weighted avg       0.76      0.87      0.82     42416
#
# Hamming Loss: 0.125754432289702
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Linear DA AGGREGATE
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92    181370
#            1       0.00      0.00      0.00     30711
#
#     accuracy                           0.86    212081
#    macro avg       0.43      0.50      0.46    212081
# weighted avg       0.73      0.86      0.79    212081
#
# Hamming Loss: 0.1448078415808157
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92     35929
#            1       0.00      0.00      0.00      6488
#
#     accuracy                           0.85     42417
#    macro avg       0.42      0.50      0.46     42417
# weighted avg       0.72      0.85      0.78     42417
#
# Hamming Loss: 0.1529575406087182
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92     36367
#            1       0.00      0.00      0.00      6049
#
#     accuracy                           0.86     42416
#    macro avg       0.43      0.50      0.46     42416
# weighted avg       0.74      0.86      0.79     42416
#
# Hamming Loss: 0.14261127876273105
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92     36278
#            1       0.00      0.00      0.00      6138
#
#     accuracy                           0.86     42416
#    macro avg       0.43      0.50      0.46     42416
# weighted avg       0.73      0.86      0.79     42416
#
# Hamming Loss: 0.14470954356846474
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest
#               precision    recall  f1-score   support
#
#            0       0.84      1.00      0.91     35714
#            1       0.00      0.00      0.00      6702
#
#     accuracy                           0.84     42416
#    macro avg       0.42      0.50      0.46     42416
# weighted avg       0.71      0.84      0.77     42416
#
# Hamming Loss: 0.15800641267446247
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93     37082
#            1       0.00      0.00      0.00      5334
#
#     accuracy                           0.87     42416
#    macro avg       0.44      0.50      0.47     42416
# weighted avg       0.76      0.87      0.82     42416
#
# Hamming Loss: 0.125754432289702
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - Random Forest AGGREGATE
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92    181370
#            1       0.00      0.00      0.00     30711
#
#     accuracy                           0.86    212081
#    macro avg       0.43      0.50      0.46    212081
# weighted avg       0.73      0.86      0.79    212081
#
# Hamming Loss: 0.1448078415808157
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92     35929
#            1       0.00      0.00      0.00      6488
#
#     accuracy                           0.85     42417
#    macro avg       0.42      0.50      0.46     42417
# weighted avg       0.72      0.85      0.78     42417
#
# Hamming Loss: 0.1529575406087182
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92     36367
#            1       0.00      0.00      0.00      6049
#
#     accuracy                           0.86     42416
#    macro avg       0.43      0.50      0.46     42416
# weighted avg       0.74      0.86      0.79     42416
#
# Hamming Loss: 0.14261127876273105
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92     36278
#            1       0.00      0.00      0.00      6138
#
#     accuracy                           0.86     42416
#    macro avg       0.43      0.50      0.46     42416
# weighted avg       0.73      0.86      0.79     42416
#
# Hamming Loss: 0.14470954356846474
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN
#               precision    recall  f1-score   support
#
#            0       0.84      1.00      0.91     35714
#            1       0.00      0.00      0.00      6702
#
#     accuracy                           0.84     42416
#    macro avg       0.42      0.50      0.46     42416
# weighted avg       0.71      0.84      0.77     42416
#
# Hamming Loss: 0.15800641267446247
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93     37082
#            1       0.00      0.00      0.00      5334
#
#     accuracy                           0.87     42416
#    macro avg       0.44      0.50      0.47     42416
# weighted avg       0.76      0.87      0.82     42416
#
# Hamming Loss: 0.125754432289702
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - KNN AGGREGATE
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92    181370
#            1       0.00      0.00      0.00     30711
#
#     accuracy                           0.86    212081
#    macro avg       0.43      0.50      0.46    212081
# weighted avg       0.73      0.86      0.79    212081
#
# Hamming Loss: 0.1448078415808157
# BRFSS MultiLabel Cancer + Diabetes - Grounded - SVM
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92     35929
#            1       0.00      0.00      0.00      6488
#
#     accuracy                           0.85     42417
#    macro avg       0.42      0.50      0.46     42417
# weighted avg       0.72      0.85      0.78     42417
#
# Hamming Loss: 0.1529575406087182
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - SVM
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92     36367
#            1       0.00      0.00      0.00      6049
#
#     accuracy                           0.86     42416
#    macro avg       0.43      0.50      0.46     42416
# weighted avg       0.74      0.86      0.79     42416
#
# Hamming Loss: 0.14261127876273105
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - SVM
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92     36278
#            1       0.00      0.00      0.00      6138
#
#     accuracy                           0.86     42416
#    macro avg       0.43      0.50      0.46     42416
# weighted avg       0.73      0.86      0.79     42416
#
# Hamming Loss: 0.14470954356846474
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - SVM
#               precision    recall  f1-score   support
#
#            0       0.84      1.00      0.91     35714
#            1       0.00      0.00      0.00      6702
#
#     accuracy                           0.84     42416
#    macro avg       0.42      0.50      0.46     42416
# weighted avg       0.71      0.84      0.77     42416
#
# Hamming Loss: 0.15800641267446247
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - RUSBoost
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92     36367
#            1       0.00      0.00      0.00      6049
#
#     accuracy                           0.86     42416
#    macro avg       0.43      0.50      0.46     42416
# weighted avg       0.74      0.86      0.79     42416
#
# Hamming Loss: 0.14261127876273105
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - RUSBoost
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92     36278
#            1       0.00      0.00      0.00      6138
#
#     accuracy                           0.86     42416
#    macro avg       0.43      0.50      0.46     42416
# weighted avg       0.73      0.86      0.79     42416
#
# Hamming Loss: 0.14470954356846474
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - RUSBoost
#               precision    recall  f1-score   support
#
#            0       0.84      1.00      0.91     35714
#            1       0.00      0.00      0.00      6702
#
#     accuracy                           0.84     42416
#    macro avg       0.42      0.50      0.46     42416
# weighted avg       0.71      0.84      0.77     42416
#
# Hamming Loss: 0.15800641267446247
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - RUSBoost
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93     37082
#            1       0.00      0.00      0.00      5334
#
#     accuracy                           0.87     42416
#    macro avg       0.44      0.50      0.47     42416
# weighted avg       0.76      0.87      0.82     42416
#
# Hamming Loss: 0.125754432289702
# y_pred shape:
# (42416, 2)
# y_pred2 shape:
# (5,)
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - RUSBoost AGGREGATE
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92    181370
#            1       0.00      0.00      0.00     30711
#
#     accuracy                           0.86    212081
#    macro avg       0.43      0.50      0.46    212081
# weighted avg       0.73      0.86      0.79    212081
#
# Hamming Loss: 0.1448078415808157
# BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92     35929
#            1       0.00      0.00      0.00      6488
#
#     accuracy                           0.85     42417
#    macro avg       0.42      0.50      0.46     42417
# weighted avg       0.72      0.85      0.78     42417
#
# Hamming Loss: 0.1529575406087182
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92     36367
#            1       0.00      0.00      0.00      6049
#
#     accuracy                           0.86     42416
#    macro avg       0.43      0.50      0.46     42416
# weighted avg       0.74      0.86      0.79     42416
#
# Hamming Loss: 0.14261127876273105
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92     36278
#            1       0.00      0.00      0.00      6138
#
#     accuracy                           0.86     42416
#    macro avg       0.43      0.50      0.46     42416
# weighted avg       0.73      0.86      0.79     42416
#
# Hamming Loss: 0.14470954356846474
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost
#               precision    recall  f1-score   support
#
#            0       0.84      1.00      0.91     35714
#            1       0.00      0.00      0.00      6702
#
#     accuracy                           0.84     42416
#    macro avg       0.42      0.50      0.46     42416
# weighted avg       0.71      0.84      0.77     42416
#
# Hamming Loss: 0.15800641267446247
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\multiclass.py:81: UserWarning: Label 0 is present in all training examples.
#   str(classes[c]))
# BRFSS MultiLabel Cancer + Diabetes - Grounded - AdaBoost
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93     37082
#            1       0.00      0.00      0.00      5334
#
#     accuracy                           0.87     42416
#    macro avg       0.44      0.50      0.47     42416
# weighted avg       0.76      0.87      0.82     42416
#
# Hamming Loss: 0.125754432289702
# y_pred shape:
# (42416, 2)
# y_pred2 shape:
# (5,)
# BRFSS MultiLabel Cancer + Diabetes - Grounded, Knowledge Graph-Based Feature Selection - ADABoost AGGREGATE
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92    181370
#            1       0.00      0.00      0.00     30711
#
#     accuracy                           0.86    212081
#    macro avg       0.43      0.50      0.46    212081
# weighted avg       0.73      0.86      0.79    212081
#
# Hamming Loss: 0.1448078415808157
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\envs\newenvt\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
